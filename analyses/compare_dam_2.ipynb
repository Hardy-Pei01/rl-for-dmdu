# %% [markdown]
# # Robust Dam Problem (random initial state)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_robust_performance_2/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea_random_initial-23-06-2022-16-07_0.tar.gz',
#  'ea_random_initial-23-06-2022-16-07_1.tar.gz',
#  'ea_random_initial-23-06-2022-16-07_2.tar.gz',
#  'ea_random_initial-23-06-2022-16-07_3.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_0.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_1.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_10.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_11.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_12.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_13.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_14.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_15.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_16.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_17.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_18.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_19.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_2.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_20.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_21.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_22.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_23.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_24.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_25.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_26.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_27.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_28.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_29.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_3.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_4.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_5.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_6.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_7.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_8.tar.gz',
#  'ea_random_initial_avg-24-06-2022-13-53_9.tar.gz',
#  'nes_random_initial-23-06-2022-16-32_best.csv',
#  'nes_random_initial-23-06-2022-16-35_high.csv',
#  'nes_random_initial_avg-23-06-2022-17-18_best.csv',
#  'nes_random_initial_avg-23-06-2022-17-20_high.csv',
#  'repsep_random_initial-23-06-2022-16-38_best.csv',
#  'repsep_random_initial-23-06-2022-16-41_high.csv',
#  'repsep_random_initial_avg-23-06-2022-17-12_best.csv',
#  'repsep_random_initial_avg-23-06-2022-17-15_high.csv']

# %%
ea=[]
for i in range(1, 5):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# ea_random_initial-23-06-2022-16-07_0.tar.gz
# ea_random_initial-23-06-2022-16-07_1.tar.gz
# ea_random_initial-23-06-2022-16-07_2.tar.gz
# ea_random_initial-23-06-2022-16-07_3.tar.gz
#     utility  reliability       Algorithms
# 0 -0.056254    -9.856251  Epsilon-NSGA-II
# 1 -0.425008    -9.762497  Epsilon-NSGA-II
# 2 -0.312507    -9.781248  Epsilon-NSGA-II
# 3 -0.712512    -9.687499  Epsilon-NSGA-II

# %%
path = files[35]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes_random_initial-23-06-2022-16-32_best.csv
#      utility  reliability Algorithms
# 0  -0.513553    -9.554044     MO-NES
# 1  -1.217668    -9.407958     MO-NES
# 2  -0.964750    -9.448894     MO-NES
# 3  -0.074695    -9.802474     MO-NES
# 4  -0.504076    -9.564494     MO-NES
# ..       ...          ...        ...
# 74 -0.234048    -9.671671     MO-NES
# 75 -0.062688    -9.825865     MO-NES
# 76 -0.056280    -9.850075     MO-NES
# 77 -0.066427    -9.817853     MO-NES
# 78 -1.275033    -9.399994     MO-NES
#
# [79 rows x 3 columns]

# %%
path = files[39]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep_random_initial-23-06-2022-16-38_best.csv
#      utility  reliability Algorithms
# 0  -0.063408    -9.825044   MO-eREPS
# 1  -0.165079    -9.713162   MO-eREPS
# 2  -0.150124    -9.724041   MO-eREPS
# 3  -0.100476    -9.769337   MO-eREPS
# 4  -0.094286    -9.777618   MO-eREPS
# ..       ...          ...        ...
# 64 -1.275033    -9.399994   MO-eREPS
# 65 -0.154083    -9.720848   MO-eREPS
# 66 -0.276967    -9.649197   MO-eREPS
# 67 -0.488659    -9.570194   MO-eREPS
# 68 -0.056284    -9.845216   MO-eREPS
#
# [69 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(5, 35):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 0:04:06
# Out:
# ea_random_initial_avg-24-06-2022-13-53_0.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_1.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_10.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_11.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_12.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_13.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_14.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_15.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_16.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_17.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_18.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_19.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_2.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_20.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_21.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_22.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_23.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_24.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_25.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_26.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_27.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_28.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_29.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_3.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_4.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_5.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_6.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_7.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_8.tar.gz
# ea_random_initial_avg-24-06-2022-13-53_9.tar.gz
#      utility  reliability           Algorithms
# 0  -0.062505    -9.831248  Epsilon-NSGA-II_avg
# 1  -0.056254    -9.850000  Epsilon-NSGA-II_avg
# 2  -0.818773    -9.543744  Epsilon-NSGA-II_avg
# 3  -1.250030    -9.431246  Epsilon-NSGA-II_avg
# 4  -0.850024    -9.531246  Epsilon-NSGA-II_avg
# 5  -0.162509    -9.774997  Epsilon-NSGA-II_avg
# 6  -0.875027    -9.499994  Epsilon-NSGA-II_avg
# 7  -0.412516    -9.662495  Epsilon-NSGA-II_avg
# 8  -1.218778    -9.443744  Epsilon-NSGA-II_avg
# 9  -0.343766    -9.674995  Epsilon-NSGA-II_avg
# 10 -0.243762    -9.731246  Epsilon-NSGA-II_avg
# 11 -0.287512    -9.718744  Epsilon-NSGA-II_avg
# 12 -0.087508    -9.799996  Epsilon-NSGA-II_avg
# 13 -0.318764    -9.706247  Epsilon-NSGA-II_avg
# 14 -0.568771    -9.593744  Epsilon-NSGA-II_avg
# 15 -0.512517    -9.637494  Epsilon-NSGA-II_avg
# 16 -0.337515    -9.693746  Epsilon-NSGA-II_avg
# 17 -0.468767    -9.649995  Epsilon-NSGA-II_avg
# 18 -1.050027    -9.481245  Epsilon-NSGA-II_avg
# 19 -1.118778    -9.468745  Epsilon-NSGA-II_avg
# 20 -0.543769    -9.624996  Epsilon-NSGA-II_avg
# 21 -1.175029    -9.456245  Epsilon-NSGA-II_avg
# 22 -1.275033    -9.399994  Epsilon-NSGA-II_avg
# 23 -1.268782    -9.418746  Epsilon-NSGA-II_avg
# 24 -0.650022    -9.581245  Epsilon-NSGA-II_avg
# 25 -0.868776    -9.518746  Epsilon-NSGA-II_avg
# 26 -0.718772    -9.568745  Epsilon-NSGA-II_avg
# 27 -0.131257    -9.787495  Epsilon-NSGA-II_avg
# 28 -0.775023    -9.556245  Epsilon-NSGA-II_avg
# 29 -0.187511    -9.743745  Epsilon-NSGA-II_avg

# %%
path = files[37]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:00:15
# Out:
# nes_random_initial_avg-23-06-2022-17-18_best.csv
#      utility  reliability  Algorithms
# 0  -0.924662    -9.457744  MO-NES_avg
# 1  -0.100004    -9.843725  MO-NES_avg
# 2  -1.174402    -9.417043  MO-NES_avg
# 3  -0.100012    -9.837892  MO-NES_avg
# 4  -0.709062    -9.502494  MO-NES_avg
# 5  -1.041541    -9.435844  MO-NES_avg
# 6  -0.130926    -9.772782  MO-NES_avg
# 7  -1.240598    -9.404444  MO-NES_avg
# 8  -1.274283    -9.400144  MO-NES_avg
# 9  -0.620927    -9.521644  MO-NES_avg
# 10 -0.927978    -9.457600  MO-NES_avg
# 11 -1.096585    -9.425594  MO-NES_avg
# 12 -0.100076    -9.831334  MO-NES_avg
# 13 -0.111668    -9.811164  MO-NES_avg
# 14 -0.513015    -9.553594  MO-NES_avg
# 15 -1.043972    -9.435644  MO-NES_avg
# 16 -0.855671    -9.468394  MO-NES_avg
# 17 -1.250719    -9.403094  MO-NES_avg
# 18 -0.356878    -9.608994  MO-NES_avg
# 19 -0.224992    -9.685761  MO-NES_avg
# 20 -0.373565    -9.608194  MO-NES_avg
# 21 -1.262082    -9.402194  MO-NES_avg
# 22 -0.790873    -9.482794  MO-NES_avg
# 23 -0.960995    -9.452594  MO-NES_avg
# 24 -0.323764    -9.632194  MO-NES_avg
# 25 -0.266512    -9.655847  MO-NES_avg
# 26 -0.108230    -9.811387  MO-NES_avg
# 27 -0.465156    -9.579294  MO-NES_avg
# 28 -0.121597    -9.795541  MO-NES_avg
# 29 -1.186017    -9.412294  MO-NES_avg
# 30 -0.840776    -9.471594  MO-NES_avg
# 31 -0.126197    -9.778677  MO-NES_avg
# 32 -1.104508    -9.424294  MO-NES_avg
# 33 -0.337329    -9.616194  MO-NES_avg
# 34 -0.665075    -9.510394  MO-NES_avg
# 35 -0.447846    -9.586494  MO-NES_avg
# 36 -0.516342    -9.552994  MO-NES_avg
# 37 -0.154985    -9.746685  MO-NES_avg
# 38 -0.747099    -9.498194  MO-NES_avg
# 39 -0.101213    -9.823847  MO-NES_avg
# 40 -1.006345    -9.445994  MO-NES_avg
# 41 -1.064638    -9.431194  MO-NES_avg
# 42 -0.483063    -9.573237  MO-NES_avg
# 43 -1.238832    -9.404644  MO-NES_avg
# 44 -0.304363    -9.632594  MO-NES_avg
# 45 -1.046382    -9.435094  MO-NES_avg
# 46 -1.195057    -9.411694  MO-NES_avg
# 47 -0.216097    -9.741497  MO-NES_avg
# 48 -1.149357    -9.417594  MO-NES_avg
# 49 -1.275033    -9.399994  MO-NES_avg

# %%
path = files[41]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:00:15
# Out:
# repsep_random_initial_avg-23-06-2022-17-12_best.csv
#      utility  reliability    Algorithms
# 0  -1.016225    -9.440044  MO-eREPS_avg
# 1  -0.449655    -9.581744  MO-eREPS_avg
# 2  -0.412155    -9.594244  MO-eREPS_avg
# 3  -0.106082    -9.756186  MO-eREPS_avg
# 4  -0.215800    -9.681423  MO-eREPS_avg
# ..       ...          ...           ...
# 59 -0.064792    -9.820913  MO-eREPS_avg
# 60 -0.503357    -9.555494  MO-eREPS_avg
# 61 -0.061890    -9.827663  MO-eREPS_avg
# 62 -1.272670    -9.400494  MO-eREPS_avg
# 63 -1.275033    -9.399994  MO-eREPS_avg
#
# [64 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %% [markdown]
# # Robust Dam Problem (deep)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_deep_performance_2/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-20-06-2022-19-12_0.tar.gz',
#  'ea-20-06-2022-19-12_1.tar.gz',
#  'ea-20-06-2022-19-12_10.tar.gz',
#  'ea-20-06-2022-19-12_11.tar.gz',
#  'ea-20-06-2022-19-12_2.tar.gz',
#  'ea-20-06-2022-19-12_3.tar.gz',
#  'ea-20-06-2022-19-12_4.tar.gz',
#  'ea-20-06-2022-19-12_5.tar.gz',
#  'ea-20-06-2022-19-12_6.tar.gz',
#  'ea-20-06-2022-19-12_7.tar.gz',
#  'ea-20-06-2022-19-12_8.tar.gz',
#  'ea-20-06-2022-19-12_9.tar.gz',
#  'nes-20-06-2022-19-26_best.csv',
#  'nes-20-06-2022-19-30_high.csv',
#  'repsep-20-06-2022-20-04_best.csv',
#  'repsep-20-06-2022-20-07_high.csv']

# %%
ea=[]
for i in range(1, 13):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# 2:44:18
# Out:
# ea-20-06-2022-19-12_0.tar.gz
# ea-20-06-2022-19-12_1.tar.gz
# ea-20-06-2022-19-12_10.tar.gz
# ea-20-06-2022-19-12_11.tar.gz
# ea-20-06-2022-19-12_2.tar.gz
# ea-20-06-2022-19-12_3.tar.gz
# ea-20-06-2022-19-12_4.tar.gz
# ea-20-06-2022-19-12_5.tar.gz
# ea-20-06-2022-19-12_6.tar.gz
# ea-20-06-2022-19-12_7.tar.gz
# ea-20-06-2022-19-12_8.tar.gz
# ea-20-06-2022-19-12_9.tar.gz
#      utility  reliability       Algorithms
# 0  -1.344520   -10.483557  Epsilon-NSGA-II
# 1  -1.173777   -10.458416  Epsilon-NSGA-II
# 2  -0.986710   -10.533685  Epsilon-NSGA-II
# 3  -0.966826   -10.556930  Epsilon-NSGA-II
# 4  -2.101050   -10.390663  Epsilon-NSGA-II
# 5  -1.190822   -10.535436  Epsilon-NSGA-II
# 6  -1.076432   -10.546595  Epsilon-NSGA-II
# 7  -1.035115   -10.500511  Epsilon-NSGA-II
# 8  -1.316999   -10.461725  Epsilon-NSGA-II
# 9  -0.984165   -10.580531  Epsilon-NSGA-II
# 10 -0.970074   -10.548880  Epsilon-NSGA-II
# 11 -0.980673   -10.593843  Epsilon-NSGA-II

# %%
path = files[13]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes-20-06-2022-19-26_best.csv
#      utility  reliability Algorithms
# 0  -0.151146    -9.798892     MO-NES
# 1  -0.041490    -9.891847     MO-NES
# 2  -0.224540    -9.750292     MO-NES
# 3  -0.153992    -9.796192     MO-NES
# 4  -0.823910    -9.610425     MO-NES
# ..       ...          ...        ...
# 77 -0.261709    -9.733192     MO-NES
# 78 -0.282565    -9.717842     MO-NES
# 79 -0.151445    -9.798592     MO-NES
# 80 -0.073184    -9.870485     MO-NES
# 81 -0.072934    -9.871196     MO-NES
#
# [82 rows x 3 columns]

# %%
path = files[15]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep-20-06-2022-20-04_best.csv
#        utility  reliability Algorithms
# 0    -0.112734    -9.850168   MO-eREPS
# 1    -0.110692    -9.855461   MO-eREPS
# 2    -0.127633    -9.824882   MO-eREPS
# 3    -0.127720    -9.824764   MO-eREPS
# 4    -0.112139    -9.851613   MO-eREPS
# ...        ...          ...        ...
# 1046 -0.172272    -9.781342   MO-eREPS
# 1047 -0.135142    -9.815802   MO-eREPS
# 1048 -0.109062    -9.861041   MO-eREPS
# 1049 -0.109833    -9.858119   MO-eREPS
# 1050 -0.066671    -9.895039   MO-eREPS
#
# [1051 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, repsep, nes])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(11, 29):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 2:49:00
# Out:
# ea_avg-15-06-2022-14-32_0.tar.gz
# ea_avg-15-06-2022-14-32_1.tar.gz
# ea_avg-15-06-2022-14-32_10.tar.gz
# ea_avg-15-06-2022-14-32_11.tar.gz
# ea_avg-15-06-2022-14-32_12.tar.gz
# ea_avg-15-06-2022-14-32_13.tar.gz
# ea_avg-15-06-2022-14-32_14.tar.gz
# ea_avg-15-06-2022-14-32_15.tar.gz
# ea_avg-15-06-2022-14-32_16.tar.gz
# ea_avg-15-06-2022-14-32_17.tar.gz
# ea_avg-15-06-2022-14-32_2.tar.gz
# ea_avg-15-06-2022-14-32_3.tar.gz
# ea_avg-15-06-2022-14-32_4.tar.gz
# ea_avg-15-06-2022-14-32_5.tar.gz
# ea_avg-15-06-2022-14-32_6.tar.gz
# ea_avg-15-06-2022-14-32_7.tar.gz
# ea_avg-15-06-2022-14-32_8.tar.gz
# ea_avg-15-06-2022-14-32_9.tar.gz
#      utility  reliability           Algorithms
# 0  -2.162947   -10.205205  Epsilon-NSGA-II_avg
# 1  -1.866544   -10.282647  Epsilon-NSGA-II_avg
# 2  -1.498090   -10.294420  Epsilon-NSGA-II_avg
# 3  -1.020557   -10.498313  Epsilon-NSGA-II_avg
# 4  -1.064035   -10.427321  Epsilon-NSGA-II_avg
# 5  -1.046334   -10.460896  Epsilon-NSGA-II_avg
# 6  -1.033927   -10.503498  Epsilon-NSGA-II_avg
# 7  -1.024672   -10.485168  Epsilon-NSGA-II_avg
# 8  -1.024066   -10.478417  Epsilon-NSGA-II_avg
# 9  -0.991475   -10.534880  Epsilon-NSGA-II_avg
# 10 -1.797531   -10.201007  Epsilon-NSGA-II_avg
# 11 -1.200216   -10.415975  Epsilon-NSGA-II_avg
# 12 -1.071135   -10.475907  Epsilon-NSGA-II_avg
# 13 -1.030561   -10.476875  Epsilon-NSGA-II_avg
# 14 -1.033876   -10.508739  Epsilon-NSGA-II_avg
# 15 -1.099494   -10.438160  Epsilon-NSGA-II_avg
# 16 -1.670769   -10.269140  Epsilon-NSGA-II_avg
# 17 -1.681601   -10.257370  Epsilon-NSGA-II_avg

# %%
path = files[32]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:03:17
# Out:
# nes_avg-15-06-2022-14-50_high.csv
#       utility  reliability  Algorithms
# 0   -1.050756   -10.273884  MO-NES_avg
# 1   -0.948212   -10.526093  MO-NES_avg
# 2   -1.079465   -10.214036  MO-NES_avg
# 3   -1.043594   -10.304363  MO-NES_avg
# 4   -1.056263   -10.263069  MO-NES_avg
# ..        ...          ...         ...
# 107 -1.071525   -10.257650  MO-NES_avg
# 108 -0.956077   -10.498767  MO-NES_avg
# 109 -1.235252   -10.002350  MO-NES_avg
# 110 -1.135203   -10.122698  MO-NES_avg
# 111 -1.376961    -9.848539  MO-NES_avg
#
# [112 rows x 3 columns]

# %%
path = files[32]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:02:30
# Out:
# nes_avg-15-06-2022-14-50_high.csv
#       utility  reliability    Algorithms
# 0   -1.050756   -10.273884  MO-eREPS_avg
# 1   -0.948212   -10.526093  MO-eREPS_avg
# 2   -1.079465   -10.214036  MO-eREPS_avg
# 3   -1.043594   -10.304363  MO-eREPS_avg
# 4   -1.056263   -10.263069  MO-eREPS_avg
# ..        ...          ...           ...
# 107 -1.071525   -10.257650  MO-eREPS_avg
# 108 -0.956077   -10.498767  MO-eREPS_avg
# 109 -1.235252   -10.002350  MO-eREPS_avg
# 110 -1.135203   -10.122698  MO-eREPS_avg
# 111 -1.376961    -9.848539  MO-eREPS_avg
#
# [112 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()
