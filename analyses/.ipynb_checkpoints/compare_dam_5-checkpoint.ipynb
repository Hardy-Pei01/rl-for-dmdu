# %%
import os, sys
sys.path.append(os.path.abspath('../'))
from utils.rl.hypervolume2d import hypervolume2d

def compute_hypervolume(df, antiutopia, utopia):
    array = df.drop('Algorithms', axis=1)
    array = array.values
    return hypervolume2d(array, antiutopia, utopia)

# %% [markdown]
# # Robust Dam Problem (random initial state)

# %%
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_robust_performance/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'initial-24-06-2022-23-47_0.tar.gz',
#  'initial-24-06-2022-23-47_1.tar.gz',
#  'initial-24-06-2022-23-47_10.tar.gz',
#  'initial-24-06-2022-23-47_11.tar.gz',
#  'initial-24-06-2022-23-47_12.tar.gz',
#  'initial-24-06-2022-23-47_2.tar.gz',
#  'initial-24-06-2022-23-47_3.tar.gz',
#  'initial-24-06-2022-23-47_4.tar.gz',
#  'initial-24-06-2022-23-47_5.tar.gz',
#  'initial-24-06-2022-23-47_6.tar.gz',
#  'initial-24-06-2022-23-47_7.tar.gz',
#  'initial-24-06-2022-23-47_8.tar.gz',
#  'initial-24-06-2022-23-47_9.tar.gz',
#  'initial_avg-24-06-2022-23-50_0.tar.gz',
#  'initial_avg-24-06-2022-23-50_1.tar.gz',
#  'initial_avg-24-06-2022-23-50_10.tar.gz',
#  'initial_avg-24-06-2022-23-50_11.tar.gz',
#  'initial_avg-24-06-2022-23-50_12.tar.gz',
#  'initial_avg-24-06-2022-23-50_13.tar.gz',
#  'initial_avg-24-06-2022-23-50_14.tar.gz',
#  'initial_avg-24-06-2022-23-50_15.tar.gz',
#  'initial_avg-24-06-2022-23-50_16.tar.gz',
#  'initial_avg-24-06-2022-23-50_17.tar.gz',
#  'initial_avg-24-06-2022-23-50_18.tar.gz',
#  'initial_avg-24-06-2022-23-50_19.tar.gz',
#  'initial_avg-24-06-2022-23-50_2.tar.gz',
#  'initial_avg-24-06-2022-23-50_20.tar.gz',
#  'initial_avg-24-06-2022-23-50_21.tar.gz',
#  'initial_avg-24-06-2022-23-50_22.tar.gz',
#  'initial_avg-24-06-2022-23-50_23.tar.gz',
#  'initial_avg-24-06-2022-23-50_24.tar.gz',
#  'initial_avg-24-06-2022-23-50_25.tar.gz',
#  'initial_avg-24-06-2022-23-50_26.tar.gz',
#  'initial_avg-24-06-2022-23-50_27.tar.gz',
#  'initial_avg-24-06-2022-23-50_28.tar.gz',
#  'initial_avg-24-06-2022-23-50_29.tar.gz',
#  'initial_avg-24-06-2022-23-50_3.tar.gz',
#  'initial_avg-24-06-2022-23-50_30.tar.gz',
#  'initial_avg-24-06-2022-23-50_31.tar.gz',
#  'initial_avg-24-06-2022-23-50_32.tar.gz',
#  'initial_avg-24-06-2022-23-50_33.tar.gz',
#  'initial_avg-24-06-2022-23-50_34.tar.gz',
#  'initial_avg-24-06-2022-23-50_35.tar.gz',
#  'initial_avg-24-06-2022-23-50_36.tar.gz',
#  'initial_avg-24-06-2022-23-50_37.tar.gz',
#  'initial_avg-24-06-2022-23-50_38.tar.gz',
#  'initial_avg-24-06-2022-23-50_39.tar.gz',
#  'initial_avg-24-06-2022-23-50_4.tar.gz',
#  'initial_avg-24-06-2022-23-50_5.tar.gz',
#  'initial_avg-24-06-2022-23-50_6.tar.gz',
#  'initial_avg-24-06-2022-23-50_7.tar.gz',
#  'initial_avg-24-06-2022-23-50_8.tar.gz',
#  'initial_avg-24-06-2022-23-50_9.tar.gz',
#  'nes_initial-27-06-2022-18-49_best.csv',
#  'nes_initial-27-06-2022-18-52_high.csv',
#  'nes_initial_avg-28-06-2022-15-36_best.csv',
#  'nes_initial_avg-28-06-2022-15-39_high.csv',
#  'repsep_initial-27-06-2022-18-56_best.csv',
#  'repsep_initial-27-06-2022-19-00_high.csv',
#  'repsep_initial_avg-28-06-2022-15-28_best.csv',
#  'repsep_initial_avg-28-06-2022-15-32_high.csv']

# %%
ea=[]
for i in range(1, 14):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# initial-24-06-2022-23-47_0.tar.gz
# initial-24-06-2022-23-47_1.tar.gz
# initial-24-06-2022-23-47_10.tar.gz
# initial-24-06-2022-23-47_11.tar.gz
# initial-24-06-2022-23-47_12.tar.gz
# initial-24-06-2022-23-47_2.tar.gz
# initial-24-06-2022-23-47_3.tar.gz
# initial-24-06-2022-23-47_4.tar.gz
# initial-24-06-2022-23-47_5.tar.gz
# initial-24-06-2022-23-47_6.tar.gz
# initial-24-06-2022-23-47_7.tar.gz
# initial-24-06-2022-23-47_8.tar.gz
# initial-24-06-2022-23-47_9.tar.gz
#      utility  reliability       Algorithms
# 0  -2.568756    -9.306250  Epsilon-NSGA-II
# 1  -2.418755    -9.331250  Epsilon-NSGA-II
# 2  -3.806257    -9.200000  Epsilon-NSGA-II
# 3  -3.956258    -9.037500  Epsilon-NSGA-II
# 4  -3.212507    -9.206250  Epsilon-NSGA-II
# 5  -2.025005    -9.337500  Epsilon-NSGA-II
# 6  -1.431253    -9.531250  Epsilon-NSGA-II
# 7  -3.062506    -9.231250  Epsilon-NSGA-II
# 8  -1.581254    -9.437500  Epsilon-NSGA-II
# 9  -1.087502    -9.700000  Epsilon-NSGA-II
# 10 -1.237503    -9.606250  Epsilon-NSGA-II
# 11 -0.556260    -9.756251  Epsilon-NSGA-II
# 12 -1.875004    -9.431250  Epsilon-NSGA-II

# %%
path = files[55]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes_initial-27-06-2022-18-52_high.csv
#      utility  reliability Algorithms
# 0  -0.844870    -9.557951     MO-NES
# 1  -1.446330    -9.363422     MO-NES
# 2  -4.020934    -8.956702     MO-NES
# 3  -3.979565    -8.961309     MO-NES
# 4  -2.004413    -9.265149     MO-NES
# ..       ...          ...        ...
# 86 -2.279717    -9.204049     MO-NES
# 87 -4.025008    -8.956249     MO-NES
# 88 -2.513980    -9.159549     MO-NES
# 89 -0.681538    -9.602111     MO-NES
# 90 -1.029026    -9.464563     MO-NES
#
# [91 rows x 3 columns]

# %%
path = files[58]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep_initial-27-06-2022-18-56_best.csv
#       utility  reliability Algorithms
# 0   -0.633870    -9.636660   MO-eREPS
# 1   -0.636610    -9.634247   MO-eREPS
# 2   -1.460754    -9.359813   MO-eREPS
# 3   -3.288026    -9.050111   MO-eREPS
# 4   -1.782504    -9.296343   MO-eREPS
# ..        ...          ...        ...
# 503 -2.647489    -9.155648   MO-eREPS
# 504 -3.985827    -8.960678   MO-eREPS
# 505 -2.633228    -9.158698   MO-eREPS
# 506 -0.662414    -9.615672   MO-eREPS
# 507 -2.623645    -9.160748   MO-eREPS
#
# [508 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(14, 54):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 0:04:06
# Out:
# initial_avg-24-06-2022-23-50_0.tar.gz
# initial_avg-24-06-2022-23-50_1.tar.gz
# initial_avg-24-06-2022-23-50_10.tar.gz
# initial_avg-24-06-2022-23-50_11.tar.gz
# initial_avg-24-06-2022-23-50_12.tar.gz
# initial_avg-24-06-2022-23-50_13.tar.gz
# initial_avg-24-06-2022-23-50_14.tar.gz
# initial_avg-24-06-2022-23-50_15.tar.gz
# initial_avg-24-06-2022-23-50_16.tar.gz
# initial_avg-24-06-2022-23-50_17.tar.gz
# initial_avg-24-06-2022-23-50_18.tar.gz
# initial_avg-24-06-2022-23-50_19.tar.gz
# initial_avg-24-06-2022-23-50_2.tar.gz
# initial_avg-24-06-2022-23-50_20.tar.gz
# initial_avg-24-06-2022-23-50_21.tar.gz
# initial_avg-24-06-2022-23-50_22.tar.gz
# initial_avg-24-06-2022-23-50_23.tar.gz
# initial_avg-24-06-2022-23-50_24.tar.gz
# initial_avg-24-06-2022-23-50_25.tar.gz
# initial_avg-24-06-2022-23-50_26.tar.gz
# initial_avg-24-06-2022-23-50_27.tar.gz
# initial_avg-24-06-2022-23-50_28.tar.gz
# initial_avg-24-06-2022-23-50_29.tar.gz
# initial_avg-24-06-2022-23-50_3.tar.gz
# initial_avg-24-06-2022-23-50_30.tar.gz
# initial_avg-24-06-2022-23-50_31.tar.gz
# initial_avg-24-06-2022-23-50_32.tar.gz
# initial_avg-24-06-2022-23-50_33.tar.gz
# initial_avg-24-06-2022-23-50_34.tar.gz
# initial_avg-24-06-2022-23-50_35.tar.gz
# initial_avg-24-06-2022-23-50_36.tar.gz
# initial_avg-24-06-2022-23-50_37.tar.gz
# initial_avg-24-06-2022-23-50_38.tar.gz
# initial_avg-24-06-2022-23-50_39.tar.gz
# initial_avg-24-06-2022-23-50_4.tar.gz
# initial_avg-24-06-2022-23-50_5.tar.gz
# initial_avg-24-06-2022-23-50_6.tar.gz
# initial_avg-24-06-2022-23-50_7.tar.gz
# initial_avg-24-06-2022-23-50_8.tar.gz
# initial_avg-24-06-2022-23-50_9.tar.gz
#      utility  reliability           Algorithms
# 0  -0.631263    -9.687495  Epsilon-NSGA-II_avg
# 1  -0.743768    -9.631246  Epsilon-NSGA-II_avg
# 2  -2.987515    -9.099998  Epsilon-NSGA-II_avg
# 3  -2.637506    -9.156249  Epsilon-NSGA-II_avg
# 4  -1.375033    -9.399994  Epsilon-NSGA-II_avg
# 5  -0.587513    -9.699996  Epsilon-NSGA-II_avg
# 6  -3.281257    -9.056249  Epsilon-NSGA-II_avg
# 7  -0.968773    -9.549995  Epsilon-NSGA-II_avg
# 8  -0.837521    -9.593746  Epsilon-NSGA-II_avg
# 9  -0.787517    -9.618744  Epsilon-NSGA-II_avg
# 10 -1.150027    -9.481245  Epsilon-NSGA-II_avg
# 11 -0.662515    -9.674997  Epsilon-NSGA-II_avg
# 12 -0.687517    -9.643745  Epsilon-NSGA-II_avg
# 13 -1.043774    -9.524996  Epsilon-NSGA-II_avg
# 14 -1.350030    -9.431246  Epsilon-NSGA-II_avg
# 15 -1.750036    -9.331246  Epsilon-NSGA-II_avg
# 16 -0.562511    -9.731248  Epsilon-NSGA-II_avg
# 17 -0.818769    -9.606247  Epsilon-NSGA-II_avg
# 18 -1.550033    -9.381245  Epsilon-NSGA-II_avg
# 19 -1.218778    -9.468745  Epsilon-NSGA-II_avg
# 20 -1.775038    -9.299994  Epsilon-NSGA-II_avg
# 21 -1.275029    -9.456245  Epsilon-NSGA-II_avg
# 22 -0.556260    -9.750000  Epsilon-NSGA-II_avg
# 23 -1.650004    -9.356249  Epsilon-NSGA-II_avg
# 24 -3.687517    -8.999998  Epsilon-NSGA-II_avg
# 25 -2.243770    -9.224997  Epsilon-NSGA-II_avg
# 26 -1.318778    -9.443744  Epsilon-NSGA-II_avg
# 27 -1.012522    -9.537494  Epsilon-NSGA-II_avg
# 28 -2.818774    -9.124997  Epsilon-NSGA-II_avg
# 29 -2.312534    -9.206245  Epsilon-NSGA-II_avg
# 30 -1.618783    -9.368745  Epsilon-NSGA-II_avg
# 31 -1.718784    -9.343744  Epsilon-NSGA-II_avg
# 32 -4.025008    -8.956249  Epsilon-NSGA-II_avg
# 33 -1.768787    -9.318746  Epsilon-NSGA-II_avg
# 34 -0.843772    -9.574995  Epsilon-NSGA-II_avg
# 35 -2.387513    -9.199998  Epsilon-NSGA-II_avg
# 36 -2.093755    -9.256249  Epsilon-NSGA-II_avg
# 37 -1.368782    -9.418746  Epsilon-NSGA-II_avg
# 38 -0.912522    -9.562495  Epsilon-NSGA-II_avg
# 39 -1.068777    -9.493744  Epsilon-NSGA-II_avg

# %%
path = files[56]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:00:15
# Out:
# nes_initial_avg-28-06-2022-15-36_best.csv
#        utility  reliability  Algorithms
# 0    -2.230084    -9.205445  MO-NES_avg
# 1    -3.708935    -8.992903  MO-NES_avg
# 2    -3.274180    -9.048072  MO-NES_avg
# 3    -2.446934    -9.170445  MO-NES_avg
# 4    -1.363471    -9.373445  MO-NES_avg
# ...        ...          ...         ...
# 1009 -2.546911    -9.154845  MO-NES_avg
# 1010 -3.252492    -9.050936  MO-NES_avg
# 1011 -3.193210    -9.058872  MO-NES_avg
# 1012 -4.025008    -8.956249  MO-NES_avg
# 1013 -0.743758    -9.725853  MO-NES_avg
#
# [1014 rows x 3 columns]

# %%
path = files[60]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:00:15
# Out:
# repsep_initial_avg-28-06-2022-15-28_best.csv
#        utility  reliability    Algorithms
# 0    -1.322455    -9.383994  MO-eREPS_avg
# 1    -0.910312    -9.494744  MO-eREPS_avg
# 2    -2.137151    -9.220244  MO-eREPS_avg
# 3    -4.005900    -8.958497  MO-eREPS_avg
# 4    -0.815719    -9.531726  MO-eREPS_avg
# ...        ...          ...           ...
# 1152 -0.865629    -9.511244  MO-eREPS_avg
# 1153 -0.822510    -9.528244  MO-eREPS_avg
# 1154 -3.109330    -9.070187  MO-eREPS_avg
# 1155 -0.569550    -9.711049  MO-eREPS_avg
# 1156 -4.025008    -8.956249  MO-eREPS_avg
#
# [1157 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.4974640560262284

# %%
compute_hypervolume(ea_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5565699334135664

# %%
compute_hypervolume(repsep_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5729951795693837

# %%
compute_hypervolume(nes_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5520730057209008

# %% [markdown]
# # Robust Dam Problem (deep)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_deep_performance/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['ea-03-07-2022-23-07_0.tar.gz',
#  'ea-03-07-2022-23-07_1.tar.gz',
#  'ea-03-07-2022-23-07_10.tar.gz',
#  'ea-03-07-2022-23-07_11.tar.gz',
#  'ea-03-07-2022-23-07_12.tar.gz',
#  'ea-03-07-2022-23-07_13.tar.gz',
#  'ea-03-07-2022-23-07_14.tar.gz',
#  'ea-03-07-2022-23-07_15.tar.gz',
#  'ea-03-07-2022-23-07_16.tar.gz',
#  'ea-03-07-2022-23-07_17.tar.gz',
#  'ea-03-07-2022-23-07_18.tar.gz',
#  'ea-03-07-2022-23-07_2.tar.gz',
#  'ea-03-07-2022-23-07_3.tar.gz',
#  'ea-03-07-2022-23-07_4.tar.gz',
#  'ea-03-07-2022-23-07_5.tar.gz',
#  'ea-03-07-2022-23-07_6.tar.gz',
#  'ea-03-07-2022-23-07_7.tar.gz',
#  'ea-03-07-2022-23-07_8.tar.gz',
#  'ea-03-07-2022-23-07_9.tar.gz',
#  'ea_avg-07-07-2022-16-13_0.tar.gz',
#  'ea_avg-07-07-2022-16-13_1.tar.gz',
#  'ea_avg-07-07-2022-16-13_10.tar.gz',
#  'ea_avg-07-07-2022-16-13_11.tar.gz',
#  'ea_avg-07-07-2022-16-13_12.tar.gz',
#  'ea_avg-07-07-2022-16-13_13.tar.gz',
#  'ea_avg-07-07-2022-16-13_14.tar.gz',
#  'ea_avg-07-07-2022-16-13_15.tar.gz',
#  'ea_avg-07-07-2022-16-13_16.tar.gz',
#  'ea_avg-07-07-2022-16-13_17.tar.gz',
#  'ea_avg-07-07-2022-16-13_18.tar.gz',
#  'ea_avg-07-07-2022-16-13_19.tar.gz',
#  'ea_avg-07-07-2022-16-13_2.tar.gz',
#  'ea_avg-07-07-2022-16-13_20.tar.gz',
#  'ea_avg-07-07-2022-16-13_3.tar.gz',
#  'ea_avg-07-07-2022-16-13_4.tar.gz',
#  'ea_avg-07-07-2022-16-13_5.tar.gz',
#  'ea_avg-07-07-2022-16-13_6.tar.gz',
#  'ea_avg-07-07-2022-16-13_7.tar.gz',
#  'ea_avg-07-07-2022-16-13_8.tar.gz',
#  'ea_avg-07-07-2022-16-13_9.tar.gz',
#  'ea_mv-07-07-2022-16-12_0.tar.gz',
#  'ea_mv-07-07-2022-16-12_1.tar.gz',
#  'ea_mv-07-07-2022-16-12_10.tar.gz',
#  'ea_mv-07-07-2022-16-12_11.tar.gz',
#  'ea_mv-07-07-2022-16-12_12.tar.gz',
#  'ea_mv-07-07-2022-16-12_2.tar.gz',
#  'ea_mv-07-07-2022-16-12_3.tar.gz',
#  'ea_mv-07-07-2022-16-12_4.tar.gz',
#  'ea_mv-07-07-2022-16-12_5.tar.gz',
#  'ea_mv-07-07-2022-16-12_6.tar.gz',
#  'ea_mv-07-07-2022-16-12_7.tar.gz',
#  'ea_mv-07-07-2022-16-12_8.tar.gz',
#  'ea_mv-07-07-2022-16-12_9.tar.gz',
#  'nes_10th-07-07-2022-18-32_best.csv',
#  'nes_10th-07-07-2022-18-34_high.csv',
#  'nes_avg-07-07-2022-18-44_best.csv',
#  'nes_avg-07-07-2022-18-46_high.csv',
#  'nes_mv-07-07-2022-18-53_best.csv',
#  'nes_mv-07-07-2022-18-55_high.csv',
#  'repsep_10th-07-07-2022-18-39_best.csv',
#  'repsep_10th-07-07-2022-18-42_high.csv',
#  'repsep_avg-07-07-2022-18-48_best.csv',
#  'repsep_avg-07-07-2022-18-50_high.csv',
#  'repsep_mv-07-07-2022-18-57_best.csv',
#  'repsep_mv-07-07-2022-18-59_high.csv']

# %%
ea=[]
for i in range(1, 27):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# 2:44:18
# Out:
# ea-03-07-2022-23-07_0.tar.gz
# ea-03-07-2022-23-07_1.tar.gz
# ea-03-07-2022-23-07_10.tar.gz
# ea-03-07-2022-23-07_11.tar.gz
# ea-03-07-2022-23-07_12.tar.gz
# ea-03-07-2022-23-07_13.tar.gz
# ea-03-07-2022-23-07_14.tar.gz
# ea-03-07-2022-23-07_15.tar.gz
# ea-03-07-2022-23-07_16.tar.gz
# ea-03-07-2022-23-07_17.tar.gz
# ea-03-07-2022-23-07_18.tar.gz
# ea-03-07-2022-23-07_2.tar.gz
# ea-03-07-2022-23-07_3.tar.gz
# ea-03-07-2022-23-07_4.tar.gz
# ea-03-07-2022-23-07_5.tar.gz
# ea-03-07-2022-23-07_6.tar.gz
# ea-03-07-2022-23-07_7.tar.gz
# ea-03-07-2022-23-07_8.tar.gz
# ea-03-07-2022-23-07_9.tar.gz
#      utility  reliability            Algorithms
# 0  -4.123178    -9.859570  Epsilon-NSGA-II_10th
# 1  -2.023316   -10.187897  Epsilon-NSGA-II_10th
# 2  -1.601292   -10.254641  Epsilon-NSGA-II_10th
# 3  -1.612125   -10.253102  Epsilon-NSGA-II_10th
# 4  -1.574030   -10.285054  Epsilon-NSGA-II_10th
# 5  -1.545219   -10.300021  Epsilon-NSGA-II_10th
# 6  -1.591842   -10.295241  Epsilon-NSGA-II_10th
# 7  -1.554494   -10.306490  Epsilon-NSGA-II_10th
# 8  -1.595929   -10.307509  Epsilon-NSGA-II_10th
# 9  -1.541590   -10.258794  Epsilon-NSGA-II_10th
# 10 -1.598547   -10.258728  Epsilon-NSGA-II_10th
# 11 -1.990663   -10.228057  Epsilon-NSGA-II_10th
# 12 -2.129649   -10.233864  Epsilon-NSGA-II_10th
# 13 -2.309845   -10.086815  Epsilon-NSGA-II_10th
# 14 -2.861517   -10.127664  Epsilon-NSGA-II_10th
# 15 -3.891330    -9.845421  Epsilon-NSGA-II_10th
# 16 -1.619944   -10.236427  Epsilon-NSGA-II_10th
# 17 -4.101838    -9.902284  Epsilon-NSGA-II_10th
# 18 -1.604972   -10.255089  Epsilon-NSGA-II_10th

# %%
path = files[70]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes_10th-07-07-2022-18-32_best.csv
#      utility  reliability   Algorithms
# 0  -2.785807    -9.352002  MO-NES_10th
# 1  -1.728847   -10.062776  MO-NES_10th
# 2  -2.900486    -9.337186  MO-NES_10th
# 3  -2.134823    -9.593536  MO-NES_10th
# 4  -2.213135    -9.523286  MO-NES_10th
# ..       ...          ...          ...
# 95 -2.916843    -9.315779  MO-NES_10th
# 96 -1.945128    -9.735875  MO-NES_10th
# 97 -1.975267    -9.672326  MO-NES_10th
# 98 -5.246278    -8.932216  MO-NES_10th
# 99 -1.808601    -9.913198  MO-NES_10th
#
# [100 rows x 3 columns]

# %%
path = files[75]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep_10th-07-07-2022-18-39_best.csv
#       utility  reliability     Algorithms
# 0   -4.074738    -9.093851  MO-eREPS_10th
# 1   -5.574775    -8.916498  MO-eREPS_10th
# 2   -2.544987    -9.407554  MO-eREPS_10th
# 3   -2.131022    -9.558267  MO-eREPS_10th
# 4   -2.244904    -9.515162  MO-eREPS_10th
# ..        ...          ...            ...
# 97  -2.212840    -9.537181  MO-eREPS_10th
# 98  -3.320842    -9.227753  MO-eREPS_10th
# 99  -3.865981    -9.149351  MO-eREPS_10th
# 100 -1.904214    -9.766676  MO-eREPS_10th
# 101 -1.550105   -10.581760  MO-eREPS_10th
#
# [102 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(27, 70):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 2:49:00
# Out:
# ea_avg-07-07-2022-16-13_0.tar.gz
# ea_avg-07-07-2022-16-13_1.tar.gz
# ea_avg-07-07-2022-16-13_10.tar.gz
# ea_avg-07-07-2022-16-13_11.tar.gz
# ea_avg-07-07-2022-16-13_12.tar.gz
# ea_avg-07-07-2022-16-13_13.tar.gz
# ea_avg-07-07-2022-16-13_14.tar.gz
# ea_avg-07-07-2022-16-13_15.tar.gz
# ea_avg-07-07-2022-16-13_16.tar.gz
# ea_avg-07-07-2022-16-13_17.tar.gz
# ea_avg-07-07-2022-16-13_18.tar.gz
# ea_avg-07-07-2022-16-13_19.tar.gz
# ea_avg-07-07-2022-16-13_2.tar.gz
# ea_avg-07-07-2022-16-13_20.tar.gz
# ea_avg-07-07-2022-16-13_3.tar.gz
# ea_avg-07-07-2022-16-13_4.tar.gz
# ea_avg-07-07-2022-16-13_5.tar.gz
# ea_avg-07-07-2022-16-13_6.tar.gz
# ea_avg-07-07-2022-16-13_7.tar.gz
# ea_avg-07-07-2022-16-13_8.tar.gz
# ea_avg-07-07-2022-16-13_9.tar.gz
#      utility  reliability           Algorithms
# 0  -2.617066    -9.905291  Epsilon-NSGA-II_avg
# 1  -1.679040   -10.152657  Epsilon-NSGA-II_avg
# 2  -1.640712   -10.165954  Epsilon-NSGA-II_avg
# 3  -1.559080   -10.260819  Epsilon-NSGA-II_avg
# 4  -1.560298   -10.268724  Epsilon-NSGA-II_avg
# 5  -2.545020    -9.959531  Epsilon-NSGA-II_avg
# 6  -1.557027   -10.267449  Epsilon-NSGA-II_avg
# 7  -2.526007    -9.947690  Epsilon-NSGA-II_avg
# 8  -1.678396   -10.178298  Epsilon-NSGA-II_avg
# 9  -1.567158   -10.258137  Epsilon-NSGA-II_avg
# 10 -2.553002    -9.925124  Epsilon-NSGA-II_avg
# 11 -2.565143    -9.864312  Epsilon-NSGA-II_avg
# 12 -1.571166   -10.283960  Epsilon-NSGA-II_avg
# 13 -1.548988   -10.242984  Epsilon-NSGA-II_avg
# 14 -1.539631   -10.307077  Epsilon-NSGA-II_avg
# 15 -2.546546    -9.915947  Epsilon-NSGA-II_avg
# 16 -1.548270   -10.308210  Epsilon-NSGA-II_avg
# 17 -2.645222    -9.916426  Epsilon-NSGA-II_avg
# 18 -1.684684   -10.140709  Epsilon-NSGA-II_avg
# 19 -1.624278   -10.218486  Epsilon-NSGA-II_avg
# 20 -1.590393   -10.199487  Epsilon-NSGA-II_avg

# %%
path = files[73]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:03:17
# Out:
# nes_avg-07-07-2022-18-46_high.csv
#      utility  reliability  Algorithms
# 0  -2.946307    -9.310715  MO-NES_avg
# 1  -1.514193   -10.167971  MO-NES_avg
# 2  -1.615278    -9.977287  MO-NES_avg
# 3  -3.305606    -9.248597  MO-NES_avg
# 4  -1.519244   -10.159862  MO-NES_avg
# ..       ...          ...         ...
# 93 -4.487752    -9.053943  MO-NES_avg
# 94 -1.422066   -10.400445  MO-NES_avg
# 95 -1.983685    -9.588905  MO-NES_avg
# 96 -1.394188   -10.481376  MO-NES_avg
# 97 -1.929638    -9.606478  MO-NES_avg
#
# [98 rows x 3 columns]

# %%
path = files[76]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:02:30
# Out:
# repsep_avg-07-07-2022-18-48_best.csv
#       utility  reliability    Algorithms
# 0   -2.492773    -9.423879  MO-eREPS_avg
# 1   -2.190586    -9.493789  MO-eREPS_avg
# 2   -1.551486   -10.095757  MO-eREPS_avg
# 3   -4.619956    -9.032908  MO-eREPS_avg
# 4   -1.945729    -9.617935  MO-eREPS_avg
# ..        ...          ...           ...
# 97  -5.234161    -8.951001  MO-eREPS_avg
# 98  -1.378158   -10.545623  MO-eREPS_avg
# 99  -1.815144    -9.703179  MO-eREPS_avg
# 100 -1.774337    -9.753127  MO-eREPS_avg
# 101 -1.434601   -10.380852  MO-eREPS_avg
#
# [102 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()
