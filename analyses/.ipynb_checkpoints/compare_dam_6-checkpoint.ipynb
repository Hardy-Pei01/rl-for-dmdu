# %%
import os, sys
sys.path.append(os.path.abspath('../'))
from utils.rl.hv import HyperVolume

def compute_hypervolume(df, antiutopia, utopia):
    array = df.drop('Algorithms', axis=1)
    array = array.values
    hv_computer = HyperVolume(antiutopia, utopia)
    return hv_computer.compute(array)

# %% [markdown]
# # Robust Dam Problem (random initial state)

# %%
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_robust_performance_5/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-03-07-2022-19-38_0.tar.gz',
#  'ea-03-07-2022-19-38_1.tar.gz',
#  'ea-03-07-2022-19-38_10.tar.gz',
#  'ea-03-07-2022-19-38_11.tar.gz',
#  'ea-03-07-2022-19-38_12.tar.gz',
#  'ea-03-07-2022-19-38_2.tar.gz',
#  'ea-03-07-2022-19-38_3.tar.gz',
#  'ea-03-07-2022-19-38_4.tar.gz',
#  'ea-03-07-2022-19-38_5.tar.gz',
#  'ea-03-07-2022-19-38_6.tar.gz',
#  'ea-03-07-2022-19-38_7.tar.gz',
#  'ea-03-07-2022-19-38_8.tar.gz',
#  'ea-03-07-2022-19-38_9.tar.gz',
#  'ea_avg-06-07-2022-15-58_0.tar.gz',
#  'ea_avg-06-07-2022-15-58_1.tar.gz',
#  'ea_avg-06-07-2022-15-58_10.tar.gz',
#  'ea_avg-06-07-2022-15-58_11.tar.gz',
#  'ea_avg-06-07-2022-15-58_12.tar.gz',
#  'ea_avg-06-07-2022-15-58_13.tar.gz',
#  'ea_avg-06-07-2022-15-58_14.tar.gz',
#  'ea_avg-06-07-2022-15-58_15.tar.gz',
#  'ea_avg-06-07-2022-15-58_16.tar.gz',
#  'ea_avg-06-07-2022-15-58_17.tar.gz',
#  'ea_avg-06-07-2022-15-58_18.tar.gz',
#  'ea_avg-06-07-2022-15-58_19.tar.gz',
#  'ea_avg-06-07-2022-15-58_2.tar.gz',
# ...

# %%
ea=[]
for i in range(1, 14):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II_10th"
ea
# Out:
# ea-03-07-2022-19-38_0.tar.gz
# ea-03-07-2022-19-38_1.tar.gz
# ea-03-07-2022-19-38_10.tar.gz
# ea-03-07-2022-19-38_11.tar.gz
# ea-03-07-2022-19-38_12.tar.gz
# ea-03-07-2022-19-38_2.tar.gz
# ea-03-07-2022-19-38_3.tar.gz
# ea-03-07-2022-19-38_4.tar.gz
# ea-03-07-2022-19-38_5.tar.gz
# ea-03-07-2022-19-38_6.tar.gz
# ea-03-07-2022-19-38_7.tar.gz
# ea-03-07-2022-19-38_8.tar.gz
# ea-03-07-2022-19-38_9.tar.gz
#      utility  reliability            Algorithms
# 0  -1.875008    -9.431250  Epsilon-NSGA-II_10th
# 1  -1.581259    -9.437501  Epsilon-NSGA-II_10th
# 2  -3.956267    -9.106251  Epsilon-NSGA-II_10th
# 3  -2.568763    -9.306251  Epsilon-NSGA-II_10th
# 4  -3.062512    -9.231250  Epsilon-NSGA-II_10th
# 5  -1.431256    -9.600000  Epsilon-NSGA-II_10th
# 6  -1.087504    -9.700000  Epsilon-NSGA-II_10th
# 7  -1.237507    -9.606251  Epsilon-NSGA-II_10th
# 8  -3.212515    -9.206251  Epsilon-NSGA-II_10th
# 9  -2.025011    -9.337501  Epsilon-NSGA-II_10th
# ...

# %%
path = files[64]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES_10th"
print(path)
nes
# Out:
# nes_10th-08-07-2022-18-45_best.csv
#       utility  reliability   Algorithms
# 0   -3.988277    -8.960330  MO-NES_10th
# 1   -3.764262    -8.986248  MO-NES_10th
# 2   -0.624194    -9.644786  MO-NES_10th
# 3   -2.495998    -9.163248  MO-NES_10th
# 4   -3.142409    -9.070097  MO-NES_10th
# ..        ...          ...          ...
# 494 -2.735620    -9.124959  MO-NES_10th
# 495 -3.618316    -9.004648  MO-NES_10th
# 496 -3.002078    -9.086848  MO-NES_10th
# 497 -3.636588    -9.002248  MO-NES_10th
# 498 -2.385012    -9.182848  MO-NES_10th
#
# [499 rows x 3 columns]

# %%
path = files[70]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS_10th"
print(path)
repsep
# Out:
# repsep_10th-08-07-2022-18-41_best.csv
#       utility  reliability     Algorithms
# 0   -3.245202    -9.055438  MO-eREPS_10th
# 1   -3.343478    -9.041248  MO-eREPS_10th
# 2   -0.557793    -9.734954  MO-eREPS_10th
# 3   -3.346234    -9.041048  MO-eREPS_10th
# 4   -3.997761    -8.959276  MO-eREPS_10th
# ..        ...          ...            ...
# 173 -3.309994    -9.045861  MO-eREPS_10th
# 174 -4.025017    -8.956248  MO-eREPS_10th
# 175 -0.598739    -9.671106  MO-eREPS_10th
# 176 -4.016711    -8.957171  MO-eREPS_10th
# 177 -1.726905    -9.307437  MO-eREPS_10th
#
# [178 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.493311070313117

# %%
compute_hypervolume(nes, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5718028697659049

# %%
compute_hypervolume(repsep, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5701631762519294

# %%
ea_avg=[]
for i in range(14, 54):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 0:04:06
# Out:
# ea_avg-06-07-2022-15-58_0.tar.gz
# ea_avg-06-07-2022-15-58_1.tar.gz
# ea_avg-06-07-2022-15-58_10.tar.gz
# ea_avg-06-07-2022-15-58_11.tar.gz
# ea_avg-06-07-2022-15-58_12.tar.gz
# ea_avg-06-07-2022-15-58_13.tar.gz
# ea_avg-06-07-2022-15-58_14.tar.gz
# ea_avg-06-07-2022-15-58_15.tar.gz
# ea_avg-06-07-2022-15-58_16.tar.gz
# ea_avg-06-07-2022-15-58_17.tar.gz
# ea_avg-06-07-2022-15-58_18.tar.gz
# ea_avg-06-07-2022-15-58_19.tar.gz
# ea_avg-06-07-2022-15-58_2.tar.gz
# ea_avg-06-07-2022-15-58_20.tar.gz
# ea_avg-06-07-2022-15-58_21.tar.gz
# ea_avg-06-07-2022-15-58_22.tar.gz
# ea_avg-06-07-2022-15-58_23.tar.gz
# ea_avg-06-07-2022-15-58_24.tar.gz
# ea_avg-06-07-2022-15-58_25.tar.gz
# ea_avg-06-07-2022-15-58_26.tar.gz
# ea_avg-06-07-2022-15-58_27.tar.gz
# ea_avg-06-07-2022-15-58_28.tar.gz
# ea_avg-06-07-2022-15-58_29.tar.gz
# ea_avg-06-07-2022-15-58_3.tar.gz
# ea_avg-06-07-2022-15-58_30.tar.gz
# ea_avg-06-07-2022-15-58_31.tar.gz
# ea_avg-06-07-2022-15-58_32.tar.gz
# ...

# %%
path = files[66]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:00:15
# Out:
# nes_avg-08-07-2022-19-05_best.csv
#       utility  reliability  Algorithms
# 0   -3.221478    -9.055053  MO-NES_avg
# 1   -1.106018    -9.449050  MO-NES_avg
# 2   -3.589970    -9.007519  MO-NES_avg
# 3   -2.996506    -9.086250  MO-NES_avg
# 4   -3.919390    -8.968082  MO-NES_avg
# ..        ...          ...         ...
# 665 -4.025017    -8.956248  MO-NES_avg
# 666 -1.056238    -9.469450  MO-NES_avg
# 667 -1.115669    -9.445450  MO-NES_avg
# 668 -1.521991    -9.337850  MO-NES_avg
# 669 -1.900322    -9.263050  MO-NES_avg
#
# [670 rows x 3 columns]

# %%
path = files[72]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:00:15
# Out:
# repsep_avg-08-07-2022-18-58_best.csv
#       utility  reliability    Algorithms
# 0   -1.889475    -9.265050  MO-eREPS_avg
# 1   -3.771123    -8.985411  MO-eREPS_avg
# 2   -0.665138    -9.612939  MO-eREPS_avg
# 3   -1.999719    -9.245050  MO-eREPS_avg
# 4   -3.915756    -8.968499  MO-eREPS_avg
# ..        ...          ...           ...
# 661 -2.208008    -9.207579  MO-eREPS_avg
# 662 -0.573381    -9.704184  MO-eREPS_avg
# 663 -3.826179    -8.978909  MO-eREPS_avg
# 664 -4.025017    -8.956248  MO-eREPS_avg
# 665 -3.021476    -9.082650  MO-eREPS_avg
#
# [666 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5564507857822536

# %%
compute_hypervolume(nes_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5508680737984525

# %%
compute_hypervolume(repsep_avg, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5731592058070281

# %%
ea_mv=[]
for i in range(54, 64):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_mv.append(all_outcomes)
    print(files[i])
ea_mv=pd.DataFrame(ea_mv)
ea_mv["Algorithms"]="Epsilon-NSGA-II_mv"
ea_mv
# 0:04:06
# Out:
# ea_mv-03-07-2022-19-39_0.tar.gz
# ea_mv-03-07-2022-19-39_1.tar.gz
# ea_mv-03-07-2022-19-39_2.tar.gz
# ea_mv-03-07-2022-19-39_3.tar.gz
# ea_mv-03-07-2022-19-39_4.tar.gz
# ea_mv-03-07-2022-19-39_5.tar.gz
# ea_mv-03-07-2022-19-39_6.tar.gz
# ea_mv-03-07-2022-19-39_7.tar.gz
# ea_mv-03-07-2022-19-39_8.tar.gz
# ea_mv-03-07-2022-19-39_9.tar.gz
#     utility  reliability          Algorithms
# 0 -1.774972    -9.300002  Epsilon-NSGA-II_mv
# 1 -1.068725    -9.493751  Epsilon-NSGA-II_mv
# 2 -1.374974    -9.400002  Epsilon-NSGA-II_mv
# 3 -0.687483    -9.643754  Epsilon-NSGA-II_mv
# 4 -0.843729    -9.575004  Epsilon-NSGA-II_mv
# 5 -0.662487    -9.675004  Epsilon-NSGA-II_mv
# 6 -0.587489    -9.700005  Epsilon-NSGA-II_mv
# 7 -2.312490    -9.206250  Epsilon-NSGA-II_mv
# 8 -0.562492    -9.731255  Epsilon-NSGA-II_mv
# 9 -0.681235    -9.662502  Epsilon-NSGA-II_mv

# %%
path = files[68]
nes_mv = pd.read_csv(results_path + path)
nes_mv["Algorithms"]="MO-NES_mv"
print(path)
nes_mv
# 0:00:15
# Out:
# nes_mv-08-07-2022-18-54_best.csv
#      utility  reliability Algorithms
# 0  -0.683124    -9.706810  MO-NES_mv
# 1  -0.658672    -9.717552  MO-NES_mv
# 2  -0.565855    -9.734861  MO-NES_mv
# 3  -0.556560    -9.740951  MO-NES_mv
# 4  -0.571299    -9.732505  MO-NES_mv
# ..       ...          ...        ...
# 71 -0.566231    -9.734637  MO-NES_mv
# 72 -0.612644    -9.731047  MO-NES_mv
# 73 -0.683870    -9.706452  MO-NES_mv
# 74 -0.649444    -9.721922  MO-NES_mv
# 75 -0.582044    -9.731250  MO-NES_mv
#
# [76 rows x 3 columns]

# %%
path = files[74]
repsep_mv = pd.read_csv(results_path + path)
repsep_mv["Algorithms"]="MO-eREPS_mv"
print(path)
repsep_mv
# 0:00:15
# Out:
# repsep_mv-08-07-2022-18-50_best.csv
#      utility  reliability   Algorithms
# 0  -1.028551    -9.582440  MO-eREPS_mv
# 1  -0.930362    -9.602867  MO-eREPS_mv
# 2  -0.746243    -9.714603  MO-eREPS_mv
# 3  -2.341376    -9.328648  MO-eREPS_mv
# 4  -0.743748    -9.728827  MO-eREPS_mv
# 5  -1.092708    -9.562496  MO-eREPS_mv
# 6  -0.763805    -9.710202  MO-eREPS_mv
# 7  -1.090926    -9.563018  MO-eREPS_mv
# 8  -1.584346    -9.486602  MO-eREPS_mv
# 9  -4.024050    -9.045033  MO-eREPS_mv
# 10 -2.588279    -9.275848  MO-eREPS_mv
# 11 -0.975791    -9.589425  MO-eREPS_mv
# 12 -0.793150    -9.663099  MO-eREPS_mv
# 13 -3.920365    -9.063550  MO-eREPS_mv
# 14 -1.347165    -9.512233  MO-eREPS_mv
# 15 -3.669360    -9.274800  MO-eREPS_mv
# 16 -1.062457    -9.568687  MO-eREPS_mv
# 17 -0.845979    -9.610189  MO-eREPS_mv
# 18 -4.025017    -8.956248  MO-eREPS_mv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_mv, nes_mv, repsep_mv])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_mv, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.5183434153202073

# %%
compute_hypervolume(nes_mv, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.3743754801556977

# %%
compute_hypervolume(repsep_mv, np.array([-4.5, -10.5]), np.array([0, -8.5]))
# Out:
# 0.4833378108914583

# %% [markdown]
# # Robust Dam Problem (deep)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_deep_performance_3/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-03-07-2022-23-07_0.tar.gz',
#  'ea-03-07-2022-23-07_1.tar.gz',
#  'ea-03-07-2022-23-07_10.tar.gz',
#  'ea-03-07-2022-23-07_11.tar.gz',
#  'ea-03-07-2022-23-07_12.tar.gz',
#  'ea-03-07-2022-23-07_13.tar.gz',
#  'ea-03-07-2022-23-07_14.tar.gz',
#  'ea-03-07-2022-23-07_15.tar.gz',
#  'ea-03-07-2022-23-07_16.tar.gz',
#  'ea-03-07-2022-23-07_17.tar.gz',
#  'ea-03-07-2022-23-07_18.tar.gz',
#  'ea-03-07-2022-23-07_2.tar.gz',
#  'ea-03-07-2022-23-07_3.tar.gz',
#  'ea-03-07-2022-23-07_4.tar.gz',
#  'ea-03-07-2022-23-07_5.tar.gz',
#  'ea-03-07-2022-23-07_6.tar.gz',
#  'ea-03-07-2022-23-07_7.tar.gz',
#  'ea-03-07-2022-23-07_8.tar.gz',
#  'ea-03-07-2022-23-07_9.tar.gz',
#  'ea_avg-07-07-2022-16-13_0.tar.gz',
#  'ea_avg-07-07-2022-16-13_1.tar.gz',
#  'ea_avg-07-07-2022-16-13_10.tar.gz',
#  'ea_avg-07-07-2022-16-13_11.tar.gz',
#  'ea_avg-07-07-2022-16-13_12.tar.gz',
#  'ea_avg-07-07-2022-16-13_13.tar.gz',
#  'ea_avg-07-07-2022-16-13_14.tar.gz',
# ...

# %%
ea=[]
for i in range(1, 20):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II_10th"
ea
# 2:44:18
# Out:
# ea-03-07-2022-23-07_0.tar.gz
# ea-03-07-2022-23-07_1.tar.gz
# ea-03-07-2022-23-07_10.tar.gz
# ea-03-07-2022-23-07_11.tar.gz
# ea-03-07-2022-23-07_12.tar.gz
# ea-03-07-2022-23-07_13.tar.gz
# ea-03-07-2022-23-07_14.tar.gz
# ea-03-07-2022-23-07_15.tar.gz
# ea-03-07-2022-23-07_16.tar.gz
# ea-03-07-2022-23-07_17.tar.gz
# ea-03-07-2022-23-07_18.tar.gz
# ea-03-07-2022-23-07_2.tar.gz
# ea-03-07-2022-23-07_3.tar.gz
# ea-03-07-2022-23-07_4.tar.gz
# ea-03-07-2022-23-07_5.tar.gz
# ea-03-07-2022-23-07_6.tar.gz
# ea-03-07-2022-23-07_7.tar.gz
# ea-03-07-2022-23-07_8.tar.gz
# ea-03-07-2022-23-07_9.tar.gz
#      utility  reliability            Algorithms
# 0  -4.123178    -9.859570  Epsilon-NSGA-II_10th
# 1  -2.023316   -10.187897  Epsilon-NSGA-II_10th
# 2  -1.601292   -10.254641  Epsilon-NSGA-II_10th
# 3  -1.612125   -10.253102  Epsilon-NSGA-II_10th
# 4  -1.574030   -10.285054  Epsilon-NSGA-II_10th
# 5  -1.545219   -10.300021  Epsilon-NSGA-II_10th
# 6  -1.591842   -10.295241  Epsilon-NSGA-II_10th
# ...

# %%
path = files[54]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES_10th"
print(path)
nes
# Out:
# nes_10th-08-07-2022-21-35_best.csv
#       utility  reliability   Algorithms
# 0   -1.552217   -10.537625  MO-NES_10th
# 1   -2.779428    -9.352802  MO-NES_10th
# 2   -1.727875   -10.061983  MO-NES_10th
# 3   -2.913098    -9.334386  MO-NES_10th
# 4   -2.132391    -9.593985  MO-NES_10th
# ..        ...          ...          ...
# 99  -2.921864    -9.315179  MO-NES_10th
# 100 -1.947180    -9.731779  MO-NES_10th
# 101 -1.977657    -9.668782  MO-NES_10th
# 102 -5.244699    -8.932459  MO-NES_10th
# 103 -1.812218    -9.908559  MO-NES_10th
#
# [104 rows x 3 columns]

# %%
path = files[60]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS_10th"
print(path)
repsep
# Out:
# repsep_10th-08-07-2022-21-39_best.csv
#       utility  reliability     Algorithms
# 0   -4.085039    -9.092251  MO-eREPS_10th
# 1   -5.574775    -8.916498  MO-eREPS_10th
# 2   -2.548640    -9.407654  MO-eREPS_10th
# 3   -2.131039    -9.556044  MO-eREPS_10th
# 4   -2.241750    -9.517362  MO-eREPS_10th
# ..        ...          ...            ...
# 98  -2.217693    -9.533911  MO-eREPS_10th
# 99  -3.303983    -9.229753  MO-eREPS_10th
# 100 -3.856177    -9.150151  MO-eREPS_10th
# 101 -1.905157    -9.762128  MO-eREPS_10th
# 102 -1.550105   -10.581760  MO-eREPS_10th
#
# [103 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.47305410115104135

# %%
compute_hypervolume(nes, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.6598795800309464

# %%
compute_hypervolume(repsep, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.6582427357321992

# %%
ea_avg=[]
for i in range(20, 41):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 2:49:00
# Out:
# ea_avg-07-07-2022-16-13_0.tar.gz
# ea_avg-07-07-2022-16-13_1.tar.gz
# ea_avg-07-07-2022-16-13_10.tar.gz
# ea_avg-07-07-2022-16-13_11.tar.gz
# ea_avg-07-07-2022-16-13_12.tar.gz
# ea_avg-07-07-2022-16-13_13.tar.gz
# ea_avg-07-07-2022-16-13_14.tar.gz
# ea_avg-07-07-2022-16-13_15.tar.gz
# ea_avg-07-07-2022-16-13_16.tar.gz
# ea_avg-07-07-2022-16-13_17.tar.gz
# ea_avg-07-07-2022-16-13_18.tar.gz
# ea_avg-07-07-2022-16-13_19.tar.gz
# ea_avg-07-07-2022-16-13_2.tar.gz
# ea_avg-07-07-2022-16-13_20.tar.gz
# ea_avg-07-07-2022-16-13_3.tar.gz
# ea_avg-07-07-2022-16-13_4.tar.gz
# ea_avg-07-07-2022-16-13_5.tar.gz
# ea_avg-07-07-2022-16-13_6.tar.gz
# ea_avg-07-07-2022-16-13_7.tar.gz
# ea_avg-07-07-2022-16-13_8.tar.gz
# ea_avg-07-07-2022-16-13_9.tar.gz
#      utility  reliability           Algorithms
# 0  -2.617066    -9.905291  Epsilon-NSGA-II_avg
# 1  -1.679040   -10.152657  Epsilon-NSGA-II_avg
# 2  -1.640712   -10.165954  Epsilon-NSGA-II_avg
# 3  -1.559080   -10.260819  Epsilon-NSGA-II_avg
# ...

# %%
path = files[57]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:03:17
# Out:
# nes_avg-08-07-2022-21-48_high.csv
#       utility  reliability  Algorithms
# 0   -2.951932    -9.309215  MO-NES_avg
# 1   -4.164434    -9.100311  MO-NES_avg
# 2   -1.616619    -9.975956  MO-NES_avg
# 3   -3.291604    -9.249797  MO-NES_avg
# 4   -1.513897   -10.157079  MO-NES_avg
# ..        ...          ...         ...
# 97  -1.421519   -10.400568  MO-NES_avg
# 98  -1.974003    -9.592579  MO-NES_avg
# 99  -1.393585   -10.484590  MO-NES_avg
# 100 -4.804436    -9.006793  MO-NES_avg
# 101 -1.932803    -9.604311  MO-NES_avg
#
# [102 rows x 3 columns]

# %%
path = files[62]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:02:30
# Out:
# repsep_avg-08-07-2022-21-51_best.csv
#       utility  reliability    Algorithms
# 0   -2.493052    -9.423479  MO-eREPS_avg
# 1   -2.191200    -9.493289  MO-eREPS_avg
# 2   -1.550775   -10.090029  MO-eREPS_avg
# 3   -1.944443    -9.617254  MO-eREPS_avg
# 4   -1.970129    -9.591172  MO-eREPS_avg
# ..        ...          ...           ...
# 100 -1.376068   -10.555164  MO-eREPS_avg
# 101 -1.816332    -9.701069  MO-eREPS_avg
# 102 -1.777457    -9.750389  MO-eREPS_avg
# 103 -1.433054   -10.381654  MO-eREPS_avg
# 104 -1.917689    -9.632467  MO-eREPS_avg
#
# [105 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_avg, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.48258014761519735

# %%
compute_hypervolume(nes_avg, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.6772223742038228

# %%
compute_hypervolume(repsep_avg, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.677190852236865

# %%
ea_mv=[]
for i in range(41, 54):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_mv.append(all_outcomes)
    print(files[i])
ea_mv=pd.DataFrame(ea_mv)
ea_mv["Algorithms"]="Epsilon-NSGA-II_mv"
ea_mv
# 0:04:06
# Out:
# ea_mv-07-07-2022-16-12_0.tar.gz
# ea_mv-07-07-2022-16-12_1.tar.gz
# ea_mv-07-07-2022-16-12_10.tar.gz
# ea_mv-07-07-2022-16-12_11.tar.gz
# ea_mv-07-07-2022-16-12_12.tar.gz
# ea_mv-07-07-2022-16-12_2.tar.gz
# ea_mv-07-07-2022-16-12_3.tar.gz
# ea_mv-07-07-2022-16-12_4.tar.gz
# ea_mv-07-07-2022-16-12_5.tar.gz
# ea_mv-07-07-2022-16-12_6.tar.gz
# ea_mv-07-07-2022-16-12_7.tar.gz
# ea_mv-07-07-2022-16-12_8.tar.gz
# ea_mv-07-07-2022-16-12_9.tar.gz
#      utility  reliability          Algorithms
# 0  -1.779096   -10.293110  Epsilon-NSGA-II_mv
# 1  -1.690390   -10.300111  Epsilon-NSGA-II_mv
# 2  -1.531374   -10.365161  Epsilon-NSGA-II_mv
# 3  -1.499898   -10.348763  Epsilon-NSGA-II_mv
# 4  -1.500426   -10.357277  Epsilon-NSGA-II_mv
# 5  -1.515721   -10.353440  Epsilon-NSGA-II_mv
# 6  -1.513555   -10.433747  Epsilon-NSGA-II_mv
# 7  -1.502560   -10.355213  Epsilon-NSGA-II_mv
# 8  -1.530697   -10.435423  Epsilon-NSGA-II_mv
# 9  -1.543975   -10.395904  Epsilon-NSGA-II_mv
# ...

# %%
path = files[58]
nes_mv = pd.read_csv(results_path + path)
nes_mv["Algorithms"]="MO-NES_mv"
print(path)
nes_mv
# 0:00:15
# Out:
# nes_mv-08-07-2022-21-55_best.csv
#      utility  reliability Algorithms
# 0  -1.536403   -10.112357  MO-NES_mv
# 1  -1.377404   -10.550800  MO-NES_mv
# 2  -2.140596    -9.526049  MO-NES_mv
# 3  -1.633756    -9.921812  MO-NES_mv
# 4  -1.667882    -9.849138  MO-NES_mv
# ..       ...          ...        ...
# 68 -1.546718   -10.047882  MO-NES_mv
# 69 -1.822111    -9.683986  MO-NES_mv
# 70 -1.504491   -10.184385  MO-NES_mv
# 71 -2.131112    -9.564108  MO-NES_mv
# 72 -1.610361    -9.935256  MO-NES_mv
#
# [73 rows x 3 columns]

# %%
path = files[64]
repsep_mv = pd.read_csv(results_path + path)
repsep_mv["Algorithms"]="MO-eREPS_mv"
print(path)
repsep_mv
# 0:00:15
# Out:
# repsep_mv-08-07-2022-21-59_best.csv
#      utility  reliability   Algorithms
# 0  -5.478742    -9.028201  MO-eREPS_mv
# 1  -1.437176   -10.482145  MO-eREPS_mv
# 2  -1.605440    -9.991236  MO-eREPS_mv
# 3  -1.373481   -10.573965  MO-eREPS_mv
# 4  -1.378316   -10.566522  MO-eREPS_mv
# 5  -1.511080   -10.257988  MO-eREPS_mv
# 6  -1.387267   -10.547134  MO-eREPS_mv
# 7  -1.818169    -9.780020  MO-eREPS_mv
# 8  -1.405800   -10.537521  MO-eREPS_mv
# 9  -1.729491    -9.838722  MO-eREPS_mv
# 10 -1.901506    -9.637059  MO-eREPS_mv
# 11 -2.308630    -9.557508  MO-eREPS_mv
# 12 -1.525100   -10.214290  MO-eREPS_mv
# 13 -1.503258   -10.332800  MO-eREPS_mv
# 14 -2.373109    -9.493583  MO-eREPS_mv
# 15 -1.410912   -10.501920  MO-eREPS_mv
# 16 -3.314826    -9.291159  MO-eREPS_mv
# 17 -1.429184   -10.501062  MO-eREPS_mv
# 18 -2.086067    -9.576882  MO-eREPS_mv
# 19 -1.702908    -9.855950  MO-eREPS_mv
# 20 -1.378397   -10.555924  MO-eREPS_mv
# 21 -1.369213   -10.593437  MO-eREPS_mv
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_mv, nes_mv, repsep_mv])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_mv, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.3972078673825811

# %%
compute_hypervolume(nes_mv, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.601540607313537

# %%
compute_hypervolume(repsep_mv, np.array([-8, -12]), np.array([0, -8.5]))
# Out:
# 0.6472826922731412

# %% [markdown]
# # Dam3 Problem

# %%
import numpy as np
ea = np.array([[-0.237107, -9.631446, 0.0], [-0.874214, -9.431446, 0.0], [0.000000, -9.831446, 0.0],
               [-0.505661, -9.531446, 0.0], [-0.068554, -9.731446, 0.0]])

# %%
nes = np.array([[-0.23710722,-9.63144639,0.],[-0.06855361,-9.73144639,0.],[-0.50566083,-9.53144639,0.],
                [0.,-9.83144639,0.],[-0.87421444,-9.43144639,0.]])

# %%
repsep = np.array([[-0.06855361,-9.73144639,0.],[0.,-9.83144639,0.],[-0.87421444,-9.43144639,0.],[-0.50566083,-9.53144639,0.],[-0.23710722,-9.63144639,0.]])

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(9,6), dpi= 100)
ax = plt.axes(projection='3d')
ax.scatter3D(ea[:,0], ea[:,1], ea[:,2])
ax.scatter3D(nes[:,0], nes[:,1], nes[:,2])
ax.scatter3D(repsep[:,0], repsep[:,1], repsep[:,2])

# %%
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam3_deep_performance/'
files=sorted(os.listdir(results_path))

ea_results_path='../results/dam3_deep_performance/ea_avg/'
ea_files=sorted(os.listdir(ea_results_path))
ea_files
# Out:
# ['ea_avg-18-07-2022-15-36_0.tar.gz',
#  'ea_avg-18-07-2022-15-36_1.tar.gz',
#  'ea_avg-18-07-2022-15-36_10.tar.gz',
#  'ea_avg-18-07-2022-15-36_100.tar.gz',
#  'ea_avg-18-07-2022-15-36_101.tar.gz',
#  'ea_avg-18-07-2022-15-36_102.tar.gz',
#  'ea_avg-18-07-2022-15-36_103.tar.gz',
#  'ea_avg-18-07-2022-15-36_104.tar.gz',
#  'ea_avg-18-07-2022-15-36_105.tar.gz',
#  'ea_avg-18-07-2022-15-36_106.tar.gz',
#  'ea_avg-18-07-2022-15-36_107.tar.gz',
#  'ea_avg-18-07-2022-15-36_108.tar.gz',
#  'ea_avg-18-07-2022-15-36_109.tar.gz',
#  'ea_avg-18-07-2022-15-36_11.tar.gz',
#  'ea_avg-18-07-2022-15-36_110.tar.gz',
#  'ea_avg-18-07-2022-15-36_111.tar.gz',
#  'ea_avg-18-07-2022-15-36_112.tar.gz',
#  'ea_avg-18-07-2022-15-36_113.tar.gz',
#  'ea_avg-18-07-2022-15-36_114.tar.gz',
#  'ea_avg-18-07-2022-15-36_115.tar.gz',
#  'ea_avg-18-07-2022-15-36_116.tar.gz',
#  'ea_avg-18-07-2022-15-36_117.tar.gz',
#  'ea_avg-18-07-2022-15-36_118.tar.gz',
#  'ea_avg-18-07-2022-15-36_119.tar.gz',
# ...

# %%
ea=[]
for i in range(0, 397):
    _, all_outcomes=load_results(ea_results_path + ea_files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('upstream_flooding', 'water_demand', 'electricity_demand'))
    ea.append(all_outcomes)
    print(ea_files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# 2:44:18
# Out:
# ea_avg-18-07-2022-15-36_0.tar.gz
# ea_avg-18-07-2022-15-36_1.tar.gz
# ea_avg-18-07-2022-15-36_10.tar.gz
# ea_avg-18-07-2022-15-36_100.tar.gz
# ea_avg-18-07-2022-15-36_101.tar.gz
# ea_avg-18-07-2022-15-36_102.tar.gz
# ea_avg-18-07-2022-15-36_103.tar.gz
# ea_avg-18-07-2022-15-36_104.tar.gz
# ea_avg-18-07-2022-15-36_105.tar.gz
# ea_avg-18-07-2022-15-36_106.tar.gz
# ea_avg-18-07-2022-15-36_107.tar.gz
# ea_avg-18-07-2022-15-36_108.tar.gz
# ea_avg-18-07-2022-15-36_109.tar.gz
# ea_avg-18-07-2022-15-36_11.tar.gz
# ea_avg-18-07-2022-15-36_110.tar.gz
# ea_avg-18-07-2022-15-36_111.tar.gz
# ea_avg-18-07-2022-15-36_112.tar.gz
# ea_avg-18-07-2022-15-36_113.tar.gz
# ea_avg-18-07-2022-15-36_114.tar.gz
# ea_avg-18-07-2022-15-36_115.tar.gz
# ea_avg-18-07-2022-15-36_116.tar.gz
# ea_avg-18-07-2022-15-36_117.tar.gz
# ea_avg-18-07-2022-15-36_118.tar.gz
# ea_avg-18-07-2022-15-36_119.tar.gz
# ea_avg-18-07-2022-15-36_12.tar.gz
# ea_avg-18-07-2022-15-36_120.tar.gz
# ea_avg-18-07-2022-15-36_121.tar.gz
# ...

# %%
path = files[2]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# 0:00:15
# Out:
# nes-18-07-2022-15-37_best.csv
#      upstream_flooding  water_demand  electricity_demand Algorithms
# 0           -12.153227     -9.502898           -0.113442     MO-NES
# 1           -15.455891     -9.131501           -0.084165     MO-NES
# 2            -8.262456     -9.209138           -0.226938     MO-NES
# 3            -2.322716     -9.745253           -0.513618     MO-NES
# 4           -23.022927     -9.250377           -0.024589     MO-NES
# ..                 ...           ...                 ...        ...
# 664          -2.263036     -9.686861           -0.524134     MO-NES
# 665         -10.257093     -9.006882           -0.201889     MO-NES
# 666          -6.518117     -8.985445           -0.379066     MO-NES
# 667         -47.401931     -9.525800           -0.000116     MO-NES
# 668         -15.178256     -9.487745           -0.066297     MO-NES
#
# [669 rows x 4 columns]

# %%
path = files[4]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREP"
print(path)
repsep
# 0:00:15
# Out:
# repsep-18-07-2022-21-23_best.csv
#      upstream_flooding  water_demand  electricity_demand Algorithms
# 0           -26.729283     -9.313700           -0.012809    MO-eREP
# 1           -26.209225     -9.226509           -0.014816    MO-eREP
# 2            -5.463077     -9.230602           -0.343476    MO-eREP
# 3            -7.125302     -9.052891           -0.327250    MO-eREP
# 4           -10.851088     -9.139267           -0.200640    MO-eREP
# ..                 ...           ...                 ...        ...
# 680         -30.669967     -9.344213           -0.006435    MO-eREP
# 681         -30.427528     -9.332454           -0.006770    MO-eREP
# 682          -5.508746     -9.114185           -0.395320    MO-eREP
# 683         -13.220905     -9.057578           -0.121457    MO-eREP
# 684          -6.024184     -9.210853           -0.320971    MO-eREP
#
# [685 rows x 4 columns]

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(9,6), dpi= 100)
ax = plt.axes(projection='3d')
ax.scatter3D(ea['upstream_flooding'], ea['water_demand'], ea['electricity_demand'])
ax.scatter3D(nes['upstream_flooding'], nes['water_demand'], nes['electricity_demand'])
ax.scatter3D(repsep['upstream_flooding'], repsep['water_demand'], repsep['electricity_demand'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="upstream_flooding", y="electricity_demand", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("upstream_flooding")
plt.ylabel("water_demand")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([-70, -11, -1]), np.array([-1, -8, 0]))
# Out:
# 0.5635328681664763

# %%
compute_hypervolume(nes, np.array([-70, -11, -1]), np.array([-1, -8, 0]))
# Out:
# 0.6320426498935912

# %%
compute_hypervolume(repsep, np.array([-70, -11, -1]), np.array([-1, -8, 0]))
# Out:
# 0.6358230620443708
