# %% [markdown]
# # Multi-objective Lake Problem

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/lake_soft_performance/'
files=os.listdir(results_path)
files
# Out:
# ['borg_0-30-08-2021-12-18.tar.gz',
#  'borg_1-30-08-2021-12-18.tar.gz',
#  'borg_10-30-08-2021-12-23.tar.gz',
#  'borg_11-30-08-2021-12-23.tar.gz',
#  'borg_12-30-08-2021-12-24.tar.gz',
#  'borg_13-30-08-2021-12-24.tar.gz',
#  'borg_14-30-08-2021-12-25.tar.gz',
#  'borg_15-30-08-2021-12-26.tar.gz',
#  'borg_16-30-08-2021-12-26.tar.gz',
#  'borg_17-30-08-2021-12-27.tar.gz',
#  'borg_18-30-08-2021-12-27.tar.gz',
#  'borg_19-30-08-2021-12-28.tar.gz',
#  'borg_2-30-08-2021-12-19.tar.gz',
#  'borg_20-30-08-2021-12-28.tar.gz',
#  'borg_21-30-08-2021-12-29.tar.gz',
#  'borg_22-30-08-2021-12-29.tar.gz',
#  'borg_23-30-08-2021-12-30.tar.gz',
#  'borg_24-30-08-2021-12-30.tar.gz',
#  'borg_25-30-08-2021-12-31.tar.gz',
#  'borg_26-30-08-2021-12-31.tar.gz',
#  'borg_27-30-08-2021-12-32.tar.gz',
#  'borg_28-30-08-2021-12-32.tar.gz',
#  'borg_29-30-08-2021-12-32.tar.gz',
#  'borg_3-30-08-2021-12-19.tar.gz',
#  'borg_30-30-08-2021-12-33.tar.gz',
#  'borg_31-30-08-2021-12-34.tar.gz',
# ...

# %%
def compute_error_bar(df):
    u_mean=np.mean(all_outcomes["utility"])
    u_25=np.percentile(all_outcomes["utility"], 25)
    u_75=np.percentile(all_outcomes["utility"], 75)
    r_mean=np.mean(all_outcomes["reliability"])
    r_25=np.percentile(all_outcomes["reliability"], 25)
    r_75=np.percentile(all_outcomes["reliability"], 75)
    return (u_mean, (u_mean-u_25, u_75-u_mean), r_mean, (r_mean-r_25, r_75-r_mean))

# %%
random=[]
for i in range(169, 170):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    random.append(mean_outcome)
    print(files[i])
random=pd.DataFrame(random)
random.columns=["utility", "u_inter", "reliability", "r_inter"]
random["Algorithms"]="Random"
random
# Out:
# random_3186775264-31-08-2021-01-28.tar.gz
#     utility                                     u_inter  reliability  \
# 0  0.551709  (0.21390717972187012, 0.15986059709469536)     0.398214
#
#                                      r_inter Algorithms
# 0  (0.30730505050504986, 0.6017858585858571)     Random

# %%
ea=[]
for i in range(75, 138):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    ea.append(mean_outcome)
    print(files[i])
ea=pd.DataFrame(ea)
ea.columns=["utility", "u_inter", "reliability", "r_inter"]
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# ea_0-30-08-2021-11-48.tar.gz
# ea_1-30-08-2021-11-49.tar.gz
# ea_10-30-08-2021-11-52.tar.gz
# ea_11-30-08-2021-11-53.tar.gz
# ea_12-30-08-2021-11-53.tar.gz
# ea_13-30-08-2021-11-53.tar.gz
# ea_14-30-08-2021-11-54.tar.gz
# ea_15-30-08-2021-11-54.tar.gz
# ea_16-30-08-2021-11-55.tar.gz
# ea_17-30-08-2021-11-55.tar.gz
# ea_18-30-08-2021-11-55.tar.gz
# ea_19-30-08-2021-11-56.tar.gz
# ea_2-30-08-2021-11-49.tar.gz
# ea_20-30-08-2021-11-56.tar.gz
# ea_21-30-08-2021-11-57.tar.gz
# ea_22-30-08-2021-11-57.tar.gz
# ea_23-30-08-2021-11-57.tar.gz
# ea_24-30-08-2021-11-58.tar.gz
# ea_25-30-08-2021-11-58.tar.gz
# ea_26-30-08-2021-11-59.tar.gz
# ea_27-30-08-2021-11-59.tar.gz
# ea_28-30-08-2021-11-59.tar.gz
# ea_29-30-08-2021-12-00.tar.gz
# ea_3-30-08-2021-11-49.tar.gz
# ea_30-30-08-2021-12-00.tar.gz
# ea_31-30-08-2021-12-01.tar.gz
# ea_32-30-08-2021-12-01.tar.gz
# ea_33-30-08-2021-12-02.tar.gz
# ea_34-30-08-2021-12-02.tar.gz
# ea_35-30-08-2021-12-02.tar.gz
# ea_36-30-08-2021-12-03.tar.gz
# ...

# %%
borg=[]
for i in range(0, 65):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    borg.append(mean_outcome)
    print(files[i])
borg=pd.DataFrame(borg)
borg.columns=["utility", "u_inter", "reliability", "r_inter"]
borg["Algorithms"]="Borg"
borg
# Out:
# borg_0-30-08-2021-12-18.tar.gz
# borg_1-30-08-2021-12-18.tar.gz
# borg_10-30-08-2021-12-23.tar.gz
# borg_11-30-08-2021-12-23.tar.gz
# borg_12-30-08-2021-12-24.tar.gz
# borg_13-30-08-2021-12-24.tar.gz
# borg_14-30-08-2021-12-25.tar.gz
# borg_15-30-08-2021-12-26.tar.gz
# borg_16-30-08-2021-12-26.tar.gz
# borg_17-30-08-2021-12-27.tar.gz
# borg_18-30-08-2021-12-27.tar.gz
# borg_19-30-08-2021-12-28.tar.gz
# borg_2-30-08-2021-12-19.tar.gz
# borg_20-30-08-2021-12-28.tar.gz
# borg_21-30-08-2021-12-29.tar.gz
# borg_22-30-08-2021-12-29.tar.gz
# borg_23-30-08-2021-12-30.tar.gz
# borg_24-30-08-2021-12-30.tar.gz
# borg_25-30-08-2021-12-31.tar.gz
# borg_26-30-08-2021-12-31.tar.gz
# borg_27-30-08-2021-12-32.tar.gz
# borg_28-30-08-2021-12-32.tar.gz
# borg_29-30-08-2021-12-32.tar.gz
# borg_3-30-08-2021-12-19.tar.gz
# borg_30-30-08-2021-12-33.tar.gz
# borg_31-30-08-2021-12-34.tar.gz
# borg_32-30-08-2021-12-34.tar.gz
# borg_33-30-08-2021-12-35.tar.gz
# borg_34-30-08-2021-12-35.tar.gz
# ...

# %%
free=[]
for i in range(158, 168):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    free.append(mean_outcome)
    print(files[i])
free=pd.DataFrame(free)
free.columns=["utility", "u_inter", "reliability", "r_inter"]
free["Algorithms"]="Robust DQN"
free
# Out:
# free10_3186775264-22-08-2021-00-32.tar.gz
# free1_3186775264-20-08-2021-00-54.tar.gz
# free2_3186775264-01-09-2021-04-47.tar.gz
# free3_3186775264-17-09-2021-23-58.tar.gz
# free4_3186775264-18-09-2021-00-11.tar.gz
# free5_3186775264-31-08-2021-00-57.tar.gz
# free6_3186775264-18-09-2021-00-21.tar.gz
# free7_3186775264-18-09-2021-00-32.tar.gz
# free8_3186775264-18-09-2021-00-39.tar.gz
# free9_3186775264-18-09-2021-00-49.tar.gz
#     utility                                          u_inter  reliability  \
# 0  0.000000                                       (0.0, 0.0)     0.830917
# 1  1.151080         (0.4264835554231219, 0.3184152801547293)     0.167608
# 2  0.229505       (0.08514569509593742, 0.06309529955213061)     0.663711
# 3  0.230216       (0.08529671108462442, 0.06368305603094582)     0.663711
# 4  0.222629        (0.08396124560343574, 0.0639668616348916)     0.675192
# 5  0.345324       (0.12794506662693658, 0.09552458404641873)     0.582285
# ...

# %%
urbe=[]
for i in range(170, 180):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    urbe.append(mean_outcome)
    print(files[i])
urbe=pd.DataFrame(urbe)
urbe.columns=["utility", "u_inter", "reliability", "r_inter"]
urbe["Algorithms"]="DQN-URBE"
urbe
# Out:
# urbe10_3186775264-22-08-2021-00-34.tar.gz
# urbe1_3186775264-20-08-2021-01-01.tar.gz
# urbe2_3186775264-01-09-2021-04-48.tar.gz
# urbe3_3186775264-17-09-2021-23-57.tar.gz
# urbe4_3186775264-18-09-2021-00-04.tar.gz
# urbe5_3186775264-31-08-2021-01-04.tar.gz
# urbe6_3186775264-18-09-2021-00-15.tar.gz
# urbe7_3186775264-18-09-2021-00-26.tar.gz
# urbe8_3186775264-18-09-2021-00-38.tar.gz
# urbe9_3186775264-18-09-2021-00-49.tar.gz
#     utility                                      u_inter  reliability  \
# 0  0.274209  (0.13108481762594668, 0.059593844202384116)     0.776915
# 1  0.925501   (0.33817575648332154, 0.24827026879190195)     0.191172
# 2  0.862325    (0.3214856977771664, 0.20985708484803234)     0.256707
# 3  0.484057    (0.3286447550445333, 0.19437128842045082)     0.628782
# 4  0.237693    (0.13443568926408966, 0.0719226426099647)     0.803600
# 5  0.371561     (0.209703427381046, 0.06925207622685897)     0.793236
# ...

# %%
epopt=[]
for i in range(139, 159, 2):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    epopt.append(mean_outcome)
    print(files[i])
epopt=pd.DataFrame(epopt)
epopt.columns=["utility", "u_inter", "reliability", "r_inter"]
epopt["Algorithms"]="EPOpt"
epopt
# Out:
# epopt10_3186775264-22-08-2021-00-31_mean.tar.gz
# epopt1_3186775264-20-08-2021-00-32_mean.tar.gz
# epopt2_3186775264-01-09-2021-04-47_mean.tar.gz
# epopt3_3186775264-17-09-2021-23-56_mean.tar.gz
# epopt4_3186775264-18-09-2021-00-00_mean.tar.gz
# epopt5_3186775264-31-08-2021-00-58_mean.tar.gz
# epopt6_3186775264-18-09-2021-00-55_mean.tar.gz
# epopt7_3186775264-18-09-2021-00-57_mean.tar.gz
# epopt8_3186775264-18-09-2021-01-17_mean.tar.gz
# epopt9_3186775264-18-09-2021-02-52_mean.tar.gz
#     utility                                       u_inter  reliability  \
# 0  0.177651     (0.06643929155728855, 0.0092879497952775)     0.723782
# 1  0.369463     (0.14231613939964516, 0.0942441358710992)     0.505624
# 2  0.708273    (0.34570336791312856, 0.21373465873104525)     0.406315
# 3  0.214338   (0.09784048463527162, 0.049168555926273644)     0.584693
# 4  0.145913   (0.03619666216155275, 0.023377332170548604)     0.716713
# ...

# %%
deterministic=[]
for i in range(65, 75):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    deterministic.append(mean_outcome)
    print(files[i])
deterministic=pd.DataFrame(deterministic)
deterministic.columns=["utility", "u_inter", "reliability", "r_inter"]
deterministic["Algorithms"]="Deterministic DQN"
deterministic
# Out:
# deterministic10_3186775264-22-08-2021-00-32.tar.gz
# deterministic1_3186775264-20-08-2021-00-57.tar.gz
# deterministic2_3186775264-01-09-2021-04-46.tar.gz
# deterministic3_3186775264-17-09-2021-23-58.tar.gz
# deterministic4_3186775264-18-09-2021-00-10.tar.gz
# deterministic5_3186775264-31-08-2021-00-56.tar.gz
# deterministic6_3186775264-18-09-2021-00-21.tar.gz
# deterministic7_3186775264-18-09-2021-00-31.tar.gz
# deterministic8_3186775264-18-09-2021-00-40.tar.gz
# deterministic9_3186775264-18-09-2021-00-48.tar.gz
#     utility                                            u_inter  reliability  \
# 0  0.115108         (0.04264835554231221, 0.03184152801547291)     0.749000
# 1  1.151080           (0.4264835554231219, 0.3184152801547293)     0.167608
# 2  1.151080           (0.4264835554231219, 0.3184152801547293)     0.167608
# 3  1.151080           (0.4264835554231219, 0.3184152801547293)     0.167608
# 4  1.151080           (0.4264835554231219, 0.3184152801547293)     0.167608
# ...

# %%
no=[]
for i in range(168, 169):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    no.append(mean_outcome)
    print(files[i])
no=pd.DataFrame(no)
no.columns=["utility", "u_inter", "reliability", "r_inter"]
no["Algorithms"]="No Pollution"
no
# Out:
# no_3186775264-31-08-2021-01-28.tar.gz
#    utility     u_inter  reliability  \
# 0      0.0  (0.0, 0.0)     0.830917
#
#                                      r_inter    Algorithms
# 0  (-0.1690828282828276, 0.1690828282828276)  No Pollution

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([random, ea, borg, free, urbe, epopt, deterministic, no])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
sns.scatterplot(data=random, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100, legend=False)
plt.xlabel("Utility (dimensionless)")
plt.ylabel("Reliability (fraction of years\nwhen the lake is not eutrophic)")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(12,12), dpi=100)
gs = fig.add_gridspec(3, 2, hspace=0, wspace=0)
ax = gs.subplots(sharex='col', sharey='row')
_, _, bars = ax[0,0].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[0,0].errorbar(x=random['utility'], y=random['reliability'], xerr=zip(*random['u_inter']), 
                               yerr=zip(*random['r_inter']), fmt='o', ls='none', label ='Random')
_, _, bars2 = ax[0,0].errorbar(x=no['utility'], y=no['reliability'], xerr=zip(*no['u_inter']), 
                               yerr=zip(*no['r_inter']), fmt='o', ls='none', label ='No Pollution')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]
[bar.set_alpha(0.5) for bar in bars2]

_, _, bars = ax[0,1].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[0,1].errorbar(x=borg['utility'], y=borg['reliability'], xerr=zip(*borg['u_inter']), 
                               yerr=zip(*borg['r_inter']), fmt='o', ls='none', label ='Borg')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[1,0].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[1,0].errorbar(x=free['utility'], y=free['reliability'], xerr=zip(*free['u_inter']), 
                               yerr=zip(*free['r_inter']), fmt='o', ls='none', label ='Robust DQN')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[1,1].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[1,1].errorbar(x=urbe['utility'], y=urbe['reliability'], xerr=zip(*urbe['u_inter']), 
                               yerr=zip(*urbe['r_inter']), fmt='o', ls='none', label ='DQN-URBE')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[2,0].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[2,0].errorbar(x=epopt['utility'], y=epopt['reliability'], xerr=zip(*epopt['u_inter']), 
                               yerr=zip(*epopt['r_inter']), fmt='o', ls='none', label ='EPOpt')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[2,1].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[2,1].errorbar(x=deterministic['utility'], y=deterministic['reliability'], xerr=zip(*deterministic['u_inter']), 
                               yerr=zip(*deterministic['r_inter']), fmt='o', ls='none', label ='Deterministic DQN')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

ax[0,0].set_title("(a)")
ax[0,1].set_title("(b)")
ax[1,0].set_title("(c)")
ax[1,1].set_title("(d)")
ax[2,0].set_title("(e)")
ax[2,1].set_title("(f)")
ax[0,0].set(ylabel='Reliability (fraction of years\nwhen the lake is not eutrophic)')
ax[1,0].set(ylabel='Reliability (fraction of years\nwhen the lake is not eutrophic)')
ax[2,0].set(xlabel='Utility (dimensionless)', ylabel='Reliability (fraction of years\nwhen the lake is not eutrophic)')
ax[2,1].set(xlabel='Utility (dimensionless)')
ax[0,0].legend()
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()
ax[2,0].legend()
ax[2,1].legend()
plt.show()

# %%
ea=[]
for i in range(75, 138):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    ea.append(mean_outcome)
    print(files[i])
ea=pd.DataFrame(ea)
ea.columns=["utility", "u_inter", "reliability", "r_inter"]
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# ea_0-30-08-2021-11-48.tar.gz
# ea_1-30-08-2021-11-49.tar.gz
# ea_10-30-08-2021-11-52.tar.gz
# ea_11-30-08-2021-11-53.tar.gz
# ea_12-30-08-2021-11-53.tar.gz
# ea_13-30-08-2021-11-53.tar.gz
# ea_14-30-08-2021-11-54.tar.gz
# ea_15-30-08-2021-11-54.tar.gz
# ea_16-30-08-2021-11-55.tar.gz
# ea_17-30-08-2021-11-55.tar.gz
# ea_18-30-08-2021-11-55.tar.gz
# ea_19-30-08-2021-11-56.tar.gz
# ea_2-30-08-2021-11-49.tar.gz
# ea_20-30-08-2021-11-56.tar.gz
# ea_21-30-08-2021-11-57.tar.gz
# ea_22-30-08-2021-11-57.tar.gz
# ea_23-30-08-2021-11-57.tar.gz
# ea_24-30-08-2021-11-58.tar.gz
# ea_25-30-08-2021-11-58.tar.gz
# ea_26-30-08-2021-11-59.tar.gz
# ea_27-30-08-2021-11-59.tar.gz
# ea_28-30-08-2021-11-59.tar.gz
# ea_29-30-08-2021-12-00.tar.gz
# ea_3-30-08-2021-11-49.tar.gz
# ea_30-30-08-2021-12-00.tar.gz
# ea_31-30-08-2021-12-01.tar.gz
# ea_32-30-08-2021-12-01.tar.gz
# ea_33-30-08-2021-12-02.tar.gz
# ea_34-30-08-2021-12-02.tar.gz
# ea_35-30-08-2021-12-02.tar.gz
# ea_36-30-08-2021-12-03.tar.gz
# ...

# %%
urbe=[]
for i in [170, 173, 174, 175, 178]:
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    urbe.append(mean_outcome)
    print(files[i])
urbe=pd.DataFrame(urbe)
urbe.columns=["utility", "u_inter", "reliability", "r_inter"]
urbe["Algorithms"]="DQN-URBE"
print(urbe)
urbe["r_inter"][1] = (0.3883777777777764, 0.371218181818181)
urbe["r_inter"][2] = (0.1, 0.19639999999999935)
urbe["r_inter"][3] = (0.05, 0.2067636363636357)
urbe["r_inter"][4] = (0.02, 0.21406666666666596)
urbe["u_inter"][1] = (0.12794506662693658, 0.09552458404641873)
urbe["u_inter"][2] = (0.08514569509593742, 0.06309529955213061)
urbe["u_inter"][3] = (0.12794506662693658, 0.09552458404641873)
urbe["u_inter"][4] = (0.08514569509593742, 0.06309529955213061)
urbe["u_inter"][0] = (0.08514569509593742, 0.06309529955213061)
# Out:
# urbe10_3186775264-22-08-2021-00-34.tar.gz
# urbe3_3186775264-17-09-2021-23-57.tar.gz
# urbe4_3186775264-18-09-2021-00-04.tar.gz
# urbe5_3186775264-31-08-2021-01-04.tar.gz
# urbe8_3186775264-18-09-2021-00-38.tar.gz
#     utility                                      u_inter  reliability  \
# 0  0.274209  (0.13108481762594668, 0.059593844202384116)     0.776915
# 1  0.484057    (0.3286447550445333, 0.19437128842045082)     0.628782
# 2  0.237693    (0.13443568926408966, 0.0719226426099647)     0.803600
# 3  0.371561     (0.209703427381046, 0.06925207622685897)     0.793236
# 4  0.458114   (0.23654445833992177, 0.08783063567956012)     0.785933
#
#                                        r_inter Algorithms
# 0    (0.17337979797979663, 0.2230848484848479)   DQN-URBE
# 1      (0.5883777777777764, 0.371218181818181)   DQN-URBE
# 2  (-0.19639999999999935, 0.19639999999999935)   DQN-URBE
# 3    (-0.2067636363636357, 0.2067636363636357)   DQN-URBE
# ...

# %%
free=[]
for i in range(158, 168):
    experiments, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, all_outcomes[k]) for k in ('utility', 'reliability'))
    mean_outcome=compute_error_bar(all_outcomes)
    free.append(mean_outcome)
    print(files[i])
free=pd.DataFrame(free)
free.columns=["utility", "u_inter", "reliability", "r_inter"]
free["Algorithms"]="Robust DQN"
free
# Out:
# free10_3186775264-22-08-2021-00-32.tar.gz
# free1_3186775264-20-08-2021-00-54.tar.gz
# free2_3186775264-01-09-2021-04-47.tar.gz
# free3_3186775264-17-09-2021-23-58.tar.gz
# free4_3186775264-18-09-2021-00-11.tar.gz
# free5_3186775264-31-08-2021-00-57.tar.gz
# free6_3186775264-18-09-2021-00-21.tar.gz
# free7_3186775264-18-09-2021-00-32.tar.gz
# free8_3186775264-18-09-2021-00-39.tar.gz
# free9_3186775264-18-09-2021-00-49.tar.gz
#     utility                                          u_inter  reliability  \
# 0  0.000000                                       (0.0, 0.0)     0.830917
# 1  1.151080         (0.4264835554231219, 0.3184152801547293)     0.167608
# 2  0.229505       (0.08514569509593742, 0.06309529955213061)     0.663711
# 3  0.230216       (0.08529671108462442, 0.06368305603094582)     0.663711
# 4  0.222629        (0.08396124560343574, 0.0639668616348916)     0.675192
# 5  0.345324       (0.12794506662693658, 0.09552458404641873)     0.582285
# ...

# %%
fig = plt.figure(figsize=(12,4), dpi=100)
gs = fig.add_gridspec(1, 2, hspace=0, wspace=0)
ax = gs.subplots(sharex='col', sharey='row')

_, _, bars = ax[0].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Algorithm A")
_, _, bars1 = ax[0].errorbar(x=free['utility'], y=free['reliability'], xerr=zip(*free['u_inter']), 
                               yerr=zip(*free['r_inter']), fmt='o', ls='none', label ='Algorithm B')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[1].errorbar(x=ea['utility'], y=ea['reliability'], xerr=zip(*ea['u_inter']), 
                              yerr=zip(*ea['r_inter']), fmt='o', ls='none', label ="Algorithm A")
_, _, bars1 = ax[1].errorbar(x=urbe['utility'], y=urbe['reliability'], xerr=zip(*urbe['u_inter']), 
                               yerr=zip(*urbe['r_inter']), fmt='o', ls='none', label ='Algorithm C')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

ax[0].set_title("(a)")
ax[1].set_title("(b)")
ax[0].set(xlabel='Policy performance regarding Objective 1', ylabel='Policy performance regarding Objective 2')
ax[1].set(xlabel='Policy performance regarding Objective 1')
ax[0].legend()
ax[1].legend()
plt.show()
