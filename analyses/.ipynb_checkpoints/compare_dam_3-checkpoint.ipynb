# %% [markdown]
# # Robust Dam Problem (random initial state)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_robust_performance_3/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea_10-24-06-2022-21-27_0.tar.gz',
#  'ea_10-24-06-2022-21-27_1.tar.gz',
#  'ea_10-24-06-2022-21-27_10.tar.gz',
#  'ea_10-24-06-2022-21-27_11.tar.gz',
#  'ea_10-24-06-2022-21-27_12.tar.gz',
#  'ea_10-24-06-2022-21-27_2.tar.gz',
#  'ea_10-24-06-2022-21-27_3.tar.gz',
#  'ea_10-24-06-2022-21-27_4.tar.gz',
#  'ea_10-24-06-2022-21-27_5.tar.gz',
#  'ea_10-24-06-2022-21-27_6.tar.gz',
#  'ea_10-24-06-2022-21-27_7.tar.gz',
#  'ea_10-24-06-2022-21-27_8.tar.gz',
#  'ea_10-24-06-2022-21-27_9.tar.gz',
#  'ea_20-24-06-2022-21-30_0.tar.gz',
#  'ea_20-24-06-2022-21-30_1.tar.gz',
#  'ea_20-24-06-2022-21-30_10.tar.gz',
#  'ea_20-24-06-2022-21-30_11.tar.gz',
#  'ea_20-24-06-2022-21-30_12.tar.gz',
#  'ea_20-24-06-2022-21-30_13.tar.gz',
#  'ea_20-24-06-2022-21-30_14.tar.gz',
#  'ea_20-24-06-2022-21-30_2.tar.gz',
#  'ea_20-24-06-2022-21-30_3.tar.gz',
#  'ea_20-24-06-2022-21-30_4.tar.gz',
#  'ea_20-24-06-2022-21-30_5.tar.gz',
#  'ea_20-24-06-2022-21-30_6.tar.gz',
#  'ea_20-24-06-2022-21-30_7.tar.gz',
#  'ea_20-24-06-2022-21-30_8.tar.gz',
#  'ea_20-24-06-2022-21-30_9.tar.gz',
#  'nes_random_initial-24-06-2022-16-50_best.csv',
#  'nes_random_initial-24-06-2022-16-54_high.csv',
#  'repsep_random_initial-24-06-2022-16-36_best.csv',
#  'repsep_random_initial-24-06-2022-16-40_high.csv']

# %%
ea=[]
for i in range(1, 14):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# ea_10-24-06-2022-21-27_0.tar.gz
# ea_10-24-06-2022-21-27_1.tar.gz
# ea_10-24-06-2022-21-27_10.tar.gz
# ea_10-24-06-2022-21-27_11.tar.gz
# ea_10-24-06-2022-21-27_12.tar.gz
# ea_10-24-06-2022-21-27_2.tar.gz
# ea_10-24-06-2022-21-27_3.tar.gz
# ea_10-24-06-2022-21-27_4.tar.gz
# ea_10-24-06-2022-21-27_5.tar.gz
# ea_10-24-06-2022-21-27_6.tar.gz
# ea_10-24-06-2022-21-27_7.tar.gz
# ea_10-24-06-2022-21-27_8.tar.gz
# ea_10-24-06-2022-21-27_9.tar.gz
#      utility  reliability       Algorithms
# 0  -2.568756    -9.306250  Epsilon-NSGA-II
# 1  -2.418755    -9.331250  Epsilon-NSGA-II
# 2  -3.806257    -9.200000  Epsilon-NSGA-II
# 3  -3.956258    -9.037500  Epsilon-NSGA-II
# 4  -3.212507    -9.206250  Epsilon-NSGA-II
# 5  -2.025005    -9.337500  Epsilon-NSGA-II
# 6  -1.431253    -9.531250  Epsilon-NSGA-II
# 7  -3.062506    -9.231250  Epsilon-NSGA-II
# 8  -1.581254    -9.437500  Epsilon-NSGA-II
# 9  -1.087502    -9.700000  Epsilon-NSGA-II
# 10 -1.237503    -9.606250  Epsilon-NSGA-II
# 11 -0.556260    -9.756251  Epsilon-NSGA-II
# 12 -1.875004    -9.431250  Epsilon-NSGA-II

# %%
path = files[29]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes_random_initial-24-06-2022-16-50_best.csv
#       utility  reliability Algorithms
# 0   -4.003325    -8.958658     MO-NES
# 1   -0.743758    -9.731214     MO-NES
# 2   -1.195124    -9.418845     MO-NES
# 3   -3.512254    -9.020405     MO-NES
# 4   -3.778156    -8.987892     MO-NES
# ..        ...          ...        ...
# 112 -3.525297    -9.015623     MO-NES
# 113 -4.025000    -8.956250     MO-NES
# 114 -4.025008    -8.956249     MO-NES
# 115 -4.024974    -8.956253     MO-NES
# 116 -4.025008    -8.956249     MO-NES
#
# [117 rows x 3 columns]

# %%
path = files[31]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep_random_initial-24-06-2022-16-36_best.csv
#       utility  reliability Algorithms
# 0   -3.362791    -9.037898   MO-eREPS
# 1   -1.020479    -9.460244   MO-eREPS
# 2   -4.008375    -8.958097   MO-eREPS
# 3   -3.678515    -8.996694   MO-eREPS
# 4   -3.976111    -8.961698   MO-eREPS
# ..        ...          ...        ...
# 240 -2.472198    -9.172548   MO-eREPS
# 241 -3.364395    -9.037698   MO-eREPS
# 242 -1.771966    -9.298475   MO-eREPS
# 243 -3.923951    -8.967598   MO-eREPS
# 244 -4.025008    -8.956249   MO-eREPS
#
# [245 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(14, 29):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_20th"
ea_avg
# 0:04:06
# Out:
# ea_20-24-06-2022-21-30_0.tar.gz
# ea_20-24-06-2022-21-30_1.tar.gz
# ea_20-24-06-2022-21-30_10.tar.gz
# ea_20-24-06-2022-21-30_11.tar.gz
# ea_20-24-06-2022-21-30_12.tar.gz
# ea_20-24-06-2022-21-30_13.tar.gz
# ea_20-24-06-2022-21-30_14.tar.gz
# ea_20-24-06-2022-21-30_2.tar.gz
# ea_20-24-06-2022-21-30_3.tar.gz
# ea_20-24-06-2022-21-30_4.tar.gz
# ea_20-24-06-2022-21-30_5.tar.gz
# ea_20-24-06-2022-21-30_6.tar.gz
# ea_20-24-06-2022-21-30_7.tar.gz
# ea_20-24-06-2022-21-30_8.tar.gz
# ea_20-24-06-2022-21-30_9.tar.gz
#      utility  reliability            Algorithms
# 0  -1.581254    -9.506250  Epsilon-NSGA-II_20th
# 1  -1.156252    -9.618749  Epsilon-NSGA-II_20th
# 2  -2.093755    -9.324999  Epsilon-NSGA-II_20th
# 3  -2.637506    -9.224999  Epsilon-NSGA-II_20th
# 4  -3.281257    -9.056249  Epsilon-NSGA-II_20th
# 5  -3.956258    -9.106250  Epsilon-NSGA-II_20th
# 6  -4.025008    -8.956249  Epsilon-NSGA-II_20th
# 7  -1.306253    -9.524999  Epsilon-NSGA-II_20th
# 8  -1.087502    -9.631250  Epsilon-NSGA-II_20th
# 9  -0.556260    -9.750000  Epsilon-NSGA-II_20th
# 10 -1.237503    -9.537500  Epsilon-NSGA-II_20th
# 11 -1.650004    -9.424999  Epsilon-NSGA-II_20th
# 12 -2.568756    -9.237500  Epsilon-NSGA-II_20th
# 13 -2.025005    -9.337500  Epsilon-NSGA-II_20th
# 14 -3.212507    -9.206250  Epsilon-NSGA-II_20th

# %%
# path = files[37]
# nes_avg = pd.read_csv(results_path + path)
# nes_avg["Algorithms"]="MO-NES_avg"
# print(path)
# nes_avg
# # 0:00:15

# %%
# path = files[41]
# repsep_avg = pd.read_csv(results_path + path)
# repsep_avg["Algorithms"]="MO-eREPS_avg"
# print(path)
# repsep_avg
# # 0:00:15

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, ea_avg, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()
