# %% [markdown]
# ## Load the evaluatation results for EA

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path = '../results/market_performance_small/'
files = os.listdir(results_path)
files
# Out:
# ['deterministic100-26-09-2021-04-42.tar.gz',
#  'deterministic10_-22-09-2021-03-24.tar.gz',
#  'deterministic20_-26-09-2021-05-12.tar.gz',
#  'deterministic30_-26-09-2021-06-42.tar.gz',
#  'deterministic40_-26-09-2021-07-23.tar.gz',
#  'deterministic50_-26-09-2021-22-30.tar.gz',
#  'deterministic60_-26-09-2021-10-48.tar.gz',
#  'deterministic70_-26-09-2021-11-13.tar.gz',
#  'deterministic80_-26-09-2021-11-13.tar.gz',
#  'deterministic90_-26-09-2021-11-14.tar.gz',
#  'ea_0-21-09-2021-09-01.tar.gz',
#  'ea_1-21-09-2021-09-03.tar.gz',
#  'ea_10-21-09-2021-09-26.tar.gz',
#  'ea_100-22-09-2021-01-15.tar.gz',
#  'ea_101-22-09-2021-01-17.tar.gz',
#  'ea_102-22-09-2021-01-19.tar.gz',
#  'ea_103-22-09-2021-01-21.tar.gz',
#  'ea_104-22-09-2021-01-23.tar.gz',
#  'ea_11-21-09-2021-09-27.tar.gz',
#  'ea_12-21-09-2021-09-29.tar.gz',
#  'ea_13-21-09-2021-09-31.tar.gz',
#  'ea_14-21-09-2021-09-33.tar.gz',
#  'ea_15-21-09-2021-09-35.tar.gz',
#  'ea_16-21-09-2021-09-37.tar.gz',
#  'ea_17-21-09-2021-09-38.tar.gz',
#  'ea_18-21-09-2021-09-40.tar.gz',
#  'ea_19-21-09-2021-09-42.tar.gz',
#  'ea_2-21-09-2021-09-05.tar.gz',
#  'ea_20-21-09-2021-09-44.tar.gz',
#  'ea_21-21-09-2021-09-46.tar.gz',
#  'ea_22-21-09-2021-09-47.tar.gz',
#  'ea_23-21-09-2021-09-49.tar.gz',
#  'ea_24-21-09-2021-09-51.tar.gz',
#  'ea_25-21-09-2021-09-53.tar.gz',
#  'ea_26-21-09-2021-09-55.tar.gz',
#  'ea_27-21-09-2021-09-57.tar.gz',
#  'ea_28-21-09-2021-09-58.tar.gz',
#  'ea_29-21-09-2021-10-00.tar.gz',
#  'ea_3-21-09-2021-09-07.tar.gz',
#  'ea_30-21-09-2021-10-02.tar.gz',
#  'ea_31-21-09-2021-10-04.tar.gz',
#  'ea_32-21-09-2021-10-06.tar.gz',
#  'ea_33-21-09-2021-10-08.tar.gz',
#  'ea_34-21-09-2021-10-10.tar.gz',
#  'ea_35-21-09-2021-10-11.tar.gz',
#  'ea_36-21-09-2021-10-13.tar.gz',
#  'ea_37-21-09-2021-10-15.tar.gz',
#  'ea_38-21-09-2021-10-17.tar.gz',
#  'ea_39-21-09-2021-10-19.tar.gz',
#  'ea_4-21-09-2021-09-12.tar.gz',
#  'ea_40-21-09-2021-10-21.tar.gz',
#  'ea_41-21-09-2021-10-22.tar.gz',
#  'ea_42-21-09-2021-10-24.tar.gz',
#  'ea_43-21-09-2021-10-26.tar.gz',
#  'ea_44-21-09-2021-10-28.tar.gz',
#  'ea_45-21-09-2021-10-30.tar.gz',
#  'ea_46-21-09-2021-10-32.tar.gz',
#  'epopt20-21-09-2021-10-38_mean.tar.gz',
#  'epopt30-21-09-2021-11-09_mean.tar.gz',
#  'epopt40-21-09-2021-11-21_mean.tar.gz',
#  'epopt50-21-09-2021-11-26_mean.tar.gz',
#  'epopt60-21-09-2021-23-58_mean.tar.gz',
#  'epopt70-22-09-2021-00-07_mean.tar.gz',
#  'epopt80-22-09-2021-00-14_mean.tar.gz',
#  'epopt90-22-09-2021-00-22_mean.tar.gz',
#  'free100-21-09-2021-11-03.tar.gz',
#  'free10_-21-09-2021-23-48.tar.gz',
#  'free20_-22-09-2021-01-01.tar.gz',
#  'free30_-22-09-2021-02-55.tar.gz',
#  'free40_-22-09-2021-03-24.tar.gz',
#  'free50_-26-09-2021-04-42.tar.gz',
#  'free60_-26-09-2021-05-12.tar.gz',
#  'free70_-26-09-2021-06-42.tar.gz',
#  'free80_-26-09-2021-07-23.tar.gz',
#  'free90_-26-09-2021-10-22.tar.gz',
#  'no-27-09-2021-00-56.tar.gz']

# %%
def compute_error_bar(df):
    u_mean=np.mean(all_outcomes["price_reduction"])
    u_25=np.percentile(all_outcomes["price_reduction"], 25)
    u_75=np.percentile(all_outcomes["price_reduction"], 75)
    r_mean=np.mean(all_outcomes["emission_reduction"])
    r_25=np.percentile(all_outcomes["emission_reduction"], 25)
    r_75=np.percentile(all_outcomes["emission_reduction"], 75)
    return (u_mean, (u_mean-u_25, u_75-u_mean), r_mean, (r_mean-r_25, r_75-r_mean))

# %%
ea = []
for i in range(10, 115):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    ea.append(mean_outcome)
    print(files[i])
ea = pd.DataFrame(ea)
ea.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
ea["Algorithms"] = "Epsilon-NSGA-II"
ea
# Out:
# ea_0-21-09-2021-09-01.tar.gz
# ea_1-21-09-2021-09-03.tar.gz
# ea_10-21-09-2021-09-26.tar.gz
# ea_100-22-09-2021-01-15.tar.gz
# ea_101-22-09-2021-01-17.tar.gz
# ea_102-22-09-2021-01-19.tar.gz
# ea_103-22-09-2021-01-21.tar.gz
# ea_104-22-09-2021-01-23.tar.gz
# ea_11-21-09-2021-09-27.tar.gz
# ea_12-21-09-2021-09-29.tar.gz
# ea_13-21-09-2021-09-31.tar.gz
# ea_14-21-09-2021-09-33.tar.gz
# ea_15-21-09-2021-09-35.tar.gz
# ea_16-21-09-2021-09-37.tar.gz
# ea_17-21-09-2021-09-38.tar.gz
# ea_18-21-09-2021-09-40.tar.gz
# ea_19-21-09-2021-09-42.tar.gz
# ea_2-21-09-2021-09-05.tar.gz
# ea_20-21-09-2021-09-44.tar.gz
# ea_21-21-09-2021-09-46.tar.gz
# ea_22-21-09-2021-09-47.tar.gz
# ea_23-21-09-2021-09-49.tar.gz
# ea_24-21-09-2021-09-51.tar.gz
# ea_25-21-09-2021-09-53.tar.gz
# ea_26-21-09-2021-09-55.tar.gz
# ea_27-21-09-2021-09-57.tar.gz
# ea_28-21-09-2021-09-58.tar.gz
# ea_29-21-09-2021-10-00.tar.gz
# ea_3-21-09-2021-09-07.tar.gz
# ea_30-21-09-2021-10-02.tar.gz
# ea_31-21-09-2021-10-04.tar.gz
# ea_32-21-09-2021-10-06.tar.gz
# ea_96-22-09-2021-01-06.tar.gz
# ea_97-22-09-2021-01-08.tar.gz
# ea_98-22-09-2021-01-10.tar.gz
# ea_99-22-09-2021-01-12.tar.gz
#      price_reduction                                   p_inter  \
# 0         -66.574032  (118.60881128342943, 140.47386806774125)
# 1        -846.416160  (108.36501938756328, 160.25086984380107)
# 2         -43.382471    (91.75256545527776, 106.0644966246287)
# 3         219.628147  (130.31407521899536, 145.51018281046552)
# 4        -451.168135   (128.75975534820554, 195.8935050020219)
# ..               ...                                       ...
# 100      -604.401384    (62.65162856221184, 99.93128499547663)
# 101       265.145174  (118.14838540577895, 136.60479670739176)
# 102       259.672667  (116.75573041693366, 136.89312550767255)
# 103      -351.551387   (90.95695799851416, 123.69650135175388)
# 104      -366.497678   (97.88556717777254, 138.64279271221162)
#
#      emission_reduction                                   e_inter  \
# 0             62.104837  (15.978837157676892, 16.575642868382523)
# 1             66.526359  (13.216776909067647, 13.682326282703116)
# 2             61.622180   (17.400560704968484, 17.47869744956528)
# 3             44.744376   (17.213986300849335, 13.44459754654504)
# 4             65.262225   (14.15248318922827, 14.712086230962598)
# ..                  ...                                       ...
# 100           65.895617  (13.292230606503658, 13.807303583304375)
# 101           32.859330  (14.702916169884478, 2.3245394241714123)
# 102           33.126874  (14.741690527180339, 2.5006826993897846)
# 103           64.615185  (14.686772981485596, 15.171194475120345)
# 104           64.741053  (14.425745436645414, 15.041548398672745)
#
#           Algorithms
# 0    Epsilon-NSGA-II
# 1    Epsilon-NSGA-II
# 2    Epsilon-NSGA-II
# 3    Epsilon-NSGA-II
# 4    Epsilon-NSGA-II
# ..               ...
# 100  Epsilon-NSGA-II
# 101  Epsilon-NSGA-II
# 102  Epsilon-NSGA-II
# 103  Epsilon-NSGA-II
# 104  Epsilon-NSGA-II
#
# [105 rows x 5 columns]

# %%
free = []
for i in range(125, 135):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    free.append(mean_outcome)
    print(files[i])
free = pd.DataFrame(free)
free.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
free["Algorithms"] = "Robust Model-free DQN"
free
# Out:
# free100-21-09-2021-11-03.tar.gz
# free10_-21-09-2021-23-48.tar.gz
# free20_-22-09-2021-01-01.tar.gz
# free30_-22-09-2021-02-55.tar.gz
# free40_-22-09-2021-03-24.tar.gz
# free50_-26-09-2021-04-42.tar.gz
# free60_-26-09-2021-05-12.tar.gz
# free70_-26-09-2021-06-42.tar.gz
# free80_-26-09-2021-07-23.tar.gz
# free90_-26-09-2021-10-22.tar.gz
#    price_reduction                                  p_inter  \
# 0      -152.121264   (677.7119263817465, 697.7199553241729)
# 1       221.881630    (477.503791636467, 509.7891907033919)
# 2       400.837968  (398.2873661723135, 430.68004870351143)
# 3       221.881630    (477.503791636467, 509.7891907033919)
# 4       221.881630    (477.503791636467, 509.7891907033919)
# 5       428.772664  (405.01673371342815, 443.9507261241676)
# 6       428.772664  (405.01673371342815, 443.9507261241676)
# 7       221.881630    (477.503791636467, 509.7891907033919)
# 8       221.881630    (477.503791636467, 509.7891907033919)
# 9       221.881630    (477.503791636467, 509.7891907033919)
#
#    emission_reduction                                   e_inter  \
# 0           46.358877   (8.125616100357234, 3.7693870513466408)
# 1           56.741944  (18.810652386771096, 18.995935626429933)
# 2           38.685050    (21.31655082110909, 29.90741479321872)
# 3           56.741944  (18.810652386771096, 18.995935626429933)
# 4           56.741944  (18.810652386771096, 18.995935626429933)
# 5           12.242879   (12.497729612612252, 4.636659952023896)
# 6           12.242879   (12.497729612612252, 4.636659952023896)
# 7           56.741944  (18.810652386771096, 18.995935626429933)
# 8           56.741944  (18.810652386771096, 18.995935626429933)
# 9           56.741944  (18.810652386771096, 18.995935626429933)
#
#               Algorithms
# 0  Robust Model-free DQN
# 1  Robust Model-free DQN
# 2  Robust Model-free DQN
# 3  Robust Model-free DQN
# 4  Robust Model-free DQN
# 5  Robust Model-free DQN
# 6  Robust Model-free DQN
# 7  Robust Model-free DQN
# 8  Robust Model-free DQN
# 9  Robust Model-free DQN

# %%
epopt = []
for i in range(115, 125):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    epopt.append(mean_outcome)
    print(files[i])
epopt = pd.DataFrame(epopt)
epopt.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
epopt["Algorithms"] = "EPOpt"
epopt
# Out:
# epopt10-21-09-2021-09-19_mean.tar.gz
# epopt100-22-09-2021-00-28_mean.tar.gz
# epopt20-21-09-2021-10-38_mean.tar.gz
# epopt30-21-09-2021-11-09_mean.tar.gz
# epopt40-21-09-2021-11-21_mean.tar.gz
# epopt50-21-09-2021-11-26_mean.tar.gz
# epopt60-21-09-2021-23-58_mean.tar.gz
# epopt70-22-09-2021-00-07_mean.tar.gz
# epopt80-22-09-2021-00-14_mean.tar.gz
# epopt90-22-09-2021-00-22_mean.tar.gz
#    price_reduction                                  p_inter  \
# 0        93.307751   (580.1063718356687, 595.9504162313542)
# 1      -371.740632  (419.4299326423804, 1009.7732152060667)
# 2        93.481144    (580.819636401375, 603.5418169331155)
# 3        22.923454    (582.3163173578183, 628.333548488021)
# 4        62.076106   (588.2560158113637, 613.2919569075107)
# 5        78.638667   (570.1588715420165, 600.3978689207631)
# 6        89.728045   (566.1429109479982, 598.8666385306916)
# 7      -129.434202   (496.0499923372268, 776.2416848397256)
# 8        87.708919    (585.9307940905891, 604.458169608752)
# 9      -372.928400  (412.74870182267836, 1005.434645581325)
#
#    emission_reduction                                   e_inter Algorithms
# 0           48.222711  (16.001291077809405, 19.804232947514002)      EPOpt
# 1           54.063620  (15.368568027887008, 21.172942874375217)      EPOpt
# 2           48.068380    (16.04854868885878, 19.63782036211643)      EPOpt
# 3           58.691608   (16.69739603858882, 18.125864446092272)      EPOpt
# 4           53.797735   (15.87013162695937, 21.349423749012665)      EPOpt
# 5           50.726697  (15.106276146595178, 22.308931408470905)      EPOpt
# 6           48.626734   (16.245753679537273, 18.60130738261585)      EPOpt
# 7           53.732998    (15.80423432245621, 21.52298630188858)      EPOpt
# 8           52.501122  (15.124821818678669, 21.960875796005176)      EPOpt
# 9           54.449925   (15.023270025256899, 20.85361325095854)      EPOpt

# %%
deterministic = []
for i in range(0, 10):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    deterministic.append(mean_outcome)
    print(files[i])
deterministic = pd.DataFrame(deterministic)
deterministic.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
deterministic["Algorithms"] = "Deterministic Model-free DQN"
deterministic
# Out:
# deterministic100-26-09-2021-04-42.tar.gz
# deterministic10_-22-09-2021-03-24.tar.gz
# deterministic20_-26-09-2021-05-12.tar.gz
# deterministic30_-26-09-2021-06-42.tar.gz
# deterministic40_-26-09-2021-07-23.tar.gz
# deterministic50_-26-09-2021-22-30.tar.gz
# deterministic60_-26-09-2021-10-48.tar.gz
# deterministic70_-26-09-2021-11-13.tar.gz
# deterministic80_-26-09-2021-11-13.tar.gz
# deterministic90_-26-09-2021-11-14.tar.gz
#    price_reduction                                  p_inter  \
# 0        26.614725   (602.2720711158912, 626.3635003639063)
# 1       400.837968  (398.2873661723135, 430.68004870351143)
# 2       221.881630    (477.503791636467, 509.7891907033919)
# 3       365.249869  (399.5945523742836, 402.49754274249085)
# 4        26.614725   (602.2720711158912, 626.3635003639063)
# 5       221.881630    (477.503791636467, 509.7891907033919)
# 6       165.787586    (493.621882045746, 465.0868881101609)
# 7       221.881630    (477.503791636467, 509.7891907033919)
# 8       365.249869  (399.5945523742836, 402.49754274249085)
# 9       221.881630    (477.503791636467, 509.7891907033919)
#
#    emission_reduction                                   e_inter  \
# 0           60.294557  (16.723805628983307, 17.205977158934616)
# 1           38.685050    (21.31655082110909, 29.90741479321872)
# 2           56.741944  (18.810652386771096, 18.995935626429933)
# 3           19.734001   (9.436786408876632, 0.9508420301855232)
# 4           60.294557  (16.723805628983307, 17.205977158934616)
# 5           56.741944  (18.810652386771096, 18.995935626429933)
# 6           32.721109  (7.014173243211612, 0.20011546870789232)
# 7           56.741944  (18.810652386771096, 18.995935626429933)
# 8           19.734001   (9.436786408876632, 0.9508420301855232)
# 9           56.741944  (18.810652386771096, 18.995935626429933)
#
#                      Algorithms
# 0  Deterministic Model-free DQN
# 1  Deterministic Model-free DQN
# 2  Deterministic Model-free DQN
# 3  Deterministic Model-free DQN
# 4  Deterministic Model-free DQN
# 5  Deterministic Model-free DQN
# 6  Deterministic Model-free DQN
# 7  Deterministic Model-free DQN
# 8  Deterministic Model-free DQN
# 9  Deterministic Model-free DQN

# %%
no = []
for i in range(135, 136):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    no.append(mean_outcome)
    print(files[i])
no = pd.DataFrame(no)
no.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
no["Algorithms"] = "No Action"
no
# Out:
# no-27-09-2021-00-56.tar.gz
#    price_reduction                                  p_inter  \
# 0       428.772664  (405.01673371342815, 443.9507261241676)
#
#    emission_reduction                                  e_inter Algorithms
# 0           12.242879  (12.497729612612252, 4.636659952023896)  No Action

# %%
no1 = []
for i in range(145, 146):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    no1.append(mean_outcome)
    print(files[i])
no1 = pd.DataFrame(no1)
no1.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
no1["Algorithms"] = "No Action"
no1

# %%
no2 = []
for i in range(147, 148):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    no2.append(mean_outcome)
    print(files[i])
no2 = pd.DataFrame(no2)
no2.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
no2["Algorithms"] = "No Action (fixed include)"
no2

# %%
no3 = []
for i in range(148, 149):
    experiments, all_outcomes = load_results(results_path + files[i])
    all_outcomes = dict((k, all_outcomes[k]) for k in ('price_reduction', 'emission_reduction'))
    mean_outcome = compute_error_bar(all_outcomes)
    no3.append(mean_outcome)
    print(files[i])
no3 = pd.DataFrame(no3)
no3.columns = ["price_reduction", "p_inter", "emission_reduction", "e_inter"]
no3["Algorithms"] = "No Action (fixed period)"
no3

# %%
nominal = pd.DataFrame()
nominal['price_reduction'] = [0]
nominal['p_inter'] = [0]
nominal['emission_reduction'] = [0]
nominal['e_inter'] = [0]
nominal['Algorithms'] = ["Nominal Scenario"]
nominal
# Out:
#    price_reduction  p_inter  emission_reduction  e_inter        Algorithms
# 0                0        0                   0        0  Nominal Scenario

# %%
import seaborn as sns
import matplotlib.pyplot as plt
palette = sns.color_palette()
palette2 = sns.color_palette("Paired")
# data = pd.concat([ea, free, epopt, deterministic, no1, no2, no3, no, nominal])
data = pd.concat([ea, free, epopt, deterministic, no, nominal])
plt.figure(figsize=(12,8), dpi= 100)
sns.scatterplot(data=data, x="price_reduction", y="emission_reduction", hue="Algorithms", style="Algorithms", s=100, 
                palette=[palette[1], palette[3], palette[5], palette[6], palette[7], palette2[1]])
plt.xlabel("price_reduction ($/MWh)")
plt.ylabel("emission_reduction (tCO2-e per household)")
plt.show()

# %%
fig = plt.figure(figsize=(16,16), dpi=100)
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
ax = gs.subplots(sharex='col', sharey='row')
_, _, bars = ax[0,0].errorbar(x=ea['price_reduction'], y=ea['emission_reduction'], xerr=zip(*ea['p_inter']), 
                              yerr=zip(*ea['e_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[0,0].errorbar(x=no1['price_reduction'], y=no1['emission_reduction'], xerr=zip(*no1['p_inter']), 
                               yerr=zip(*no1['e_inter']), fmt='o', ls='none', label ='No Pollution')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[0,1].errorbar(x=ea['price_reduction'], y=ea['emission_reduction'], xerr=zip(*ea['p_inter']), 
                              yerr=zip(*ea['e_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[0,1].errorbar(x=free['price_reduction'], y=free['emission_reduction'], xerr=zip(*free['p_inter']), 
                               yerr=zip(*free['e_inter']), fmt='o', ls='none', label ='Robust Model-free DQN')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[1,0].errorbar(x=ea['price_reduction'], y=ea['emission_reduction'], xerr=zip(*ea['p_inter']), 
                              yerr=zip(*ea['e_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[1,0].errorbar(x=epopt['price_reduction'], y=epopt['emission_reduction'], xerr=zip(*epopt['p_inter']), 
                               yerr=zip(*epopt['e_inter']), fmt='o', ls='none', label ='EPOpt')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

_, _, bars = ax[1,1].errorbar(x=ea['price_reduction'], y=ea['emission_reduction'], xerr=zip(*ea['p_inter']), 
                              yerr=zip(*ea['e_inter']), fmt='o', ls='none', label ="Epsilon-NSGA-II")
_, _, bars1 = ax[1,1].errorbar(x=deterministic['price_reduction'], y=deterministic['emission_reduction'], xerr=zip(*deterministic['p_inter']), 
                               yerr=zip(*deterministic['e_inter']), fmt='o', ls='none', label ='Deterministic Model-free DQN')
[bar.set_alpha(0.5) for bar in bars]
[bar.set_alpha(0.5) for bar in bars1]

ax[0,0].set_title("(a)")
ax[0,1].set_title("(b)")
ax[1,0].set_title("(c)")
ax[1,1].set_title("(d)")
ax[0,0].set(ylabel='emission_reduction (tCO2-e per household)')
ax[1,0].set(xlabel='price_reduction ($/MWh)', ylabel='emission_reduction (tCO2-e per household)')
ax[1,1].set(xlabel='price_reduction ($/MWh)')
ax[0,0].legend()
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
