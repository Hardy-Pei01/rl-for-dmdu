# %% [markdown]
# # Robust Dam Problem (random initial state)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_robust_performance_4/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'initial-24-06-2022-23-47_0.tar.gz',
#  'initial-24-06-2022-23-47_1.tar.gz',
#  'initial-24-06-2022-23-47_10.tar.gz',
#  'initial-24-06-2022-23-47_11.tar.gz',
#  'initial-24-06-2022-23-47_12.tar.gz',
#  'initial-24-06-2022-23-47_2.tar.gz',
#  'initial-24-06-2022-23-47_3.tar.gz',
#  'initial-24-06-2022-23-47_4.tar.gz',
#  'initial-24-06-2022-23-47_5.tar.gz',
#  'initial-24-06-2022-23-47_6.tar.gz',
#  'initial-24-06-2022-23-47_7.tar.gz',
#  'initial-24-06-2022-23-47_8.tar.gz',
#  'initial-24-06-2022-23-47_9.tar.gz',
#  'initial_avg-24-06-2022-23-50_0.tar.gz',
#  'initial_avg-24-06-2022-23-50_1.tar.gz',
#  'initial_avg-24-06-2022-23-50_10.tar.gz',
#  'initial_avg-24-06-2022-23-50_11.tar.gz',
#  'initial_avg-24-06-2022-23-50_12.tar.gz',
#  'initial_avg-24-06-2022-23-50_13.tar.gz',
#  'initial_avg-24-06-2022-23-50_14.tar.gz',
#  'initial_avg-24-06-2022-23-50_15.tar.gz',
#  'initial_avg-24-06-2022-23-50_16.tar.gz',
#  'initial_avg-24-06-2022-23-50_17.tar.gz',
#  'initial_avg-24-06-2022-23-50_18.tar.gz',
#  'initial_avg-24-06-2022-23-50_19.tar.gz',
#  'initial_avg-24-06-2022-23-50_2.tar.gz',
#  'initial_avg-24-06-2022-23-50_20.tar.gz',
#  'initial_avg-24-06-2022-23-50_21.tar.gz',
#  'initial_avg-24-06-2022-23-50_22.tar.gz',
#  'initial_avg-24-06-2022-23-50_23.tar.gz',
#  'initial_avg-24-06-2022-23-50_24.tar.gz',
#  'initial_avg-24-06-2022-23-50_25.tar.gz',
#  'initial_avg-24-06-2022-23-50_26.tar.gz',
#  'initial_avg-24-06-2022-23-50_27.tar.gz',
#  'initial_avg-24-06-2022-23-50_28.tar.gz',
#  'initial_avg-24-06-2022-23-50_29.tar.gz',
#  'initial_avg-24-06-2022-23-50_3.tar.gz',
#  'initial_avg-24-06-2022-23-50_30.tar.gz',
#  'initial_avg-24-06-2022-23-50_31.tar.gz',
#  'initial_avg-24-06-2022-23-50_32.tar.gz',
#  'initial_avg-24-06-2022-23-50_33.tar.gz',
#  'initial_avg-24-06-2022-23-50_34.tar.gz',
#  'initial_avg-24-06-2022-23-50_35.tar.gz',
#  'initial_avg-24-06-2022-23-50_36.tar.gz',
#  'initial_avg-24-06-2022-23-50_37.tar.gz',
#  'initial_avg-24-06-2022-23-50_38.tar.gz',
#  'initial_avg-24-06-2022-23-50_39.tar.gz',
#  'initial_avg-24-06-2022-23-50_4.tar.gz',
#  'initial_avg-24-06-2022-23-50_5.tar.gz',
#  'initial_avg-24-06-2022-23-50_6.tar.gz',
#  'initial_avg-24-06-2022-23-50_7.tar.gz',
#  'initial_avg-24-06-2022-23-50_8.tar.gz',
#  'initial_avg-24-06-2022-23-50_9.tar.gz',
#  'nes_random_initial-24-06-2022-21-50_best.csv',
#  'nes_random_initial-24-06-2022-21-54_high.csv',
#  'nes_random_initial_avg-25-06-2022-16-13_best.csv',
#  'nes_random_initial_avg-25-06-2022-16-15_high.csv',
#  'repsep_random_initial-24-06-2022-21-57_best.csv',
#  'repsep_random_initial-24-06-2022-22-00_high.csv',
#  'repsep_random_initial_avg-25-06-2022-14-46_best.csv',
#  'repsep_random_initial_avg-25-06-2022-14-50_high.csv']

# %%
ea=[]
for i in range(1, 14):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# initial-24-06-2022-23-47_0.tar.gz
# initial-24-06-2022-23-47_1.tar.gz
# initial-24-06-2022-23-47_10.tar.gz
# initial-24-06-2022-23-47_11.tar.gz
# initial-24-06-2022-23-47_12.tar.gz
# initial-24-06-2022-23-47_2.tar.gz
# initial-24-06-2022-23-47_3.tar.gz
# initial-24-06-2022-23-47_4.tar.gz
# initial-24-06-2022-23-47_5.tar.gz
# initial-24-06-2022-23-47_6.tar.gz
# initial-24-06-2022-23-47_7.tar.gz
# initial-24-06-2022-23-47_8.tar.gz
# initial-24-06-2022-23-47_9.tar.gz
#      utility  reliability       Algorithms
# 0  -2.568756    -9.306250  Epsilon-NSGA-II
# 1  -2.418755    -9.331250  Epsilon-NSGA-II
# 2  -3.806257    -9.200000  Epsilon-NSGA-II
# 3  -3.956258    -9.037500  Epsilon-NSGA-II
# 4  -3.212507    -9.206250  Epsilon-NSGA-II
# 5  -2.025005    -9.337500  Epsilon-NSGA-II
# 6  -1.431253    -9.531250  Epsilon-NSGA-II
# 7  -3.062506    -9.231250  Epsilon-NSGA-II
# 8  -1.581254    -9.437500  Epsilon-NSGA-II
# 9  -1.087502    -9.700000  Epsilon-NSGA-II
# 10 -1.237503    -9.606250  Epsilon-NSGA-II
# 11 -0.556260    -9.756251  Epsilon-NSGA-II
# 12 -1.875004    -9.431250  Epsilon-NSGA-II

# %%
path = files[54]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes_random_initial-24-06-2022-21-50_best.csv
#       utility  reliability Algorithms
# 0   -1.376717    -9.391478     MO-NES
# 1   -0.641660    -9.630563     MO-NES
# 2   -1.072196    -9.468845     MO-NES
# 3   -3.922386    -8.967798     MO-NES
# 4   -3.978301    -8.961439     MO-NES
# ..        ...          ...        ...
# 123 -2.707660    -9.129149     MO-NES
# 124 -3.878013    -8.972861     MO-NES
# 125 -3.928329    -8.967129     MO-NES
# 126 -4.017522    -8.957081     MO-NES
# 127 -4.025008    -8.956249     MO-NES
#
# [128 rows x 3 columns]

# %%
path = files[59]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep_random_initial-24-06-2022-22-00_high.csv
#      utility  reliability Algorithms
# 0  -0.644172    -9.628526   MO-eREPS
# 1  -0.556287    -9.745691   MO-eREPS
# 2  -0.556606    -9.741292   MO-eREPS
# 3  -0.560185    -9.731037   MO-eREPS
# 4  -0.556975    -9.740043   MO-eREPS
# ..       ...          ...        ...
# 87 -0.570464    -9.725049   MO-eREPS
# 88 -0.956355    -9.494278   MO-eREPS
# 89 -3.880934    -8.973296   MO-eREPS
# 90 -3.969116    -8.962645   MO-eREPS
# 91 -4.025008    -8.956249   MO-eREPS
#
# [92 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(14, 54):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 0:04:06
# Out:
# initial_avg-24-06-2022-23-50_0.tar.gz
# initial_avg-24-06-2022-23-50_1.tar.gz
# initial_avg-24-06-2022-23-50_10.tar.gz
# initial_avg-24-06-2022-23-50_11.tar.gz
# initial_avg-24-06-2022-23-50_12.tar.gz
# initial_avg-24-06-2022-23-50_13.tar.gz
# initial_avg-24-06-2022-23-50_14.tar.gz
# initial_avg-24-06-2022-23-50_15.tar.gz
# initial_avg-24-06-2022-23-50_16.tar.gz
# initial_avg-24-06-2022-23-50_17.tar.gz
# initial_avg-24-06-2022-23-50_18.tar.gz
# initial_avg-24-06-2022-23-50_19.tar.gz
# initial_avg-24-06-2022-23-50_2.tar.gz
# initial_avg-24-06-2022-23-50_20.tar.gz
# initial_avg-24-06-2022-23-50_21.tar.gz
# initial_avg-24-06-2022-23-50_22.tar.gz
# initial_avg-24-06-2022-23-50_23.tar.gz
# initial_avg-24-06-2022-23-50_24.tar.gz
# initial_avg-24-06-2022-23-50_25.tar.gz
# initial_avg-24-06-2022-23-50_26.tar.gz
# initial_avg-24-06-2022-23-50_27.tar.gz
# initial_avg-24-06-2022-23-50_28.tar.gz
# initial_avg-24-06-2022-23-50_29.tar.gz
# initial_avg-24-06-2022-23-50_3.tar.gz
# initial_avg-24-06-2022-23-50_30.tar.gz
# initial_avg-24-06-2022-23-50_31.tar.gz
# initial_avg-24-06-2022-23-50_32.tar.gz
# initial_avg-24-06-2022-23-50_33.tar.gz
# initial_avg-24-06-2022-23-50_34.tar.gz
# initial_avg-24-06-2022-23-50_35.tar.gz
# initial_avg-24-06-2022-23-50_36.tar.gz
# initial_avg-24-06-2022-23-50_37.tar.gz
# initial_avg-24-06-2022-23-50_38.tar.gz
# initial_avg-24-06-2022-23-50_39.tar.gz
# initial_avg-24-06-2022-23-50_4.tar.gz
# initial_avg-24-06-2022-23-50_5.tar.gz
# initial_avg-24-06-2022-23-50_6.tar.gz
# initial_avg-24-06-2022-23-50_7.tar.gz
# initial_avg-24-06-2022-23-50_8.tar.gz
# initial_avg-24-06-2022-23-50_9.tar.gz
#      utility  reliability           Algorithms
# 0  -0.631263    -9.687495  Epsilon-NSGA-II_avg
# 1  -0.743768    -9.631246  Epsilon-NSGA-II_avg
# 2  -2.987515    -9.099998  Epsilon-NSGA-II_avg
# 3  -2.637506    -9.156249  Epsilon-NSGA-II_avg
# 4  -1.375033    -9.399994  Epsilon-NSGA-II_avg
# 5  -0.587513    -9.699996  Epsilon-NSGA-II_avg
# 6  -3.281257    -9.056249  Epsilon-NSGA-II_avg
# 7  -0.968773    -9.549995  Epsilon-NSGA-II_avg
# 8  -0.837521    -9.593746  Epsilon-NSGA-II_avg
# 9  -0.787517    -9.618744  Epsilon-NSGA-II_avg
# 10 -1.150027    -9.481245  Epsilon-NSGA-II_avg
# 11 -0.662515    -9.674997  Epsilon-NSGA-II_avg
# 12 -0.687517    -9.643745  Epsilon-NSGA-II_avg
# 13 -1.043774    -9.524996  Epsilon-NSGA-II_avg
# 14 -1.350030    -9.431246  Epsilon-NSGA-II_avg
# 15 -1.750036    -9.331246  Epsilon-NSGA-II_avg
# 16 -0.562511    -9.731248  Epsilon-NSGA-II_avg
# 17 -0.818769    -9.606247  Epsilon-NSGA-II_avg
# 18 -1.550033    -9.381245  Epsilon-NSGA-II_avg
# 19 -1.218778    -9.468745  Epsilon-NSGA-II_avg
# 20 -1.775038    -9.299994  Epsilon-NSGA-II_avg
# 21 -1.275029    -9.456245  Epsilon-NSGA-II_avg
# 22 -0.556260    -9.750000  Epsilon-NSGA-II_avg
# 23 -1.650004    -9.356249  Epsilon-NSGA-II_avg
# 24 -3.687517    -8.999998  Epsilon-NSGA-II_avg
# 25 -2.243770    -9.224997  Epsilon-NSGA-II_avg
# 26 -1.318778    -9.443744  Epsilon-NSGA-II_avg
# 27 -1.012522    -9.537494  Epsilon-NSGA-II_avg
# 28 -2.818774    -9.124997  Epsilon-NSGA-II_avg
# 29 -2.312534    -9.206245  Epsilon-NSGA-II_avg
# 30 -1.618783    -9.368745  Epsilon-NSGA-II_avg
# 31 -1.718784    -9.343744  Epsilon-NSGA-II_avg
# 32 -4.025008    -8.956249  Epsilon-NSGA-II_avg
# 33 -1.768787    -9.318746  Epsilon-NSGA-II_avg
# 34 -0.843772    -9.574995  Epsilon-NSGA-II_avg
# 35 -2.387513    -9.199998  Epsilon-NSGA-II_avg
# 36 -2.093755    -9.256249  Epsilon-NSGA-II_avg
# 37 -1.368782    -9.418746  Epsilon-NSGA-II_avg
# 38 -0.912522    -9.562495  Epsilon-NSGA-II_avg
# 39 -1.068777    -9.493744  Epsilon-NSGA-II_avg

# %%
path = files[56]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:00:15
# Out:
# nes_random_initial_avg-25-06-2022-16-13_best.csv
#       utility  reliability  Algorithms
# 0   -4.003539    -8.958634  MO-NES_avg
# 1   -3.393328    -9.032464  MO-NES_avg
# 2   -3.956409    -8.963880  MO-NES_avg
# 3   -1.597319    -9.322045  MO-NES_avg
# 4   -3.672359    -8.997357  MO-NES_avg
# ..        ...          ...         ...
# 897 -4.014509    -8.957416  MO-NES_avg
# 898 -3.728825    -8.990490  MO-NES_avg
# 899 -3.994821    -8.959603  MO-NES_avg
# 900 -4.025008    -8.956249  MO-NES_avg
# 901 -0.778483    -9.666586  MO-NES_avg
#
# [902 rows x 3 columns]

# %%
path = files[60]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:00:15
# Out:
# repsep_random_initial_avg-25-06-2022-14-46_best.csv
#       utility  reliability    Algorithms
# 0   -1.527692    -9.338244  MO-eREPS_avg
# 1   -2.394523    -9.175994  MO-eREPS_avg
# 2   -0.653763    -9.621030  MO-eREPS_avg
# 3   -3.009921    -9.083869  MO-eREPS_avg
# 4   -0.865904    -9.510744  MO-eREPS_avg
# ..        ...          ...           ...
# 792 -0.565533    -9.719326  MO-eREPS_avg
# 793 -1.575646    -9.328244  MO-eREPS_avg
# 794 -2.270404    -9.196994  MO-eREPS_avg
# 795 -1.548882    -9.333744  MO-eREPS_avg
# 796 -4.025008    -8.956249  MO-eREPS_avg
#
# [797 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %% [markdown]
# # Robust Dam Problem (deep)

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/dam_deep_performance/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-26-06-2022-15-11_0.tar.gz',
#  'ea-26-06-2022-15-11_1.tar.gz',
#  'ea-26-06-2022-15-11_10.tar.gz',
#  'ea-26-06-2022-15-11_11.tar.gz',
#  'ea-26-06-2022-15-11_12.tar.gz',
#  'ea-26-06-2022-15-11_13.tar.gz',
#  'ea-26-06-2022-15-11_14.tar.gz',
#  'ea-26-06-2022-15-11_15.tar.gz',
#  'ea-26-06-2022-15-11_16.tar.gz',
#  'ea-26-06-2022-15-11_17.tar.gz',
#  'ea-26-06-2022-15-11_18.tar.gz',
#  'ea-26-06-2022-15-11_19.tar.gz',
#  'ea-26-06-2022-15-11_2.tar.gz',
#  'ea-26-06-2022-15-11_20.tar.gz',
#  'ea-26-06-2022-15-11_21.tar.gz',
#  'ea-26-06-2022-15-11_22.tar.gz',
#  'ea-26-06-2022-15-11_23.tar.gz',
#  'ea-26-06-2022-15-11_24.tar.gz',
#  'ea-26-06-2022-15-11_25.tar.gz',
#  'ea-26-06-2022-15-11_3.tar.gz',
#  'ea-26-06-2022-15-11_4.tar.gz',
#  'ea-26-06-2022-15-11_5.tar.gz',
#  'ea-26-06-2022-15-11_6.tar.gz',
#  'ea-26-06-2022-15-11_7.tar.gz',
#  'ea-26-06-2022-15-11_8.tar.gz',
#  'ea-26-06-2022-15-11_9.tar.gz',
#  'ea_avg-27-06-2022-13-11_0.tar.gz',
#  'ea_avg-27-06-2022-13-11_1.tar.gz',
#  'ea_avg-27-06-2022-13-11_10.tar.gz',
#  'ea_avg-27-06-2022-13-11_11.tar.gz',
#  'ea_avg-27-06-2022-13-11_12.tar.gz',
#  'ea_avg-27-06-2022-13-11_13.tar.gz',
#  'ea_avg-27-06-2022-13-11_14.tar.gz',
#  'ea_avg-27-06-2022-13-11_15.tar.gz',
#  'ea_avg-27-06-2022-13-11_16.tar.gz',
#  'ea_avg-27-06-2022-13-11_17.tar.gz',
#  'ea_avg-27-06-2022-13-11_18.tar.gz',
#  'ea_avg-27-06-2022-13-11_19.tar.gz',
#  'ea_avg-27-06-2022-13-11_2.tar.gz',
#  'ea_avg-27-06-2022-13-11_20.tar.gz',
#  'ea_avg-27-06-2022-13-11_21.tar.gz',
#  'ea_avg-27-06-2022-13-11_22.tar.gz',
#  'ea_avg-27-06-2022-13-11_23.tar.gz',
#  'ea_avg-27-06-2022-13-11_24.tar.gz',
#  'ea_avg-27-06-2022-13-11_25.tar.gz',
#  'ea_avg-27-06-2022-13-11_26.tar.gz',
#  'ea_avg-27-06-2022-13-11_27.tar.gz',
#  'ea_avg-27-06-2022-13-11_28.tar.gz',
#  'ea_avg-27-06-2022-13-11_29.tar.gz',
#  'ea_avg-27-06-2022-13-11_3.tar.gz',
#  'ea_avg-27-06-2022-13-11_30.tar.gz',
#  'ea_avg-27-06-2022-13-11_31.tar.gz',
#  'ea_avg-27-06-2022-13-11_32.tar.gz',
#  'ea_avg-27-06-2022-13-11_33.tar.gz',
#  'ea_avg-27-06-2022-13-11_34.tar.gz',
#  'ea_avg-27-06-2022-13-11_35.tar.gz',
#  'ea_avg-27-06-2022-13-11_36.tar.gz',
#  'ea_avg-27-06-2022-13-11_37.tar.gz',
#  'ea_avg-27-06-2022-13-11_38.tar.gz',
#  'ea_avg-27-06-2022-13-11_39.tar.gz',
#  'ea_avg-27-06-2022-13-11_4.tar.gz',
#  'ea_avg-27-06-2022-13-11_40.tar.gz',
#  'ea_avg-27-06-2022-13-11_41.tar.gz',
#  'ea_avg-27-06-2022-13-11_42.tar.gz',
#  'ea_avg-27-06-2022-13-11_5.tar.gz',
#  'ea_avg-27-06-2022-13-11_6.tar.gz',
#  'ea_avg-27-06-2022-13-11_7.tar.gz',
#  'ea_avg-27-06-2022-13-11_8.tar.gz',
#  'ea_avg-27-06-2022-13-11_9.tar.gz',
#  'nes-26-06-2022-21-19_best.csv',
#  'nes-26-06-2022-21-22_high.csv',
#  'nes_avg-26-06-2022-21-31_best.csv',
#  'nes_avg-26-06-2022-21-34_high.csv',
#  'repsep-26-06-2022-21-25_best.csv',
#  'repsep-26-06-2022-21-28_high.csv',
#  'repsep_avg-26-06-2022-21-37_best.csv',
#  'repsep_avg-26-06-2022-21-40_high.csv']

# %%
ea=[]
for i in range(1, 27):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# 2:44:18
# Out:
# ea-26-06-2022-15-11_0.tar.gz
# ea-26-06-2022-15-11_1.tar.gz
# ea-26-06-2022-15-11_10.tar.gz
# ea-26-06-2022-15-11_11.tar.gz
# ea-26-06-2022-15-11_12.tar.gz
# ea-26-06-2022-15-11_13.tar.gz
# ea-26-06-2022-15-11_14.tar.gz
# ea-26-06-2022-15-11_15.tar.gz
# ea-26-06-2022-15-11_16.tar.gz
# ea-26-06-2022-15-11_17.tar.gz
# ea-26-06-2022-15-11_18.tar.gz
# ea-26-06-2022-15-11_19.tar.gz
# ea-26-06-2022-15-11_2.tar.gz
# ea-26-06-2022-15-11_20.tar.gz
# ea-26-06-2022-15-11_21.tar.gz
# ea-26-06-2022-15-11_22.tar.gz
# ea-26-06-2022-15-11_23.tar.gz
# ea-26-06-2022-15-11_24.tar.gz
# ea-26-06-2022-15-11_25.tar.gz
# ea-26-06-2022-15-11_3.tar.gz
# ea-26-06-2022-15-11_4.tar.gz
# ea-26-06-2022-15-11_5.tar.gz
# ea-26-06-2022-15-11_6.tar.gz
# ea-26-06-2022-15-11_7.tar.gz
# ea-26-06-2022-15-11_8.tar.gz
# ea-26-06-2022-15-11_9.tar.gz
#      utility  reliability       Algorithms
# 0  -3.855989    -9.768025  Epsilon-NSGA-II
# 1  -2.228186   -10.271962  Epsilon-NSGA-II
# 2  -1.559144   -10.327880  Epsilon-NSGA-II
# 3  -1.529102   -10.348104  Epsilon-NSGA-II
# 4  -1.532514   -10.317068  Epsilon-NSGA-II
# 5  -1.530930   -10.305428  Epsilon-NSGA-II
# 6  -1.534795   -10.355391  Epsilon-NSGA-II
# 7  -1.538568   -10.331624  Epsilon-NSGA-II
# 8  -3.485206    -9.898285  Epsilon-NSGA-II
# 9  -2.185315   -10.233152  Epsilon-NSGA-II
# 10 -2.274349   -10.182279  Epsilon-NSGA-II
# 11 -1.752689   -10.344939  Epsilon-NSGA-II
# 12 -3.347662   -10.059953  Epsilon-NSGA-II
# 13 -1.534806   -10.342278  Epsilon-NSGA-II
# 14 -1.527598   -10.321687  Epsilon-NSGA-II
# 15 -2.244872   -10.226086  Epsilon-NSGA-II
# 16 -1.523442   -10.343317  Epsilon-NSGA-II
# 17 -1.510762   -10.352141  Epsilon-NSGA-II
# 18 -1.546102   -10.315531  Epsilon-NSGA-II
# 19 -3.141536   -10.079291  Epsilon-NSGA-II
# 20 -3.858839    -9.903673  Epsilon-NSGA-II
# 21 -1.613669   -10.274511  Epsilon-NSGA-II
# 22 -2.615920   -10.116027  Epsilon-NSGA-II
# 23 -3.632097    -9.908489  Epsilon-NSGA-II
# 24 -2.203648   -10.237452  Epsilon-NSGA-II
# 25 -1.533224   -10.344226  Epsilon-NSGA-II

# %%
path = files[70]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes-26-06-2022-21-19_best.csv
#       utility  reliability Algorithms
# 0   -2.114117    -9.602246     MO-NES
# 1   -5.636447    -8.924484     MO-NES
# 2   -5.579895    -8.926726     MO-NES
# 3   -1.725652   -10.082747     MO-NES
# 4   -4.920148    -9.005466     MO-NES
# ..        ...          ...        ...
# 132 -1.849066    -9.871985     MO-NES
# 133 -2.198548    -9.532786     MO-NES
# 134 -3.720203    -9.195905     MO-NES
# 135 -1.889634    -9.808373     MO-NES
# 136 -1.593370   -10.447196     MO-NES
#
# [137 rows x 3 columns]

# %%
path = files[75]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep-26-06-2022-21-28_high.csv
#       utility  reliability Algorithms
# 0   -3.344331    -9.252391   MO-eREPS
# 1   -2.230676    -9.551368   MO-eREPS
# 2   -2.525559    -9.409162   MO-eREPS
# 3   -1.682565    -9.913501   MO-eREPS
# 4   -1.562144   -10.075878   MO-eREPS
# ..        ...          ...        ...
# 98  -1.378753   -10.597264   MO-eREPS
# 99  -2.044923    -9.616311   MO-eREPS
# 100 -4.744559    -9.021783   MO-eREPS
# 101 -1.383830   -10.575019   MO-eREPS
# 102 -2.979873    -9.313364   MO-eREPS
#
# [103 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
ea_avg=[]
for i in range(27, 70):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Epsilon-NSGA-II_avg"
ea_avg
# 2:49:00
# Out:
# ea_avg-27-06-2022-13-11_0.tar.gz
# ea_avg-27-06-2022-13-11_1.tar.gz
# ea_avg-27-06-2022-13-11_10.tar.gz
# ea_avg-27-06-2022-13-11_11.tar.gz
# ea_avg-27-06-2022-13-11_12.tar.gz
# ea_avg-27-06-2022-13-11_13.tar.gz
# ea_avg-27-06-2022-13-11_14.tar.gz
# ea_avg-27-06-2022-13-11_15.tar.gz
# ea_avg-27-06-2022-13-11_16.tar.gz
# ea_avg-27-06-2022-13-11_17.tar.gz
# ea_avg-27-06-2022-13-11_18.tar.gz
# ea_avg-27-06-2022-13-11_19.tar.gz
# ea_avg-27-06-2022-13-11_2.tar.gz
# ea_avg-27-06-2022-13-11_20.tar.gz
# ea_avg-27-06-2022-13-11_21.tar.gz
# ea_avg-27-06-2022-13-11_22.tar.gz
# ea_avg-27-06-2022-13-11_23.tar.gz
# ea_avg-27-06-2022-13-11_24.tar.gz
# ea_avg-27-06-2022-13-11_25.tar.gz
# ea_avg-27-06-2022-13-11_26.tar.gz
# ea_avg-27-06-2022-13-11_27.tar.gz
# ea_avg-27-06-2022-13-11_28.tar.gz
# ea_avg-27-06-2022-13-11_29.tar.gz
# ea_avg-27-06-2022-13-11_3.tar.gz
# ea_avg-27-06-2022-13-11_30.tar.gz
# ea_avg-27-06-2022-13-11_31.tar.gz
# ea_avg-27-06-2022-13-11_32.tar.gz
# ea_avg-27-06-2022-13-11_33.tar.gz
# ea_avg-27-06-2022-13-11_34.tar.gz
# ea_avg-27-06-2022-13-11_35.tar.gz
# ea_avg-27-06-2022-13-11_36.tar.gz
# ea_avg-27-06-2022-13-11_37.tar.gz
# ea_avg-27-06-2022-13-11_38.tar.gz
# ea_avg-27-06-2022-13-11_39.tar.gz
# ea_avg-27-06-2022-13-11_4.tar.gz
# ea_avg-27-06-2022-13-11_40.tar.gz
# ea_avg-27-06-2022-13-11_41.tar.gz
# ea_avg-27-06-2022-13-11_42.tar.gz
# ea_avg-27-06-2022-13-11_5.tar.gz
# ea_avg-27-06-2022-13-11_6.tar.gz
# ea_avg-27-06-2022-13-11_7.tar.gz
# ea_avg-27-06-2022-13-11_8.tar.gz
# ea_avg-27-06-2022-13-11_9.tar.gz
#      utility  reliability           Algorithms
# 0  -2.040153   -10.071143  Epsilon-NSGA-II_avg
# 1  -2.300075   -10.038083  Epsilon-NSGA-II_avg
# 2  -2.607248    -9.841126  Epsilon-NSGA-II_avg
# 3  -2.350266    -9.983253  Epsilon-NSGA-II_avg
# 4  -1.797030   -10.067746  Epsilon-NSGA-II_avg
# 5  -1.510832   -10.283466  Epsilon-NSGA-II_avg
# 6  -4.279376    -9.572393  Epsilon-NSGA-II_avg
# 7  -1.575696   -10.272644  Epsilon-NSGA-II_avg
# 8  -1.810776   -10.077220  Epsilon-NSGA-II_avg
# 9  -1.514583   -10.311756  Epsilon-NSGA-II_avg
# 10 -1.512869   -10.325375  Epsilon-NSGA-II_avg
# 11 -1.627275   -10.210530  Epsilon-NSGA-II_avg
# 12 -4.244516    -9.625068  Epsilon-NSGA-II_avg
# 13 -5.195264    -9.431113  Epsilon-NSGA-II_avg
# 14 -2.192946    -9.978066  Epsilon-NSGA-II_avg
# 15 -3.043799    -9.749599  Epsilon-NSGA-II_avg
# 16 -1.797780   -10.132125  Epsilon-NSGA-II_avg
# 17 -3.697356    -9.642548  Epsilon-NSGA-II_avg
# 18 -2.366061    -9.888768  Epsilon-NSGA-II_avg
# 19 -1.815423   -10.086905  Epsilon-NSGA-II_avg
# 20 -1.506617   -10.288518  Epsilon-NSGA-II_avg
# 21 -1.510471   -10.334375  Epsilon-NSGA-II_avg
# 22 -1.527834   -10.290246  Epsilon-NSGA-II_avg
# 23 -2.640739    -9.912189  Epsilon-NSGA-II_avg
# 24 -1.498974   -10.317031  Epsilon-NSGA-II_avg
# 25 -1.511662   -10.321732  Epsilon-NSGA-II_avg
# 26 -1.828637   -10.093458  Epsilon-NSGA-II_avg
# 27 -1.515014   -10.322539  Epsilon-NSGA-II_avg
# 28 -1.654084   -10.183698  Epsilon-NSGA-II_avg
# 29 -2.987839    -9.718097  Epsilon-NSGA-II_avg
# 30 -1.497138   -10.321869  Epsilon-NSGA-II_avg
# 31 -1.500901   -10.325114  Epsilon-NSGA-II_avg
# 32 -3.577016    -9.636853  Epsilon-NSGA-II_avg
# 33 -3.487351    -9.694286  Epsilon-NSGA-II_avg
# 34 -3.639286    -9.688911  Epsilon-NSGA-II_avg
# 35 -5.359413    -9.434456  Epsilon-NSGA-II_avg
# 36 -2.546869    -9.831934  Epsilon-NSGA-II_avg
# 37 -1.529694   -10.280366  Epsilon-NSGA-II_avg
# 38 -1.682736   -10.152077  Epsilon-NSGA-II_avg
# 39 -1.675735   -10.183412  Epsilon-NSGA-II_avg
# 40 -1.517643   -10.300450  Epsilon-NSGA-II_avg
# 41 -1.559791   -10.235443  Epsilon-NSGA-II_avg
# 42 -2.315153    -9.968011  Epsilon-NSGA-II_avg

# %%
path = files[73]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="MO-NES_avg"
print(path)
nes_avg
# 0:03:17
# Out:
# nes_avg-26-06-2022-21-34_high.csv
#       utility  reliability  Algorithms
# 0   -1.684217    -9.862206  MO-NES_avg
# 1   -3.853948    -9.169855  MO-NES_avg
# 2   -1.447906   -10.377448  MO-NES_avg
# 3   -3.068423    -9.296525  MO-NES_avg
# 4   -3.544840    -9.214135  MO-NES_avg
# ..        ...          ...         ...
# 133 -1.899343    -9.657037  MO-NES_avg
# 134 -1.459792   -10.369596  MO-NES_avg
# 135 -4.495076    -9.077563  MO-NES_avg
# 136 -3.801684    -9.184495  MO-NES_avg
# 137 -1.670014    -9.888572  MO-NES_avg
#
# [138 rows x 3 columns]

# %%
path = files[76]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:02:30
# Out:
# repsep_avg-26-06-2022-21-37_best.csv
#       utility  reliability    Algorithms
# 0   -1.986744    -9.595112  MO-eREPS_avg
# 1   -1.408499   -10.463109  MO-eREPS_avg
# 2   -1.378838   -10.570946  MO-eREPS_avg
# 3   -3.175258    -9.286295  MO-eREPS_avg
# 4   -4.851829    -9.035591  MO-eREPS_avg
# ..        ...          ...           ...
# 118 -3.064777    -9.313425  MO-eREPS_avg
# 119 -2.778933    -9.351832  MO-eREPS_avg
# 120 -1.546712   -10.096207  MO-eREPS_avg
# 121 -4.880537    -9.026098  MO-eREPS_avg
# 122 -3.155946    -9.298562  MO-eREPS_avg
#
# [123 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg, repsep_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()
