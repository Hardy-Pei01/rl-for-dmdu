# %%
import os, sys
sys.path.append(os.path.abspath('../'))
from utils.rl.hypervolume2d import hypervolume2d

def compute_hypervolume(df, antiutopia, utopia):
    array = df.drop('Algorithms', axis=1)
    array = array.values
    return hypervolume2d(array, antiutopia, utopia)

# %% [markdown]
# # Discrete Lake Problem

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/lake_discrete_performance_2/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-28-06-2022-15-30_0.tar.gz',
#  'ea-28-06-2022-15-30_1.tar.gz',
#  'ea-28-06-2022-15-30_10.tar.gz',
#  'ea-28-06-2022-15-30_11.tar.gz',
#  'ea-28-06-2022-15-30_12.tar.gz',
#  'ea-28-06-2022-15-30_13.tar.gz',
#  'ea-28-06-2022-15-30_14.tar.gz',
#  'ea-28-06-2022-15-30_15.tar.gz',
#  'ea-28-06-2022-15-30_16.tar.gz',
#  'ea-28-06-2022-15-30_17.tar.gz',
#  'ea-28-06-2022-15-30_18.tar.gz',
#  'ea-28-06-2022-15-30_19.tar.gz',
#  'ea-28-06-2022-15-30_2.tar.gz',
#  'ea-28-06-2022-15-30_20.tar.gz',
#  'ea-28-06-2022-15-30_21.tar.gz',
#  'ea-28-06-2022-15-30_22.tar.gz',
#  'ea-28-06-2022-15-30_23.tar.gz',
#  'ea-28-06-2022-15-30_24.tar.gz',
#  'ea-28-06-2022-15-30_25.tar.gz',
#  'ea-28-06-2022-15-30_26.tar.gz',
#  'ea-28-06-2022-15-30_27.tar.gz',
#  'ea-28-06-2022-15-30_28.tar.gz',
#  'ea-28-06-2022-15-30_29.tar.gz',
#  'ea-28-06-2022-15-30_3.tar.gz',
#  'ea-28-06-2022-15-30_30.tar.gz',
#  'ea-28-06-2022-15-30_31.tar.gz',
#  'ea-28-06-2022-15-30_32.tar.gz',
#  'ea-28-06-2022-15-30_33.tar.gz',
#  'ea-28-06-2022-15-30_34.tar.gz',
#  'ea-28-06-2022-15-30_35.tar.gz',
#  'ea-28-06-2022-15-30_36.tar.gz',
#  'ea-28-06-2022-15-30_37.tar.gz',
#  'ea-28-06-2022-15-30_38.tar.gz',
#  'ea-28-06-2022-15-30_39.tar.gz',
#  'ea-28-06-2022-15-30_4.tar.gz',
#  'ea-28-06-2022-15-30_40.tar.gz',
#  'ea-28-06-2022-15-30_41.tar.gz',
#  'ea-28-06-2022-15-30_42.tar.gz',
#  'ea-28-06-2022-15-30_43.tar.gz',
#  'ea-28-06-2022-15-30_44.tar.gz',
#  'ea-28-06-2022-15-30_45.tar.gz',
#  'ea-28-06-2022-15-30_46.tar.gz',
#  'ea-28-06-2022-15-30_47.tar.gz',
#  'ea-28-06-2022-15-30_48.tar.gz',
#  'ea-28-06-2022-15-30_49.tar.gz',
#  'ea-28-06-2022-15-30_5.tar.gz',
#  'ea-28-06-2022-15-30_50.tar.gz',
#  'ea-28-06-2022-15-30_51.tar.gz',
#  'ea-28-06-2022-15-30_52.tar.gz',
#  'ea-28-06-2022-15-30_53.tar.gz',
#  'ea-28-06-2022-15-30_54.tar.gz',
#  'ea-28-06-2022-15-30_55.tar.gz',
#  'ea-28-06-2022-15-30_56.tar.gz',
#  'ea-28-06-2022-15-30_57.tar.gz',
#  'ea-28-06-2022-15-30_58.tar.gz',
#  'ea-28-06-2022-15-30_59.tar.gz',
#  'ea-28-06-2022-15-30_6.tar.gz',
#  'ea-28-06-2022-15-30_60.tar.gz',
#  'ea-28-06-2022-15-30_61.tar.gz',
#  'ea-28-06-2022-15-30_62.tar.gz',
#  'ea-28-06-2022-15-30_63.tar.gz',
#  'ea-28-06-2022-15-30_64.tar.gz',
#  'ea-28-06-2022-15-30_65.tar.gz',
#  'ea-28-06-2022-15-30_66.tar.gz',
#  'ea-28-06-2022-15-30_67.tar.gz',
#  'ea-28-06-2022-15-30_7.tar.gz',
#  'ea-28-06-2022-15-30_8.tar.gz',
#  'ea-28-06-2022-15-30_9.tar.gz',
#  'nes-07-07-2022-19-01_best.csv',
#  'nes-07-07-2022-19-01_high.csv',
#  'nes-08-07-2022-22-02_best.csv',
#  'nes-08-07-2022-22-02_high.csv',
#  'nes-29-06-2022-14-29_best.csv',
#  'nes-29-06-2022-14-30_high.csv',
#  'repsep-07-07-2022-19-00_best.csv',
#  'repsep-07-07-2022-19-00_high.csv',
#  'repsep-08-07-2022-22-03_best.csv',
#  'repsep-08-07-2022-22-03_high.csv',
#  'repsep-29-06-2022-14-30_best.csv',
#  'repsep-29-06-2022-14-31_high.csv']

# %%
ea=[]
for i in range(1, 68):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Multi-Objective Evolutionary Algorithm"
ea
# 0:01:58
# Out:
# ea-28-06-2022-15-30_0.tar.gz
# ea-28-06-2022-15-30_1.tar.gz
# ea-28-06-2022-15-30_10.tar.gz
# ea-28-06-2022-15-30_11.tar.gz
# ea-28-06-2022-15-30_12.tar.gz
# ea-28-06-2022-15-30_13.tar.gz
# ea-28-06-2022-15-30_14.tar.gz
# ea-28-06-2022-15-30_15.tar.gz
# ea-28-06-2022-15-30_16.tar.gz
# ea-28-06-2022-15-30_17.tar.gz
# ea-28-06-2022-15-30_18.tar.gz
# ea-28-06-2022-15-30_19.tar.gz
# ea-28-06-2022-15-30_2.tar.gz
# ea-28-06-2022-15-30_20.tar.gz
# ea-28-06-2022-15-30_21.tar.gz
# ea-28-06-2022-15-30_22.tar.gz
# ea-28-06-2022-15-30_23.tar.gz
# ea-28-06-2022-15-30_24.tar.gz
# ea-28-06-2022-15-30_25.tar.gz
# ea-28-06-2022-15-30_26.tar.gz
# ea-28-06-2022-15-30_27.tar.gz
# ea-28-06-2022-15-30_28.tar.gz
# ea-28-06-2022-15-30_29.tar.gz
# ea-28-06-2022-15-30_3.tar.gz
# ea-28-06-2022-15-30_30.tar.gz
# ea-28-06-2022-15-30_31.tar.gz
# ea-28-06-2022-15-30_32.tar.gz
# ea-28-06-2022-15-30_33.tar.gz
# ea-28-06-2022-15-30_34.tar.gz
# ea-28-06-2022-15-30_35.tar.gz
# ea-28-06-2022-15-30_36.tar.gz
# ea-28-06-2022-15-30_37.tar.gz
# ea-28-06-2022-15-30_38.tar.gz
# ea-28-06-2022-15-30_39.tar.gz
# ea-28-06-2022-15-30_4.tar.gz
# ea-28-06-2022-15-30_40.tar.gz
# ea-28-06-2022-15-30_41.tar.gz
# ea-28-06-2022-15-30_42.tar.gz
# ea-28-06-2022-15-30_43.tar.gz
# ea-28-06-2022-15-30_44.tar.gz
# ea-28-06-2022-15-30_45.tar.gz
# ea-28-06-2022-15-30_46.tar.gz
# ea-28-06-2022-15-30_47.tar.gz
# ea-28-06-2022-15-30_48.tar.gz
# ea-28-06-2022-15-30_49.tar.gz
# ea-28-06-2022-15-30_5.tar.gz
# ea-28-06-2022-15-30_50.tar.gz
# ea-28-06-2022-15-30_51.tar.gz
# ea-28-06-2022-15-30_52.tar.gz
# ea-28-06-2022-15-30_53.tar.gz
# ea-28-06-2022-15-30_54.tar.gz
# ea-28-06-2022-15-30_55.tar.gz
# ea-28-06-2022-15-30_56.tar.gz
# ea-28-06-2022-15-30_57.tar.gz
# ea-28-06-2022-15-30_58.tar.gz
# ea-28-06-2022-15-30_59.tar.gz
# ea-28-06-2022-15-30_6.tar.gz
# ea-28-06-2022-15-30_60.tar.gz
# ea-28-06-2022-15-30_61.tar.gz
# ea-28-06-2022-15-30_62.tar.gz
# ea-28-06-2022-15-30_63.tar.gz
# ea-28-06-2022-15-30_64.tar.gz
# ea-28-06-2022-15-30_65.tar.gz
# ea-28-06-2022-15-30_66.tar.gz
# ea-28-06-2022-15-30_67.tar.gz
# ea-28-06-2022-15-30_7.tar.gz
# ea-28-06-2022-15-30_8.tar.gz
#      utility  reliability                              Algorithms
# 0   0.834548     0.565657  Multi-Objective Evolutionary Algorithm
# 1   0.999452     0.424242  Multi-Objective Evolutionary Algorithm
# 2   1.333086     0.222222  Multi-Objective Evolutionary Algorithm
# 3   1.239420     0.272727  Multi-Objective Evolutionary Algorithm
# 4   1.259639     0.262626  Multi-Objective Evolutionary Algorithm
# ..       ...          ...                                     ...
# 62  1.055618     0.383838  Multi-Objective Evolutionary Algorithm
# 63  1.532109     0.131313  Multi-Objective Evolutionary Algorithm
# 64  0.650908     0.777778  Multi-Objective Evolutionary Algorithm
# 65  1.100535     0.353535  Multi-Objective Evolutionary Algorithm
# 66  0.767550     0.636364  Multi-Objective Evolutionary Algorithm
#
# [67 rows x 3 columns]

# %%
path = files[71]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="Reinforcement Learning"
print(path)
nes
# 0:00:07
# Out:
# nes-08-07-2022-22-02_best.csv
#      utility  reliability              Algorithms
# 0   1.455590     0.161616  Reinforcement Learning
# 1   1.021355     0.373737  Reinforcement Learning
# 2   1.409339     0.171717  Reinforcement Learning
# 3   1.109492     0.313131  Reinforcement Learning
# 4   1.372499     0.191919  Reinforcement Learning
# 5   1.656497     0.080808  Reinforcement Learning
# 6   1.706516     0.060606  Reinforcement Learning
# 7   1.234748     0.262626  Reinforcement Learning
# 8   0.818996     0.525253  Reinforcement Learning
# 9   1.194623     0.272727  Reinforcement Learning
# 10  0.899842     0.474747  Reinforcement Learning
# 11  1.123948     0.303030  Reinforcement Learning
# 12  1.101689     0.323232  Reinforcement Learning
# 13  1.397549     0.181818  Reinforcement Learning
# 14  0.790280     0.545455  Reinforcement Learning
# 15  1.059506     0.343434  Reinforcement Learning
# 16  1.692485     0.070707  Reinforcement Learning
# 17  0.922570     0.454545  Reinforcement Learning
# 18  1.498801     0.141414  Reinforcement Learning
# 19  0.981450     0.424242  Reinforcement Learning
# 20  0.593287     0.707071  Reinforcement Learning
# 21  0.870617     0.494949  Reinforcement Learning
# 22  1.569689     0.111111  Reinforcement Learning
# 23  0.984964     0.404040  Reinforcement Learning
# 24  1.049888     0.353535  Reinforcement Learning
# 25  1.593923     0.101010  Reinforcement Learning
# 26  1.150438     0.292929  Reinforcement Learning
# 27  0.998344     0.393939  Reinforcement Learning
# 28  1.272318     0.242424  Reinforcement Learning
# 29  1.011997     0.383838  Reinforcement Learning
# 30  1.356036     0.202020  Reinforcement Learning
# 31  0.710235     0.595960  Reinforcement Learning
# 32  1.039343     0.363636  Reinforcement Learning
# 33  0.888912     0.484848  Reinforcement Learning
# 34  0.759990     0.555556  Reinforcement Learning
# 35  0.845764     0.515152  Reinforcement Learning
# 36  1.508680     0.131313  Reinforcement Learning
# 37  0.528304     1.000000  Reinforcement Learning
# 38  1.638022     0.090909  Reinforcement Learning
# 39  1.319215     0.222222  Reinforcement Learning
# 40  1.465667     0.151515  Reinforcement Learning
# 41  0.912705     0.464646  Reinforcement Learning
# 42  0.960797     0.434343  Reinforcement Learning
# 43  1.091236     0.333333  Reinforcement Learning
# 44  0.930930     0.444444  Reinforcement Learning
# 45  1.325190     0.212121  Reinforcement Learning
# 46  1.533114     0.121212  Reinforcement Learning
# 47  0.722467     0.585859  Reinforcement Learning
# 48  0.860272     0.505051  Reinforcement Learning
# 49  1.179181     0.282828  Reinforcement Learning
# 50  0.642464     0.666667  Reinforcement Learning

# %%
path = files[77]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# 0:00:07
# Out:
# repsep-08-07-2022-22-03_best.csv
#      utility  reliability Algorithms
# 0   0.849545     0.444444   MO-eREPS
# 1   0.871193     0.424242   MO-eREPS
# 2   1.117608     0.222222   MO-eREPS
# 3   1.179884     0.181818   MO-eREPS
# 4   0.626790     0.767677   MO-eREPS
# 5   0.681641     0.666667   MO-eREPS
# 6   0.616056     0.787879   MO-eREPS
# 7   0.765067     0.545455   MO-eREPS
# 8   0.656216     0.696970   MO-eREPS
# 9   0.629457     0.757576   MO-eREPS
# 10  0.882509     0.414141   MO-eREPS
# 11  0.556973     0.919192   MO-eREPS
# 12  1.128365     0.212121   MO-eREPS
# 13  0.935088     0.353535   MO-eREPS
# 14  0.695085     0.646465   MO-eREPS
# 15  0.621422     0.777778   MO-eREPS
# 16  1.006920     0.303030   MO-eREPS
# 17  0.839850     0.454545   MO-eREPS
# 18  0.573043     0.888889   MO-eREPS
# 19  0.773648     0.535354   MO-eREPS
# 20  1.020855     0.292929   MO-eREPS
# 21  0.786696     0.515152   MO-eREPS
# 22  0.756664     0.555556   MO-eREPS
# 23  0.979333     0.323232   MO-eREPS
# 24  0.713846     0.595960   MO-eREPS
# 25  0.893407     0.404040   MO-eREPS
# 26  0.598647     0.818182   MO-eREPS
# 27  0.966493     0.333333   MO-eREPS
# 28  0.698696     0.636364   MO-eREPS
# 29  0.688375     0.656566   MO-eREPS
# 30  0.993061     0.313131   MO-eREPS
# 31  1.197642     0.171717   MO-eREPS
# 32  1.144728     0.202020   MO-eREPS
# 33  0.605862     0.808081   MO-eREPS
# 34  0.825244     0.464646   MO-eREPS
# 35  1.213554     0.161616   MO-eREPS
# 36  0.859935     0.434343   MO-eREPS
# 37  0.577094     0.878788   MO-eREPS
# 38  1.260568     0.131313   MO-eREPS
# 39  1.161602     0.191919   MO-eREPS
# 40  0.782417     0.525253   MO-eREPS
# 41  0.535899     1.000000   MO-eREPS
# 42  1.280644     0.121212   MO-eREPS
# 43  1.232244     0.151515   MO-eREPS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 compute_hypervolume(ea, np.array([0, 0]), np.array([1.8, 1]))
#
# Input In [1], in compute_hypervolume(df, antiutopia, utopia)
#       6 array = df.drop('Algorithms', axis=1)
#       7 array = array.values
# ----> 8 return hypervolume2d(array, antiutopia, utopia)
#
# File ~/Documents/PhD-Project/code/Evolutionary/utils/rl/hypervolume2d.py:26, in hypervolume2d(f, antiutopia, utopia)
#       6 def hypervolume2d(f=None, antiutopia=None, utopia=None):
#       7     # HYPERVOLUME2D Computes the hypervolume of a 2-dimensional frontier for a
#       8     # maximization problem. If the user provides both the utopia and antiutopia,
#    (...)
#      23     #    OUTPUT
#      24     #     - hv         : hypervolume
# ---> 26     f, _, _ = pareto(f)
#      28     if utopia is not None:
#      29         f = normalize_data(f, antiutopia, utopia)
#
# ValueError: too many values to unpack (expected 3)

# %%
compute_hypervolume(nes, np.array([0, 0]), np.array([1.8, 1]))

# %%
compute_hypervolume(repsep, np.array([0, 0]), np.array([1.8, 1]))

# %% [markdown]
# # Robust Lake Problem

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import pandas as pd
import numpy as np
from EMAWorkbench import load_results

results_path='../results/lake_robust_performance_2/'
files=sorted(os.listdir(results_path))
files
# Out:
# ['.DS_Store',
#  'ea-28-06-2022-15-31_0.tar.gz',
#  'ea-28-06-2022-15-31_1.tar.gz',
#  'ea-28-06-2022-15-31_10.tar.gz',
#  'ea-28-06-2022-15-31_11.tar.gz',
#  'ea-28-06-2022-15-31_12.tar.gz',
#  'ea-28-06-2022-15-31_13.tar.gz',
#  'ea-28-06-2022-15-31_14.tar.gz',
#  'ea-28-06-2022-15-31_15.tar.gz',
#  'ea-28-06-2022-15-31_16.tar.gz',
#  'ea-28-06-2022-15-31_17.tar.gz',
#  'ea-28-06-2022-15-31_18.tar.gz',
#  'ea-28-06-2022-15-31_19.tar.gz',
#  'ea-28-06-2022-15-31_2.tar.gz',
#  'ea-28-06-2022-15-31_20.tar.gz',
#  'ea-28-06-2022-15-31_21.tar.gz',
#  'ea-28-06-2022-15-31_22.tar.gz',
#  'ea-28-06-2022-15-31_23.tar.gz',
#  'ea-28-06-2022-15-31_24.tar.gz',
#  'ea-28-06-2022-15-31_25.tar.gz',
#  'ea-28-06-2022-15-31_26.tar.gz',
#  'ea-28-06-2022-15-31_27.tar.gz',
#  'ea-28-06-2022-15-31_28.tar.gz',
#  'ea-28-06-2022-15-31_29.tar.gz',
#  'ea-28-06-2022-15-31_3.tar.gz',
#  'ea-28-06-2022-15-31_30.tar.gz',
#  'ea-28-06-2022-15-31_31.tar.gz',
#  'ea-28-06-2022-15-31_32.tar.gz',
#  'ea-28-06-2022-15-31_33.tar.gz',
#  'ea-28-06-2022-15-31_34.tar.gz',
#  'ea-28-06-2022-15-31_35.tar.gz',
#  'ea-28-06-2022-15-31_36.tar.gz',
#  'ea-28-06-2022-15-31_37.tar.gz',
#  'ea-28-06-2022-15-31_38.tar.gz',
#  'ea-28-06-2022-15-31_39.tar.gz',
#  'ea-28-06-2022-15-31_4.tar.gz',
#  'ea-28-06-2022-15-31_40.tar.gz',
#  'ea-28-06-2022-15-31_41.tar.gz',
#  'ea-28-06-2022-15-31_42.tar.gz',
#  'ea-28-06-2022-15-31_43.tar.gz',
#  'ea-28-06-2022-15-31_44.tar.gz',
#  'ea-28-06-2022-15-31_45.tar.gz',
#  'ea-28-06-2022-15-31_46.tar.gz',
#  'ea-28-06-2022-15-31_47.tar.gz',
#  'ea-28-06-2022-15-31_48.tar.gz',
#  'ea-28-06-2022-15-31_49.tar.gz',
#  'ea-28-06-2022-15-31_5.tar.gz',
#  'ea-28-06-2022-15-31_50.tar.gz',
#  'ea-28-06-2022-15-31_51.tar.gz',
#  'ea-28-06-2022-15-31_52.tar.gz',
#  'ea-28-06-2022-15-31_6.tar.gz',
#  'ea-28-06-2022-15-31_7.tar.gz',
#  'ea-28-06-2022-15-31_8.tar.gz',
#  'ea-28-06-2022-15-31_9.tar.gz',
#  'ea_avg-29-06-2022-13-44_0.tar.gz',
#  'ea_avg-29-06-2022-13-44_1.tar.gz',
#  'ea_avg-29-06-2022-13-44_10.tar.gz',
#  'ea_avg-29-06-2022-13-44_11.tar.gz',
#  'ea_avg-29-06-2022-13-44_12.tar.gz',
#  'ea_avg-29-06-2022-13-44_13.tar.gz',
#  'ea_avg-29-06-2022-13-44_14.tar.gz',
#  'ea_avg-29-06-2022-13-44_15.tar.gz',
#  'ea_avg-29-06-2022-13-44_16.tar.gz',
#  'ea_avg-29-06-2022-13-44_17.tar.gz',
#  'ea_avg-29-06-2022-13-44_18.tar.gz',
#  'ea_avg-29-06-2022-13-44_19.tar.gz',
#  'ea_avg-29-06-2022-13-44_2.tar.gz',
#  'ea_avg-29-06-2022-13-44_20.tar.gz',
#  'ea_avg-29-06-2022-13-44_21.tar.gz',
#  'ea_avg-29-06-2022-13-44_22.tar.gz',
#  'ea_avg-29-06-2022-13-44_23.tar.gz',
#  'ea_avg-29-06-2022-13-44_24.tar.gz',
#  'ea_avg-29-06-2022-13-44_25.tar.gz',
#  'ea_avg-29-06-2022-13-44_26.tar.gz',
#  'ea_avg-29-06-2022-13-44_27.tar.gz',
#  'ea_avg-29-06-2022-13-44_28.tar.gz',
#  'ea_avg-29-06-2022-13-44_29.tar.gz',
#  'ea_avg-29-06-2022-13-44_3.tar.gz',
#  'ea_avg-29-06-2022-13-44_30.tar.gz',
#  'ea_avg-29-06-2022-13-44_31.tar.gz',
#  'ea_avg-29-06-2022-13-44_32.tar.gz',
#  'ea_avg-29-06-2022-13-44_33.tar.gz',
#  'ea_avg-29-06-2022-13-44_34.tar.gz',
#  'ea_avg-29-06-2022-13-44_35.tar.gz',
#  'ea_avg-29-06-2022-13-44_36.tar.gz',
#  'ea_avg-29-06-2022-13-44_37.tar.gz',
#  'ea_avg-29-06-2022-13-44_38.tar.gz',
#  'ea_avg-29-06-2022-13-44_39.tar.gz',
#  'ea_avg-29-06-2022-13-44_4.tar.gz',
#  'ea_avg-29-06-2022-13-44_40.tar.gz',
#  'ea_avg-29-06-2022-13-44_41.tar.gz',
#  'ea_avg-29-06-2022-13-44_42.tar.gz',
#  'ea_avg-29-06-2022-13-44_43.tar.gz',
#  'ea_avg-29-06-2022-13-44_44.tar.gz',
#  'ea_avg-29-06-2022-13-44_45.tar.gz',
#  'ea_avg-29-06-2022-13-44_46.tar.gz',
#  'ea_avg-29-06-2022-13-44_47.tar.gz',
#  'ea_avg-29-06-2022-13-44_48.tar.gz',
#  'ea_avg-29-06-2022-13-44_49.tar.gz',
#  'ea_avg-29-06-2022-13-44_5.tar.gz',
#  'ea_avg-29-06-2022-13-44_50.tar.gz',
#  'ea_avg-29-06-2022-13-44_51.tar.gz',
#  'ea_avg-29-06-2022-13-44_52.tar.gz',
#  'ea_avg-29-06-2022-13-44_53.tar.gz',
#  'ea_avg-29-06-2022-13-44_54.tar.gz',
#  'ea_avg-29-06-2022-13-44_55.tar.gz',
#  'ea_avg-29-06-2022-13-44_56.tar.gz',
#  'ea_avg-29-06-2022-13-44_57.tar.gz',
#  'ea_avg-29-06-2022-13-44_58.tar.gz',
#  'ea_avg-29-06-2022-13-44_59.tar.gz',
#  'ea_avg-29-06-2022-13-44_6.tar.gz',
#  'ea_avg-29-06-2022-13-44_60.tar.gz',
#  'ea_avg-29-06-2022-13-44_61.tar.gz',
#  'ea_avg-29-06-2022-13-44_62.tar.gz',
#  'ea_avg-29-06-2022-13-44_63.tar.gz',
#  'ea_avg-29-06-2022-13-44_64.tar.gz',
#  'ea_avg-29-06-2022-13-44_65.tar.gz',
#  'ea_avg-29-06-2022-13-44_66.tar.gz',
#  'ea_avg-29-06-2022-13-44_67.tar.gz',
#  'ea_avg-29-06-2022-13-44_68.tar.gz',
#  'ea_avg-29-06-2022-13-44_69.tar.gz',
#  'ea_avg-29-06-2022-13-44_7.tar.gz',
#  'ea_avg-29-06-2022-13-44_70.tar.gz',
#  'ea_avg-29-06-2022-13-44_71.tar.gz',
#  'ea_avg-29-06-2022-13-44_72.tar.gz',
#  'ea_avg-29-06-2022-13-44_73.tar.gz',
#  'ea_avg-29-06-2022-13-44_74.tar.gz',
#  'ea_avg-29-06-2022-13-44_75.tar.gz',
#  'ea_avg-29-06-2022-13-44_76.tar.gz',
#  'ea_avg-29-06-2022-13-44_77.tar.gz',
#  'ea_avg-29-06-2022-13-44_8.tar.gz',
#  'ea_avg-29-06-2022-13-44_9.tar.gz',
#  'ea_mv-08-07-2022-17-08_0.tar.gz',
#  'ea_mv-08-07-2022-17-08_1.tar.gz',
#  'ea_mv-08-07-2022-17-08_10.tar.gz',
#  'ea_mv-08-07-2022-17-08_11.tar.gz',
#  'ea_mv-08-07-2022-17-08_12.tar.gz',
#  'ea_mv-08-07-2022-17-08_13.tar.gz',
#  'ea_mv-08-07-2022-17-08_14.tar.gz',
#  'ea_mv-08-07-2022-17-08_15.tar.gz',
#  'ea_mv-08-07-2022-17-08_16.tar.gz',
#  'ea_mv-08-07-2022-17-08_17.tar.gz',
#  'ea_mv-08-07-2022-17-08_18.tar.gz',
#  'ea_mv-08-07-2022-17-08_19.tar.gz',
#  'ea_mv-08-07-2022-17-08_2.tar.gz',
#  'ea_mv-08-07-2022-17-08_20.tar.gz',
#  'ea_mv-08-07-2022-17-08_21.tar.gz',
#  'ea_mv-08-07-2022-17-08_22.tar.gz',
#  'ea_mv-08-07-2022-17-08_23.tar.gz',
#  'ea_mv-08-07-2022-17-08_24.tar.gz',
#  'ea_mv-08-07-2022-17-08_25.tar.gz',
#  'ea_mv-08-07-2022-17-08_26.tar.gz',
#  'ea_mv-08-07-2022-17-08_27.tar.gz',
#  'ea_mv-08-07-2022-17-08_28.tar.gz',
#  'ea_mv-08-07-2022-17-08_29.tar.gz',
#  'ea_mv-08-07-2022-17-08_3.tar.gz',
#  'ea_mv-08-07-2022-17-08_30.tar.gz',
#  'ea_mv-08-07-2022-17-08_31.tar.gz',
#  'ea_mv-08-07-2022-17-08_32.tar.gz',
#  'ea_mv-08-07-2022-17-08_33.tar.gz',
#  'ea_mv-08-07-2022-17-08_34.tar.gz',
#  'ea_mv-08-07-2022-17-08_35.tar.gz',
#  'ea_mv-08-07-2022-17-08_36.tar.gz',
#  'ea_mv-08-07-2022-17-08_37.tar.gz',
#  'ea_mv-08-07-2022-17-08_38.tar.gz',
#  'ea_mv-08-07-2022-17-08_39.tar.gz',
#  'ea_mv-08-07-2022-17-08_4.tar.gz',
#  'ea_mv-08-07-2022-17-08_40.tar.gz',
#  'ea_mv-08-07-2022-17-08_41.tar.gz',
#  'ea_mv-08-07-2022-17-08_42.tar.gz',
#  'ea_mv-08-07-2022-17-08_43.tar.gz',
#  'ea_mv-08-07-2022-17-08_44.tar.gz',
#  'ea_mv-08-07-2022-17-08_45.tar.gz',
#  'ea_mv-08-07-2022-17-08_46.tar.gz',
#  'ea_mv-08-07-2022-17-08_47.tar.gz',
#  'ea_mv-08-07-2022-17-08_48.tar.gz',
#  'ea_mv-08-07-2022-17-08_49.tar.gz',
#  'ea_mv-08-07-2022-17-08_5.tar.gz',
#  'ea_mv-08-07-2022-17-08_50.tar.gz',
#  'ea_mv-08-07-2022-17-08_51.tar.gz',
#  'ea_mv-08-07-2022-17-08_52.tar.gz',
#  'ea_mv-08-07-2022-17-08_53.tar.gz',
#  'ea_mv-08-07-2022-17-08_54.tar.gz',
#  'ea_mv-08-07-2022-17-08_55.tar.gz',
#  'ea_mv-08-07-2022-17-08_56.tar.gz',
#  'ea_mv-08-07-2022-17-08_57.tar.gz',
#  'ea_mv-08-07-2022-17-08_58.tar.gz',
#  'ea_mv-08-07-2022-17-08_59.tar.gz',
#  'ea_mv-08-07-2022-17-08_6.tar.gz',
#  'ea_mv-08-07-2022-17-08_7.tar.gz',
#  'ea_mv-08-07-2022-17-08_8.tar.gz',
#  'ea_mv-08-07-2022-17-08_9.tar.gz',
#  'nes-30-06-2022-10-23_best.csv',
#  'nes-30-06-2022-10-33_high.csv',
#  'nes_avg-10-07-2022-12-15_best.csv',
#  'nes_avg-10-07-2022-12-19_high.csv',
#  'nes_mv-10-07-2022-14-53_best.csv',
#  'nes_mv-10-07-2022-14-56_high.csv',
#  'repsep-30-06-2022-09-59_best.csv',
#  'repsep-30-06-2022-10-10_high.csv',
#  'repsep_avg-10-07-2022-12-22_best.csv',
#  'repsep_avg-10-07-2022-12-25_high.csv',
#  'repsep_mv-10-07-2022-14-46_best.csv',
#  'repsep_mv-10-07-2022-14-50_high.csv']

# %%
ea=[]
for i in range(1, 54):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea.append(all_outcomes)
    print(files[i])
ea=pd.DataFrame(ea)
ea["Algorithms"]="Epsilon-NSGA-II"
ea
# Out:
# ea-28-06-2022-15-31_0.tar.gz
# ea-28-06-2022-15-31_1.tar.gz
# ea-28-06-2022-15-31_10.tar.gz
# ea-28-06-2022-15-31_11.tar.gz
# ea-28-06-2022-15-31_12.tar.gz
# ea-28-06-2022-15-31_13.tar.gz
# ea-28-06-2022-15-31_14.tar.gz
# ea-28-06-2022-15-31_15.tar.gz
# ea-28-06-2022-15-31_16.tar.gz
# ea-28-06-2022-15-31_17.tar.gz
# ea-28-06-2022-15-31_18.tar.gz
# ea-28-06-2022-15-31_19.tar.gz
# ea-28-06-2022-15-31_2.tar.gz
# ea-28-06-2022-15-31_20.tar.gz
# ea-28-06-2022-15-31_21.tar.gz
# ea-28-06-2022-15-31_22.tar.gz
# ea-28-06-2022-15-31_23.tar.gz
# ea-28-06-2022-15-31_24.tar.gz
# ea-28-06-2022-15-31_25.tar.gz
# ea-28-06-2022-15-31_26.tar.gz
# ea-28-06-2022-15-31_27.tar.gz
# ea-28-06-2022-15-31_28.tar.gz
# ea-28-06-2022-15-31_29.tar.gz
# ea-28-06-2022-15-31_3.tar.gz
# ea-28-06-2022-15-31_30.tar.gz
# ea-28-06-2022-15-31_31.tar.gz
# ea-28-06-2022-15-31_32.tar.gz
# ea-28-06-2022-15-31_33.tar.gz
# ea-28-06-2022-15-31_34.tar.gz
# ea-28-06-2022-15-31_35.tar.gz
# ea-28-06-2022-15-31_36.tar.gz
# ea-28-06-2022-15-31_37.tar.gz
# ea-28-06-2022-15-31_38.tar.gz
# ea-28-06-2022-15-31_39.tar.gz
# ea-28-06-2022-15-31_4.tar.gz
# ea-28-06-2022-15-31_40.tar.gz
# ea-28-06-2022-15-31_41.tar.gz
# ea-28-06-2022-15-31_42.tar.gz
# ea-28-06-2022-15-31_43.tar.gz
# ea-28-06-2022-15-31_44.tar.gz
# ea-28-06-2022-15-31_45.tar.gz
# ea-28-06-2022-15-31_46.tar.gz
# ea-28-06-2022-15-31_47.tar.gz
# ea-28-06-2022-15-31_48.tar.gz
# ea-28-06-2022-15-31_49.tar.gz
# ea-28-06-2022-15-31_5.tar.gz
# ea-28-06-2022-15-31_50.tar.gz
# ea-28-06-2022-15-31_51.tar.gz
# ea-28-06-2022-15-31_52.tar.gz
# ea-28-06-2022-15-31_6.tar.gz
# ea-28-06-2022-15-31_7.tar.gz
# ea-28-06-2022-15-31_8.tar.gz
# ea-28-06-2022-15-31_9.tar.gz
#      utility  reliability       Algorithms
# 0   1.032270     0.457010  Epsilon-NSGA-II
# 1   1.005158     0.470717  Epsilon-NSGA-II
# 2   1.048112     0.448576  Epsilon-NSGA-II
# 3   1.151146     0.380384  Epsilon-NSGA-II
# 4   0.980567     0.493970  Epsilon-NSGA-II
# 5   1.072330     0.427465  Epsilon-NSGA-II
# 6   0.786413     0.654556  Epsilon-NSGA-II
# 7   1.024543     0.461273  Epsilon-NSGA-II
# 8   0.836847     0.605636  Epsilon-NSGA-II
# 9   0.850771     0.600030  Epsilon-NSGA-II
# 10  1.247618     0.323636  Epsilon-NSGA-II
# 11  0.957851     0.511869  Epsilon-NSGA-II
# 12  1.506197     0.198768  Epsilon-NSGA-II
# 13  1.210899     0.342515  Epsilon-NSGA-II
# 14  0.918363     0.534515  Epsilon-NSGA-II
# 15  1.266682     0.315061  Epsilon-NSGA-II
# 16  0.879470     0.568919  Epsilon-NSGA-II
# 17  1.584534     0.169848  Epsilon-NSGA-II
# 18  1.116989     0.399364  Epsilon-NSGA-II
# 19  1.361618     0.268182  Epsilon-NSGA-II
# 20  1.531981     0.189293  Epsilon-NSGA-II
# 21  1.398934     0.247303  Epsilon-NSGA-II
# 22  1.229420     0.333303  Epsilon-NSGA-II
# 23  1.196986     0.352727  Epsilon-NSGA-II
# 24  1.163760     0.369242  Epsilon-NSGA-II
# 25  0.771059     0.673707  Epsilon-NSGA-II
# 26  0.945166     0.518192  Epsilon-NSGA-II
# 27  0.933761     0.530061  Epsilon-NSGA-II
# 28  1.320934     0.285475  Epsilon-NSGA-II
# 29  1.091201     0.419556  Epsilon-NSGA-II
# 30  1.064417     0.434384  Epsilon-NSGA-II
# 31  1.380336     0.256697  Epsilon-NSGA-II
# 32  0.713856     0.728394  Epsilon-NSGA-II
# 33  1.421777     0.240515  Epsilon-NSGA-II
# 34  0.818263     0.629152  Epsilon-NSGA-II
# 35  1.286634     0.305051  Epsilon-NSGA-II
# 36  1.462626     0.220242  Epsilon-NSGA-II
# 37  1.577490     0.173848  Epsilon-NSGA-II
# 38  0.731127     0.710667  Epsilon-NSGA-II
# 39  1.485318     0.210121  Epsilon-NSGA-II
# 40  1.555400     0.182818  Epsilon-NSGA-II
# 41  0.744014     0.701101  Epsilon-NSGA-II
# 42  0.754790     0.698091  Epsilon-NSGA-II
# 43  0.871126     0.577333  Epsilon-NSGA-II
# 44  1.138115     0.393253  Epsilon-NSGA-II
# 45  1.439552     0.232182  Epsilon-NSGA-II
# 46  0.904950     0.549657  Epsilon-NSGA-II
# 47  1.342161     0.274626  Epsilon-NSGA-II
# 48  1.103499     0.404111  Epsilon-NSGA-II
# 49  0.992853     0.483535  Epsilon-NSGA-II
# 50  0.807572     0.639596  Epsilon-NSGA-II
# 51  1.306103     0.295374  Epsilon-NSGA-II
# 52  1.177896     0.366525  Epsilon-NSGA-II

# %%
path = files[192]
nes = pd.read_csv(results_path + path)
nes["Algorithms"]="MO-NES"
print(path)
nes
# Out:
# nes-30-06-2022-10-23_best.csv
#       utility  reliability Algorithms
# 0    1.188463     0.727237     MO-NES
# 1    1.563660     0.204808     MO-NES
# 2    1.324419     0.559778     MO-NES
# 3    1.235858     0.680631     MO-NES
# 4    1.536645     0.257253     MO-NES
# ..        ...          ...        ...
# 153  1.603657     0.129985     MO-NES
# 154  1.034325     0.881798     MO-NES
# 155  1.098820     0.827348     MO-NES
# 156  1.600895     0.131167     MO-NES
# 157  1.339111     0.551212     MO-NES
#
# [158 rows x 3 columns]

# %%
path = files[198]
repsep = pd.read_csv(results_path + path)
repsep["Algorithms"]="MO-eREPS"
print(path)
repsep
# Out:
# repsep-30-06-2022-09-59_best.csv
#       utility  reliability Algorithms
# 0    1.553069     0.197394   MO-eREPS
# 1    1.270466     0.565359   MO-eREPS
# 2    1.582728     0.142864   MO-eREPS
# 3    1.043540     0.869490   MO-eREPS
# 4    1.581420     0.146106   MO-eREPS
# ..        ...          ...        ...
# 167  1.562026     0.184975   MO-eREPS
# 168  1.597874     0.132172   MO-eREPS
# 169  1.545849     0.202379   MO-eREPS
# 170  1.553514     0.196268   MO-eREPS
# 171  1.541341     0.203924   MO-eREPS
#
# [172 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea, nes, repsep])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 compute_hypervolume(ea, np.array([0, 0]), np.array([1.8, 1]))
#
# Input In [1], in compute_hypervolume(df, antiutopia, utopia)
#       6 array = df.drop('Algorithms', axis=1)
#       7 array = array.values
# ----> 8 return hypervolume2d(array, antiutopia, utopia)
#
# File ~/Documents/PhD-Project/code/Evolutionary/utils/rl/hypervolume2d.py:26, in hypervolume2d(f, antiutopia, utopia)
#       6 def hypervolume2d(f=None, antiutopia=None, utopia=None):
#       7     # HYPERVOLUME2D Computes the hypervolume of a 2-dimensional frontier for a
#       8     # maximization problem. If the user provides both the utopia and antiutopia,
#    (...)
#      23     #    OUTPUT
#      24     #     - hv         : hypervolume
# ---> 26     f, _, _ = pareto(f)
#      28     if utopia is not None:
#      29         f = normalize_data(f, antiutopia, utopia)
#
# ValueError: too many values to unpack (expected 3)

# %%
compute_hypervolume(nes, np.array([0, 0]), np.array([1.8, 1]))

# %%
compute_hypervolume(repsep, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 compute_hypervolume(repsep, np.array([0, 0]), np.array([1.8, 1]))
#
# Input In [1], in compute_hypervolume(df, antiutopia, utopia)
#       6 array = df.drop('Algorithms', axis=1)
#       7 array = array.values
# ----> 8 return hypervolume2d(array, antiutopia, utopia)
#
# File ~/Documents/PhD-Project/code/Evolutionary/utils/rl/hypervolume2d.py:26, in hypervolume2d(f, antiutopia, utopia)
#       6 def hypervolume2d(f=None, antiutopia=None, utopia=None):
#       7     # HYPERVOLUME2D Computes the hypervolume of a 2-dimensional frontier for a
#       8     # maximization problem. If the user provides both the utopia and antiutopia,
#    (...)
#      23     #    OUTPUT
#      24     #     - hv         : hypervolume
# ---> 26     f, _, _ = pareto(f)
#      28     if utopia is not None:
#      29         f = normalize_data(f, antiutopia, utopia)
#
# ValueError: too many values to unpack (expected 3)

# %%
ea_avg=[]
for i in range(54, 132):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_avg.append(all_outcomes)
    print(files[i])
ea_avg=pd.DataFrame(ea_avg)
ea_avg["Algorithms"]="Multi-Objective Evolutionary Algorithm"
ea_avg
# 0:04:06
# Out:
# ea_avg-29-06-2022-13-44_0.tar.gz
# ea_avg-29-06-2022-13-44_1.tar.gz
# ea_avg-29-06-2022-13-44_10.tar.gz
# ea_avg-29-06-2022-13-44_11.tar.gz
# ea_avg-29-06-2022-13-44_12.tar.gz
# ea_avg-29-06-2022-13-44_13.tar.gz
# ea_avg-29-06-2022-13-44_14.tar.gz
# ea_avg-29-06-2022-13-44_15.tar.gz
# ea_avg-29-06-2022-13-44_16.tar.gz
# ea_avg-29-06-2022-13-44_17.tar.gz
# ea_avg-29-06-2022-13-44_18.tar.gz
# ea_avg-29-06-2022-13-44_19.tar.gz
# ea_avg-29-06-2022-13-44_2.tar.gz
# ea_avg-29-06-2022-13-44_20.tar.gz
# ea_avg-29-06-2022-13-44_21.tar.gz
# ea_avg-29-06-2022-13-44_22.tar.gz
# ea_avg-29-06-2022-13-44_23.tar.gz
# ea_avg-29-06-2022-13-44_24.tar.gz
# ea_avg-29-06-2022-13-44_25.tar.gz
# ea_avg-29-06-2022-13-44_26.tar.gz
# ea_avg-29-06-2022-13-44_27.tar.gz
# ea_avg-29-06-2022-13-44_28.tar.gz
# ea_avg-29-06-2022-13-44_29.tar.gz
# ea_avg-29-06-2022-13-44_3.tar.gz
# ea_avg-29-06-2022-13-44_30.tar.gz
# ea_avg-29-06-2022-13-44_31.tar.gz
# ea_avg-29-06-2022-13-44_32.tar.gz
# ea_avg-29-06-2022-13-44_33.tar.gz
# ea_avg-29-06-2022-13-44_34.tar.gz
# ea_avg-29-06-2022-13-44_35.tar.gz
# ea_avg-29-06-2022-13-44_36.tar.gz
# ea_avg-29-06-2022-13-44_37.tar.gz
# ea_avg-29-06-2022-13-44_38.tar.gz
# ea_avg-29-06-2022-13-44_39.tar.gz
# ea_avg-29-06-2022-13-44_4.tar.gz
# ea_avg-29-06-2022-13-44_40.tar.gz
# ea_avg-29-06-2022-13-44_41.tar.gz
# ea_avg-29-06-2022-13-44_42.tar.gz
# ea_avg-29-06-2022-13-44_43.tar.gz
# ea_avg-29-06-2022-13-44_44.tar.gz
# ea_avg-29-06-2022-13-44_45.tar.gz
# ea_avg-29-06-2022-13-44_46.tar.gz
# ea_avg-29-06-2022-13-44_47.tar.gz
# ea_avg-29-06-2022-13-44_48.tar.gz
# ea_avg-29-06-2022-13-44_49.tar.gz
# ea_avg-29-06-2022-13-44_5.tar.gz
# ea_avg-29-06-2022-13-44_50.tar.gz
# ea_avg-29-06-2022-13-44_51.tar.gz
# ea_avg-29-06-2022-13-44_52.tar.gz
# ea_avg-29-06-2022-13-44_53.tar.gz
# ea_avg-29-06-2022-13-44_54.tar.gz
# ea_avg-29-06-2022-13-44_55.tar.gz
# ea_avg-29-06-2022-13-44_56.tar.gz
# ea_avg-29-06-2022-13-44_57.tar.gz
# ea_avg-29-06-2022-13-44_58.tar.gz
# ea_avg-29-06-2022-13-44_59.tar.gz
# ea_avg-29-06-2022-13-44_6.tar.gz
# ea_avg-29-06-2022-13-44_60.tar.gz
# ea_avg-29-06-2022-13-44_61.tar.gz
# ea_avg-29-06-2022-13-44_62.tar.gz
# ea_avg-29-06-2022-13-44_63.tar.gz
# ea_avg-29-06-2022-13-44_64.tar.gz
# ea_avg-29-06-2022-13-44_65.tar.gz
# ea_avg-29-06-2022-13-44_66.tar.gz
# ea_avg-29-06-2022-13-44_67.tar.gz
# ea_avg-29-06-2022-13-44_68.tar.gz
# ea_avg-29-06-2022-13-44_69.tar.gz
# ea_avg-29-06-2022-13-44_7.tar.gz
# ea_avg-29-06-2022-13-44_70.tar.gz
# ea_avg-29-06-2022-13-44_71.tar.gz
# ea_avg-29-06-2022-13-44_72.tar.gz
# ea_avg-29-06-2022-13-44_73.tar.gz
# ea_avg-29-06-2022-13-44_74.tar.gz
# ea_avg-29-06-2022-13-44_75.tar.gz
# ea_avg-29-06-2022-13-44_76.tar.gz
# ea_avg-29-06-2022-13-44_77.tar.gz
# ea_avg-29-06-2022-13-44_8.tar.gz
# ea_avg-29-06-2022-13-44_9.tar.gz
#      utility  reliability                              Algorithms
# 0   1.073661     0.521768  Multi-Objective Evolutionary Algorithm
# 1   1.061348     0.538899  Multi-Objective Evolutionary Algorithm
# 2   0.853979     0.739646  Multi-Objective Evolutionary Algorithm
# 3   0.477292     0.966747  Multi-Objective Evolutionary Algorithm
# 4   0.632031     0.905697  Multi-Objective Evolutionary Algorithm
# ..       ...          ...                                     ...
# 73  1.431175     0.253899  Multi-Objective Evolutionary Algorithm
# 74  1.404195     0.273162  Multi-Objective Evolutionary Algorithm
# 75  1.455055     0.239576  Multi-Objective Evolutionary Algorithm
# 76  0.613959     0.913899  Multi-Objective Evolutionary Algorithm
# 77  1.025449     0.574141  Multi-Objective Evolutionary Algorithm
#
# [78 rows x 3 columns]

# %%
path = files[194]
nes_avg = pd.read_csv(results_path + path)
nes_avg["Algorithms"]="Reinforcement Learning"
print(path)
nes_avg
# 0:00:15
# Out:
# nes_avg-10-07-2022-12-15_best.csv
#       utility  reliability              Algorithms
# 0    1.623059     0.112717  Reinforcement Learning
# 1    0.976107     0.941414  Reinforcement Learning
# 2    1.112623     0.816172  Reinforcement Learning
# 3    1.548380     0.231000  Reinforcement Learning
# 4    1.395691     0.492192  Reinforcement Learning
# ..        ...          ...                     ...
# 260  1.172392     0.759313  Reinforcement Learning
# 261  1.280429     0.642030  Reinforcement Learning
# 262  1.436650     0.445869  Reinforcement Learning
# 263  1.120801     0.807556  Reinforcement Learning
# 264  0.923438     0.984535  Reinforcement Learning
#
# [265 rows x 3 columns]

# %%
path = files[200]
repsep_avg = pd.read_csv(results_path + path)
repsep_avg["Algorithms"]="MO-eREPS_avg"
print(path)
repsep_avg
# 0:00:15
# Out:
# repsep_avg-10-07-2022-12-22_best.csv
#       utility  reliability    Algorithms
# 0    1.036993     0.889707  MO-eREPS_avg
# 1    1.624520     0.110485  MO-eREPS_avg
# 2    1.516562     0.299051  MO-eREPS_avg
# 3    1.559349     0.216071  MO-eREPS_avg
# 4    1.526334     0.283596  MO-eREPS_avg
# ..        ...          ...           ...
# 252  1.564442     0.203879  MO-eREPS_avg
# 253  1.179183     0.722556  MO-eREPS_avg
# 254  1.126082     0.793414  MO-eREPS_avg
# 255  1.641299     0.096283  MO-eREPS_avg
# 256  1.638392     0.097242  MO-eREPS_avg
#
# [257 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_avg, nes_avg])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_avg, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.5988573525884436

# %%
compute_hypervolume(nes_avg, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.7510033811796549

# %%
compute_hypervolume(repsep_avg, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.7465803083585222

# %%
ea_mv=[]
for i in range(132, 192):
    _, all_outcomes=load_results(results_path + files[i])
    all_outcomes=dict((k, np.mean(all_outcomes[k])) for k in ('utility', 'reliability'))
    ea_mv.append(all_outcomes)
    print(files[i])
ea_mv=pd.DataFrame(ea_mv)
ea_mv["Algorithms"]="Epsilon-NSGA-II_mv"
ea_mv
# 0:04:06
# Out:
# ea_mv-08-07-2022-17-08_0.tar.gz
# ea_mv-08-07-2022-17-08_1.tar.gz
# ea_mv-08-07-2022-17-08_10.tar.gz
# ea_mv-08-07-2022-17-08_11.tar.gz
# ea_mv-08-07-2022-17-08_12.tar.gz
# ea_mv-08-07-2022-17-08_13.tar.gz
# ea_mv-08-07-2022-17-08_14.tar.gz
# ea_mv-08-07-2022-17-08_15.tar.gz
# ea_mv-08-07-2022-17-08_16.tar.gz
# ea_mv-08-07-2022-17-08_17.tar.gz
# ea_mv-08-07-2022-17-08_18.tar.gz
# ea_mv-08-07-2022-17-08_19.tar.gz
# ea_mv-08-07-2022-17-08_2.tar.gz
# ea_mv-08-07-2022-17-08_20.tar.gz
# ea_mv-08-07-2022-17-08_21.tar.gz
# ea_mv-08-07-2022-17-08_22.tar.gz
# ea_mv-08-07-2022-17-08_23.tar.gz
# ea_mv-08-07-2022-17-08_24.tar.gz
# ea_mv-08-07-2022-17-08_25.tar.gz
# ea_mv-08-07-2022-17-08_26.tar.gz
# ea_mv-08-07-2022-17-08_27.tar.gz
# ea_mv-08-07-2022-17-08_28.tar.gz
# ea_mv-08-07-2022-17-08_29.tar.gz
# ea_mv-08-07-2022-17-08_3.tar.gz
# ea_mv-08-07-2022-17-08_30.tar.gz
# ea_mv-08-07-2022-17-08_31.tar.gz
# ea_mv-08-07-2022-17-08_32.tar.gz
# ea_mv-08-07-2022-17-08_33.tar.gz
# ea_mv-08-07-2022-17-08_34.tar.gz
# ea_mv-08-07-2022-17-08_35.tar.gz
# ea_mv-08-07-2022-17-08_36.tar.gz
# ea_mv-08-07-2022-17-08_37.tar.gz
# ea_mv-08-07-2022-17-08_38.tar.gz
# ea_mv-08-07-2022-17-08_39.tar.gz
# ea_mv-08-07-2022-17-08_4.tar.gz
# ea_mv-08-07-2022-17-08_40.tar.gz
# ea_mv-08-07-2022-17-08_41.tar.gz
# ea_mv-08-07-2022-17-08_42.tar.gz
# ea_mv-08-07-2022-17-08_43.tar.gz
# ea_mv-08-07-2022-17-08_44.tar.gz
# ea_mv-08-07-2022-17-08_45.tar.gz
# ea_mv-08-07-2022-17-08_46.tar.gz
# ea_mv-08-07-2022-17-08_47.tar.gz
# ea_mv-08-07-2022-17-08_48.tar.gz
# ea_mv-08-07-2022-17-08_49.tar.gz
# ea_mv-08-07-2022-17-08_5.tar.gz
# ea_mv-08-07-2022-17-08_50.tar.gz
# ea_mv-08-07-2022-17-08_51.tar.gz
# ea_mv-08-07-2022-17-08_52.tar.gz
# ea_mv-08-07-2022-17-08_53.tar.gz
# ea_mv-08-07-2022-17-08_54.tar.gz
# ea_mv-08-07-2022-17-08_55.tar.gz
# ea_mv-08-07-2022-17-08_56.tar.gz
# ea_mv-08-07-2022-17-08_57.tar.gz
# ea_mv-08-07-2022-17-08_58.tar.gz
# ea_mv-08-07-2022-17-08_59.tar.gz
# ea_mv-08-07-2022-17-08_6.tar.gz
# ea_mv-08-07-2022-17-08_7.tar.gz
# ea_mv-08-07-2022-17-08_8.tar.gz
# ea_mv-08-07-2022-17-08_9.tar.gz
#      utility  reliability          Algorithms
# 0   0.565321     0.931616  Epsilon-NSGA-II_mv
# 1   0.544156     0.945202  Epsilon-NSGA-II_mv
# 2   0.485837     0.966212  Epsilon-NSGA-II_mv
# 3   0.643194     0.887657  Epsilon-NSGA-II_mv
# 4   1.193909     0.350838  Epsilon-NSGA-II_mv
# 5   0.441433     0.972889  Epsilon-NSGA-II_mv
# 6   0.609279     0.905636  Epsilon-NSGA-II_mv
# 7   0.410735     0.979394  Epsilon-NSGA-II_mv
# 8   1.095198     0.417636  Epsilon-NSGA-II_mv
# 9   0.357559     0.990333  Epsilon-NSGA-II_mv
# 10  0.857000     0.588909  Epsilon-NSGA-II_mv
# 11  1.448109     0.222202  Epsilon-NSGA-II_mv
# 12  0.623952     0.894162  Epsilon-NSGA-II_mv
# 13  0.835722     0.603172  Epsilon-NSGA-II_mv
# 14  0.979956     0.487990  Epsilon-NSGA-II_mv
# 15  1.311789     0.292273  Epsilon-NSGA-II_mv
# 16  0.422313     0.978747  Epsilon-NSGA-II_mv
# 17  1.554351     0.179030  Epsilon-NSGA-II_mv
# 18  1.581722     0.166283  Epsilon-NSGA-II_mv
# 19  1.060352     0.444313  Epsilon-NSGA-II_mv
# 20  0.945550     0.512909  Epsilon-NSGA-II_mv
# 21  1.506023     0.203051  Epsilon-NSGA-II_mv
# 22  1.118418     0.400556  Epsilon-NSGA-II_mv
# 23  0.535450     0.950101  Epsilon-NSGA-II_mv
# 24  1.380600     0.254162  Epsilon-NSGA-II_mv
# 25  1.404477     0.242121  Epsilon-NSGA-II_mv
# 26  1.522054     0.194535  Epsilon-NSGA-II_mv
# 27  1.001256     0.479717  Epsilon-NSGA-II_mv
# 28  1.136682     0.388030  Epsilon-NSGA-II_mv
# 29  0.957981     0.509364  Epsilon-NSGA-II_mv
# 30  0.793857     0.639182  Epsilon-NSGA-II_mv
# 31  0.877476     0.576424  Epsilon-NSGA-II_mv
# 32  0.808047     0.636354  Epsilon-NSGA-II_mv
# 33  1.158726     0.375869  Epsilon-NSGA-II_mv
# 34  0.495296     0.962879  Epsilon-NSGA-II_mv
# 35  1.227737     0.338859  Epsilon-NSGA-II_mv
# 36  1.338602     0.282909  Epsilon-NSGA-II_mv
# 37  1.025365     0.466293  Epsilon-NSGA-II_mv
# 38  1.040816     0.455707  Epsilon-NSGA-II_mv
# 39  1.539044     0.184566  Epsilon-NSGA-II_mv
# 40  1.185553     0.367283  Epsilon-NSGA-II_mv
# 41  0.889144     0.571010  Epsilon-NSGA-II_mv
# 42  1.248702     0.325808  Epsilon-NSGA-II_mv
# 43  0.580570     0.922545  Epsilon-NSGA-II_mv
# 44  1.427938     0.234212  Epsilon-NSGA-II_mv
# 45  0.472649     0.968404  Epsilon-NSGA-II_mv
# 46  0.914947     0.542626  Epsilon-NSGA-II_mv
# 47  0.515136     0.953192  Epsilon-NSGA-II_mv
# 48  1.478003     0.215323  Epsilon-NSGA-II_mv
# 49  1.085009     0.420293  Epsilon-NSGA-II_mv
# 50  1.298846     0.301586  Epsilon-NSGA-II_mv
# 51  0.388860     0.984000  Epsilon-NSGA-II_mv
# 52  0.783396     0.642626  Epsilon-NSGA-II_mv
# 53  0.367879     0.989889  Epsilon-NSGA-II_mv
# 54  1.272911     0.317889  Epsilon-NSGA-II_mv
# 55  1.360950     0.270030  Epsilon-NSGA-II_mv
# 56  0.451434     0.974717  Epsilon-NSGA-II_mv
# 57  0.658056     0.880525  Epsilon-NSGA-II_mv
# 58  0.679703     0.864384  Epsilon-NSGA-II_mv
# 59  0.454145     0.973152  Epsilon-NSGA-II_mv

# %%
path = files[196]
nes_mv = pd.read_csv(results_path + path)
nes_mv["Algorithms"]="MO-NES_mv"
print(path)
nes_mv
# 0:00:15
# Out:
# nes_mv-10-07-2022-14-53_best.csv
#      utility  reliability Algorithms
# 0   0.998129     0.860525  MO-NES_mv
# 1   0.900850     0.985515  MO-NES_mv
# 2   0.950534     0.931646  MO-NES_mv
# 3   0.875522     0.993444  MO-NES_mv
# 4   0.851213     0.994980  MO-NES_mv
# 5   1.128545     0.588848  MO-NES_mv
# 6   0.787426     0.999848  MO-NES_mv
# 7   1.143209     0.546485  MO-NES_mv
# 8   1.243352     0.533162  MO-NES_mv
# 9   0.899968     0.986515  MO-NES_mv
# 10  0.944202     0.934182  MO-NES_mv
# 11  1.472463     0.123455  MO-NES_mv
# 12  0.933646     0.967283  MO-NES_mv
# 13  0.909194     0.979556  MO-NES_mv
# 14  1.424325     0.193980  MO-NES_mv
# 15  0.777577     1.000000  MO-NES_mv
# 16  0.967548     0.897818  MO-NES_mv
# 17  0.907280     0.980475  MO-NES_mv
# 18  0.997691     0.862152  MO-NES_mv
# 19  0.843876     0.996798  MO-NES_mv
# 20  0.993604     0.879374  MO-NES_mv
# 21  0.954496     0.929919  MO-NES_mv
# 22  1.372834     0.213515  MO-NES_mv
# 23  1.129306     0.567949  MO-NES_mv
# 24  0.939796     0.955303  MO-NES_mv
# 25  0.854693     0.993869  MO-NES_mv
# 26  1.026209     0.789960  MO-NES_mv
# 27  1.004475     0.848354  MO-NES_mv
# 28  1.103309     0.745606  MO-NES_mv
# 29  0.939889     0.940697  MO-NES_mv
# 30  1.131128     0.557970  MO-NES_mv
# 31  0.911713     0.979232  MO-NES_mv
# 32  1.106911     0.604596  MO-NES_mv
# 33  0.831078     0.999434  MO-NES_mv
# 34  1.480675     0.118253  MO-NES_mv
# 35  1.103566     0.613667  MO-NES_mv
# 36  1.429477     0.161364  MO-NES_mv
# 37  1.006918     0.845091  MO-NES_mv
# 38  1.036549     0.768414  MO-NES_mv
# 39  1.301305     0.383677  MO-NES_mv
# 40  1.198746     0.540889  MO-NES_mv
# 41  0.904111     0.983121  MO-NES_mv
# 42  0.982533     0.885717  MO-NES_mv
# 43  0.923792     0.973374  MO-NES_mv
# 44  0.965483     0.929131  MO-NES_mv
# 45  1.035563     0.782374  MO-NES_mv
# 46  0.942305     0.938697  MO-NES_mv
# 47  1.332782     0.314222  MO-NES_mv
# 48  0.837090     0.997687  MO-NES_mv
# 49  1.002230     0.852798  MO-NES_mv
# 50  1.028256     0.785485  MO-NES_mv
# 51  0.938129     0.963283  MO-NES_mv
# 52  1.104664     0.606071  MO-NES_mv
# 53  1.141575     0.548182  MO-NES_mv
# 54  1.472462     0.123545  MO-NES_mv
# 55  0.980209     0.893010  MO-NES_mv
# 56  0.901393     0.985485  MO-NES_mv
# 57  1.010716     0.839909  MO-NES_mv
# 58  0.887939     0.991414  MO-NES_mv
# 59  1.018197     0.816899  MO-NES_mv

# %%
path = files[202]
repsep_mv = pd.read_csv(results_path + path)
repsep_mv["Algorithms"]="MO-eREPS_mv"
print(path)
repsep_mv
# 0:00:15
# Out:
# repsep_mv-10-07-2022-14-46_best.csv
#      utility  reliability   Algorithms
# 0   0.887957     0.992202  MO-eREPS_mv
# 1   1.545521     0.192707  MO-eREPS_mv
# 2   1.444597     0.311657  MO-eREPS_mv
# 3   0.961157     0.948152  MO-eREPS_mv
# 4   1.326947     0.429081  MO-eREPS_mv
# 5   0.829915     0.999535  MO-eREPS_mv
# 6   0.908912     0.986172  MO-eREPS_mv
# 7   1.536732     0.195828  MO-eREPS_mv
# 8   0.976232     0.935232  MO-eREPS_mv
# 9   0.832996     0.999343  MO-eREPS_mv
# 10  1.182774     0.599495  MO-eREPS_mv
# 11  0.830696     0.999354  MO-eREPS_mv
# 12  0.873213     0.996242  MO-eREPS_mv
# 13  1.056963     0.786828  MO-eREPS_mv
# 14  0.951161     0.952465  MO-eREPS_mv
# 15  0.900444     0.988990  MO-eREPS_mv
# 16  0.871783     0.997576  MO-eREPS_mv
# 17  1.545438     0.193313  MO-eREPS_mv
# 18  0.884081     0.994495  MO-eREPS_mv
# 19  1.012466     0.871798  MO-eREPS_mv
# 20  1.590027     0.130818  MO-eREPS_mv
# 21  1.546267     0.150485  MO-eREPS_mv
# 22  1.279043     0.486010  MO-eREPS_mv
# 23  1.028723     0.867323  MO-eREPS_mv
# 24  1.421506     0.317000  MO-eREPS_mv
# 25  0.821893     1.000000  MO-eREPS_mv
# 26  1.109474     0.681929  MO-eREPS_mv
# 27  1.486078     0.223303  MO-eREPS_mv
# 28  1.605226     0.123616  MO-eREPS_mv
# 29  0.921118     0.957646  MO-eREPS_mv
# 30  1.545506     0.192737  MO-eREPS_mv
# 31  1.260152     0.499616  MO-eREPS_mv
# 32  0.920593     0.981899  MO-eREPS_mv
# 33  0.869755     0.998636  MO-eREPS_mv
# 34  1.011920     0.890606  MO-eREPS_mv
# 35  1.283482     0.484020  MO-eREPS_mv
# 36  1.545565     0.192626  MO-eREPS_mv
# 37  0.833526     0.998667  MO-eREPS_mv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.concat([ea_mv, nes_mv, repsep_mv])
plt.figure(figsize=(9,6), dpi= 100)
sns.scatterplot(data=data, x="utility", y="reliability", hue="Algorithms", style="Algorithms", s=100)
plt.xlabel("Utility")
plt.ylabel("Reliability")
plt.legend()
plt.show()

# %%
compute_hypervolume(ea_mv, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.5669042060024234

# %%
compute_hypervolume(nes_mv, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.6702711299759384

# %%
compute_hypervolume(repsep_mv, np.array([0, 0]), np.array([1.8, 1]))
# Out:
# 0.697447983800458
